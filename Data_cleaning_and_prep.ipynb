# %%
import google.generativeai as genai
import pathlib
import textwrap
import numpy as np
import tensorflow as tf
from PIL import Image
import cv2
import re
from IPython.display import display
from IPython.display import Markdown
import pandas as pd
import time
import os
import json
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


# !pip install -q -U google-generativeai


GOOGLE_API_KEY = os.environ.get('API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)
model =  genai.GenerativeModel('gemini-pro')

# %% [markdown]
# # Cleaning and Processing Skills:

# %%
### processing the first batch of users using gemeni API

df = pd.read_csv('web_scraping_results.csv')
df1 = pd.DataFrame(columns=['id', 'url', 'skills'])

prompt_base = "return a list of 3 skills that the following courses might teach, each should be 3 words or less, the response should be in this form: 1: the first skill, 2: the second skill, 3: the third skill"
for i in range(0,2200):
    like_name = df['like_name'][i]
    if pd.notna(like_name):  # Check if the value is not NaN
        s = str(like_name).replace('[', '').replace(']', '').replace(':','')
        if len(s) !=0:
          prompt = prompt_base+''+s
          df1.loc[i, 'id'] = df.loc[i, 'id']
          df1.loc[i, 'url'] = df.loc[i, 'url']
          response = model.generate_content(
            prompt,
            generation_config=genai.types.GenerationConfig(
                candidate_count=1,
                temperature=0.55)
          )
          df1['skills'][i] = response.text
          time.sleep(1.5)

# %%
### processing thes econd batch of users using gemeni API
df2 = pd.DataFrame(columns=['id', 'url', 'skills'])

prompt_base = "return a list of 3 skills that the following courses might teach, each should be 3 words or less, the response should be in this form: 1: the first skill, 2: the second skill, 3: the third skill"
for i in range(2199,len(df)):
    like_name = df['like_name'][i]
    if pd.notna(like_name):  # Check if the value is not NaN
        s = str(like_name).replace('[', '').replace(']', '').replace(':','')
        if len(s) !=0:
          prompt = prompt_base+''+s
          df2.loc[i, 'id'] = df.loc[i, 'id']
          df2.loc[i, 'url'] = df.loc[i, 'url']
          response = model.generate_content(
            prompt,
            generation_config=genai.types.GenerationConfig(
                candidate_count=1,
                temperature=0.55)
          )
          df2['skills'][i] = response.text
          time.sleep(1.5)

# %%
### printing an example
pd.set_option('display.max_colwidth', -1)
df2.head(30)
# Out:
# <ipython-input-29-006ba166475a>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                          id  \
# 0   hungwenc
# 1   andremagni
# 2   adithya-ramesh-949496137
# 3   grant-neuman
# 5   bertrand-chauvaux-1a562164
# 7   shivanispv
# 8   berdikhan
# 9   nitish-kumar-vaja-aaa095b0
# 10  wonjunjang
# 11  sachi-sharma
# 12  nikhil-chennupati-98899b127
# 13  amrutha-srinivasan-64937113a
# 14  khe004
# 15  sara-mulherin
# 16  shwetasuman
# 17  jayakrishnan-somasekharan-nair-34bba38b
# 18  jay-scott-b928743
# 19  john-bryan-ba19575a
# 20  yuez1989
# 21  shriya-sharma
# 22  andrew-bradnan-7a04b9117
# 24  gem-li-0018757
# 25  artem-bolshakov-b961a6118
# 26  dhimnsen
# 27  sally-carlson-088b88132
# 28  shri-deshpande
# 29  daniel-tran-a9339333
# 30  william-johnson-b08002116
# 31  haodongzhang
# 32  joseph-sackett-700262a2
#
#                                                          url  \
# 0   https://www.linkedin.com/in/hungwenc
# 1   https://www.linkedin.com/in/andremagni
# 2   https://www.linkedin.com/in/adithya-ramesh-949496137
# 3   https://www.linkedin.com/in/grant-neuman
# 5   https://www.linkedin.com/in/bertrand-chauvaux-1a562164
# 7   https://www.linkedin.com/in/shivanispv
# 8   https://www.linkedin.com/in/berdikhan
# 9   https://www.linkedin.com/in/nitishkumarvaja
# 10  https://www.linkedin.com/in/wonjunjang
# 11  https://www.linkedin.com/in/sachi-sharma
# 12  https://www.linkedin.com/in/nikhilchennupati
# 13  https://www.linkedin.com/in/amrutha-srinivasan
# 14  https://www.linkedin.com/in/khe004
# 15  https://www.linkedin.com/in/sara-mulherin
# 16  https://www.linkedin.com/in/shwetasuman
# 17  https://www.linkedin.com/in/jayakrishnansomasekharannair
# 18  https://www.linkedin.com/in/jayscott082010
# 19  https://www.linkedin.com/in/john-bryan-ba19575a
# 20  https://www.linkedin.com/in/yuez1989
# 21  https://www.linkedin.com/in/shriya-sharma
# 22  https://www.linkedin.com/in/andrew-bradnan-7a04b9117
# 24  https://www.linkedin.com/in/gem-li-0018757
# 25  https://www.linkedin.com/in/artem-bolshakov-b961a6118
# 26  https://www.linkedin.com/in/dhimnsen
# 27  https://www.linkedin.com/in/sally-carlson-088b88132
# 28  https://www.linkedin.com/in/shri-deshpande
# 29  https://www.linkedin.com/in/daniel-tran-a9339333
# 30  https://www.linkedin.com/in/william-johnson-b08002116
# 31  https://www.linkedin.com/in/haodongzhang
# 32  https://www.linkedin.com/in/joseph-sackett-700262a2
#
#                                                                                                                                                                                              skills
# 0   1: Java Development, 2: Cloud Development, 3: Eclipse MicroProfile\n1: Python Programming, 2: Efficiency, 3: Problem Solving\n1: Cloud Computing, 2: Hadoop, 3: Apache Spark
# 1   1: Data management\n2: Data analysis\n3: Machine learning
# 2   1: Data analysis\n2: Data visualization\n3: Statistical modeling
# 3   1: Machine learning algorithms\n2: Data modeling\n3: Recommender systems
# 5   1: Identity Management, 2: Access Control, 3: Authentication\n1: Software Development, 2: Design Patterns, 3: Agile Methodologies\n1: Embedded Programming, 2: C Language, 3: Real-Time Systems
# 7   1: Exception handling\n2: Spring MVC framework\n3: Functional programming
# 8   1: Mobile app design\n2: WatchOS app development\n3: Xcode development
# 9   1: Finite element analysis\n2: Productivity management\n3: Injection molding design
# 10  1: Python optimization\n2: .NET UI development\n3: Java concurrency
# 11  1: Java web development\n2: Angular development\n3: Servlet development
# 12  1: Parallel programming\n2: Concurrency\n3: Java performance optimization
# 13  1: NLP model building\n2: Machine learning foundations\n3: Recommender system building
# 14  1: Java concurrency, 2: FPGA development, 3: C++ concurrency
# 15  1: Problem Solving\n2: Data Analysis\n3: Process Optimization
# 16  1: JSON data parsing, \n2: Microservice development, \n3: Servlet programming
# 17  1: Web development\n2: Data validation\n3: Java EE 8
# 18  1: Network design\n2: Network implementation\n3: Network troubleshooting
# 19  1: Data analysis, 2: Data visualization, 3: Machine learning\n1: HTML, 2: CSS, 3: JavaScript\n1: Cloud computing, 2: DevOps, 3: Software development
# 20  1: Natural Language Processing\n2: Machine Learning Development\n3: Model Registry Management
# 21  1: Software design\n2: Continuous delivery\n3: Python development
# 22  1: Data Analysis, 2: iOS App Development, 3: gRPC in Python
# 24  1: Computer repair\n2: Programming basics\n3: Embedded systems design
# 25  1: Concurrency, Synchronization, Threading\n2: Linux Kernel, System Administration, Troubleshooting\n3: Computer Architecture, Hardware Design, Low-Level Programming
# 26  1: Neural network training\n2: R programming for AI\n3: Azure Machine Learning development
# 27  1: Serverless architecture\n2: JavaScript fundamentals\n3: API integration
# 28  1: Modular Synthesis\n2: Linux Capacity Planning\n3: Synthesis ASDR Envelopes
# 29  1: Troubleshooting systems\n2: Building AI apps\n3: Linux kernel maintenance
# 30  1: Microservice Development\n2: Network Design\n3: Data Structures
# 31  1: GraphQL development\n2: Kotlin programming\n3: Java development
# 32  1: Active Directory Management\n2: Certificate Services Administration\n3: Network Infrastructure Management

# %%
#### converting to excel file to save
d1 = df1[df1['id'] != '']
df2 =df2[df2['id'] != '']

df1['skills'] = df1['skills'].str.replace('\n', ' ')
df1['skills'] = df2['skills'].str.replace('\n', ' ')

# Function to extract skills based on the number
def extract_skill(row, num):
    if pd.notna(row):
        try:
            skills = row.split(', ')
            skill = skills[num - 1].split(': ')[1].strip().replace(' 2','') if len(skills) >= num else None
        except IndexError:
            skill = None
    else:
        skill = None
    return skill

# Create new columns skill_1, skill_2, skill_3
for i in range(1, 4):
    df1[f'skill_{i}'] = df1['skills'].apply(lambda x: extract_skill(x, i))
    df2[f'skill_{i}'] = df2['skills'].apply(lambda x: extract_skill(x, i))
df1.drop(columns=['skill_1','skill_2','skill_3'],inplace=True)

print(df1.dtypes)
df1.to_excel('batch1.xlsx', index=False)
df2.to_excel('batch2.xlsx', index=False)
# Out:
# id         object
# url        object
# skills     object
# skill_1    object
# skill_2    object
# skill_3    object
# dtype: object

# %%
### when converting to excel some columns had mistakes:
skills1 = pd.read_excel('batch1.xlsx')
skills2 = pd.read_excel('batch2.xlsx')

skills_df = pd.concat([skills1, skills2])
skills_df = skills_df[skills_df['id'] != '']
skills_df['skills'] = skills_df['skills'].str.replace('\n', ' ').str.replace(',',' ')

# Define function to identify incorrect rows
def identify_incorrect_rows(row):
    count_1 = row.count('1:')
    count_2 = row.count('2:')
    count_3 = row.count('3:')
    return count_1 > 1 or count_2 > 1 or count_3 > 1

skills_df['incorrect'] = skills_df['skills'].apply(identify_incorrect_rows)
incorrect_rows = skills_df[skills_df['incorrect'] == True]
# Display DataFrame

# Define function to fix incorrect rows
def fix_incorrect_rows(row):
    # Use regular expression to extract parts starting with "1:"
    matches = re.findall(r'(1:[^\d]*?)(?=\d+:|$)', row)

    # Initialize a counter
    counter = 1

    # Iterate over matches and modify the first match to keep "1:" and change subsequent matches
    fixed_skills = []
    for match in matches:
        if counter == 1:
            fixed_skills.append(match)
        else:
            fixed_skills.append(match.replace('1:', f'{counter}:'))
        counter += 1

    return ' '.join(fixed_skills)

# Fix incorrect rows
skills_df.loc[skills_df['incorrect'], 'skills'] = skills_df.loc[skills_df['incorrect'], 'skills'].apply(fix_incorrect_rows)



# Function to extract skills
def extract_skills(row, num):
    skills = row.split(f"{num}:")
    if len(skills) > 1:
        return skills[1].split(f"{num+1}:")[0].strip()
    else:
        return None

# Create new columns for skills
for i in range(1, 4):
    skills_df[f'skill_{i}'] = skills_df['skills'].apply(lambda x: extract_skills(x, i).lower() if extract_skills(x, i) else None)
skills_df.drop(columns=['incorrect'],inplace=True)
# Display the updated DataFrame
print(skills_df)
skills_df.to_csv('skills_df.csv', index=False)

# %% [markdown]
# # Preparing Other Attributes:

# %%
df = pd.read_csv("scraping_users.csv")
df.columns

# Assuming the "courses" column contains JSON strings, parse it into dictionaries


# Assuming the "courses" column contains JSON strings, parse it into dictionaries
df['courses_title'] = df['сourses'].apply(lambda x: json.loads(x))

# Extract only the "title" from each dictionary in the "courses" column
df['courses_title'] = df['courses_title'].apply(lambda x: [item['title'] for item in x])

def extract_field(education):
    if education:  # Check if the list is not empty
        education_list = json.loads(education)
        fields = [item['field'] for item in education_list if 'field' in item]
        return fields if fields else None
    return []

# Function to extract duration_short from experience
def extract_duration_short(experience):
    if experience:  # Check if the list is not empty
        experience_list = json.loads(experience)
        durations = [item['duration_short'] for item in experience_list if 'duration_short' in item]
        return durations if durations else None
    return []

df['degree_field'] = df['education'].apply(extract_field)
print(df['degree_field'].head())
df['exp_duration']=df['experience'].apply(extract_duration_short)
print(df['exp_duration'].head())
# Create a new column 'degree' by applying the function to the 'education' column
#df['degree'] = df['education'].apply(extract_degree)

# Select only the columns 'courses_title' and 'id'
df_selected = df[['id', 'courses_title','degree_field','exp_duration']]


# Function to translate duration to months
def translate_to_months(duration):
    total_months = 0
    if duration is not None and duration != []:
        for dur in duration:
            if ("year" in dur or "years" in dur) and ("month" in dur or "months" in dur):
                # Extract years and months
                years, months = map(int, dur.split()[::2])
                total_months += years * 12 + months
            elif "less than a year" in dur:
                total_months += 6
            elif ("year" in dur) or ("years" in dur):
                # Extract years
                total_months += int(dur.split()[0]) * 12
            elif ("month" in dur) or ("months" in dur):
                # Extract months
                total_months += int(dur.split()[0])
    return total_months

# Define UDF
df_selected['exp_duration'] = df_selected['exp_duration'].apply(translate_to_months)
final_df = df_selected[['id','courses_title','degree_field','exp_duration']]
final_df['degree_field'] = final_df['degree_field'].apply(lambda x: [] if x is None else x)
# Save the selected columns to a new CSV file
final_df.to_csv('clustering_df.csv', index=False)

# %%
clustering_df = pd.read_csv('clustering_df.csv')
# Drop rows where id is empty
clustering_df = clustering_df[clustering_df['id'] != '']

# Merge DataFrames based on 'id'
merged_df = pd.merge(clustering_df, skills_df, on='id', how='inner')
merged_df.drop(columns=['skills'],inplace=True)

users = pd.read_csv('scraping_users.csv')
users = users[['id','certifications']]

# Define function to extract titles
def extract_titles(cert_list):
    try:
        if cert_list:
            if isinstance(cert_list, str):
                cert_list = json.loads(cert_list)
            return [cert['title'] for cert in cert_list]
        else:
            return []
    except Exception as e:
        print(f"Error processing row: {e}")
        return []

# Extract titles and create 'cert_titles' column
users['cert_titles'] = users['certifications'].apply(extract_titles)

users.drop(columns=['certifications'],inplace=True)

model_df = pd.merge(merged_df, users, on='id', how='inner')
model_df['skills'] = model_df.apply(lambda row: [row['skill_1'], row['skill_2'], row['skill_3']], axis=1)

# Drop the original columns 'skill_1', 'skill_2', and 'skill_3'
model_df.drop(columns=['skill_1', 'skill_2', 'skill_3'], inplace=True)

# %% [markdown]
# # Performing Clustering of Skills:

# %%
random.seed(42)
skill1 = model_df['skills'].tolist()
flat_skill1 = [item for sublist in skill1 for item in sublist]
print(len(flat_skill1))
unique_values = list(set(flat_skill1))
unique_values = [value for value in unique_values if value is not None]

vectorizer = TfidfVectorizer(max_df=0.4, min_df=2, stop_words='english', lowercase=True)
X = vectorizer.fit_transform(unique_values)

# Step 3: Clustering
num_clusters = 150  # Adjust the number of clusters as needed
kmeans = KMeans(n_clusters=num_clusters, init='k-means++', max_iter=200, n_init=20)
kmeans.fit(X)
# Step 4: Interpretation and printing clusters
cluster_labels = kmeans.labels_  # Get cluster labels for each data point

clustered_skills = [[] for _ in range(num_clusters)]
for skill, label in zip(unique_values, cluster_labels):
    clustered_skills[label].append(skill)

# Print each cluster separately
for cluster_id, skills_in_cluster in enumerate(clustered_skills):
    print(f"Cluster {cluster_id}:")
    for skill in skills_in_cluster:
        print(skill)

    print()
# Out:
# 11325
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/numpy/core/multiarray.py in where(condition, x, y)
#     344
#     345
# --> 346 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     347 def where(condition, x=None, y=None):
#     348     """
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_sparse'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/numpy/core/multiarray.py", line 346, in where
#     @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
# KeyboardInterrupt:
# Cluster 0:
# ngrx state management
# redux architecture
# redux state management
#
# Cluster 1:
# hybrid networking infrastructure
# networking fundamentals
# linux networking configuration
# networking skills
# linux networking
# azure networking design
# networking design
# networking
# networking concepts
# networking configuration
# azure networking
# cloud networking
# wireless networking
# networking  communication  job search
# enterprise networking
# storage networking
# low-power wireless networking
# cisco networking
# azure networking solutions design
#
# Cluster 2:
# accounting analysis
# semantic analysis
# ai-assisted data analysis
# fea analysis
# log analysis
# finite element analysis (fea)
# roi analysis
# construction productivity analysis
# finite element analysis
# time series analysis
# python data analysis
# rpa use case analysis
# data analysis expertise
# material analysis
# exploratory data analysis
# vulnerability analysis
# biometric analysis
# clustering  association  data analysis
# data analysis with r
# data analysis and visualization
# threat analysis
# data analysis techniques
# quality data analysis
# descriptive analysis
# nastran analysis
# pandas analysis
# wavelet analysis
# iot security analysis
# log file analysis
# simulation analysis
# excel analysis
# nlp analysis
# data analysis tools
# security monitoring and analysis
# circuit analysis
# engineering analysis
# data analysis with pandas
# cognitive analysis
# tolerance analysis
# risk analysis
# spark analysis
# numerical analysis
# analysis
# financial data analysis
# algorithmic trading  financial modeling  data analysis
# data protection analysis
# data analysis
# time-frequency analysis
# data analysis tool selection
# error analysis
# data analysis and innovation
# hadoop data analysis
# design analysis
# security analysis
# data visualization and analysis
# pricing analysis
# predictive analysis
# statistical analysis
# spatial analysis
# market analysis
# recommendation systems  data analysis  model evaluation
# cybersecurity analysis
# decision tree analysis
# wavelet analysis methods
# financial analysis
# geospatial analysis
#
# Cluster 3:
# model development
# verilog for fpga development
# serverless development
# cli development
# quarkus development
# ios 17 development
# game development
# aws deeplens development
# swiftui development
# tkinter development
# ethereum development
# go development
# typescript development
# agile development
# jsf component development
# postgresql client development
# power apps development
# scrum development
# webpack development
# firebase app development
# jakarta ee servlet development
# aws cloud development
# servlet development
# watchos app development
# aws development
# apple tvos development
# swift app development
# fpga development with verilog
# iphone app development
# blazor ui development
# ajax development
# desktop app development
# angular development
# javaserver faces development
# ui development
# elt development
# apollo development
# android app development
# agile development methodologies
# hotwire development
# collaborative development
# ios development
# blazor development
# 2d game development
# recommender system development
# unity game development
# sharepoint development
# driver development
# workforce development
# responsive development
# iot development
# cli app development
# verilog development
# etl development
# spa development
# ar development
# metaverse development
# eclipse development
# php development
# logic app development
# websocket development
# aws lambda development
# ios 17 app development
# jsf development
# xcode development
# xcode development environment
# employee development
# tvos development
# apple tv app development
# python development
# gans development
# lambda function development
# chatbot development
# website development
# microprofile development
# smart contract development
# app development
# fpga development
# graphql development
# swift development
# gwt development
# playbook development
# real-time app development
# recommendation engine development
# json-b development
# graphical user interface development
# c++ development
# linux driver development
# tensorflow development
# unity development
# android development
# ios app development
# game engine development
# apple tvos app development
# cloud development
# ride-sharing app development
# augmented reality development
# jupyter  pycharm  python development
#
# Cluster 4:
# endpoint security design
# data security
# cloud security strategy
# cloud security
# data analytics security
# container security
# it security auditing
# saas security
# kubernetes security
# security operations management
# data security design
# google cloud security management
# implement security
# system security
# iot security
# saas security management
# security audit
# security risk assessment
# information security risk management
# endpoint security
# laptop security management
# android security
# spring security
# security vulnerability assessment
# security policy development
# cloud security operations
# open source security
# cloud security design
# security auditing
# cloud security tools
# security incident response
# systems security
# web security
# it security management
# security operations
# asset security
# cloud security engineering
# security governance
# security engineering
# information security auditing
# security management
# aws security governance
# cloud security management
# python security
# security
# security assessment
# security protocols
# cloud security auditing
# security design
# web security protocols
# security monitoring
#
# Cluster 5:
# dependabot dependency management
# git operations management
# crm management
# supply chain management
# calendar management
# gradle build management
# ci/cd pipeline management
# patch management
# hadoop management
# website content management
# icloud management
# lean management
# safety management
# bug management
# thread management
# dns/dhcp management
# bim management
# remote log management
# external library management
# identity management
# accounts payable management
# stress management
# servlet lifecycle management
# container management
# certificate management
# autocad civil 3d management
# disability management
# vmware vsphere 7 drs management
# time management
# domain management
# risk management
# classroom management
# environmental management
# operations management
# gitops management
# iot os management
# submittals management
# technical debt management
# websocket management
# lean six sigma management
# group policy management
# asset management
# energy management
# it service management
# dependency management
# microsoft 365 management
# human resources management
# credit management
# lifecycle management
# exception management
# workflow management
# stakeholder management
# openshift management
# package management
# unified communications management
# wordpress management
# accounts receivable management
# elasticsearch management
# incident management
# apache airflow management
# dns management
# vault management
# cloud management
# construction document management
# cybersecurity risk management
# user management
# domain name system management
# facility management
# firewall management
# pressure management
# upward management
# productivity management
# communications management
# aws management
# it risk management
# task management
# kubernetes management
# collaboration management
# change management
# heat stress management
# vm management
# os management
# desktop management
# multicloud management
# kanban management
# community management
# access management
# model management
# construction management
# imposter syndrome management
# multithreading management
# private cloud management
# hadoop cluster management
# cloud service management
# autocad  space management  facilities management
# account management
# inventory management
# file management
# disk management
# hybrid cloud management
# memory management
# autocad mep & civil 3d management
# financial management
# cloud cost management
# system management
# kubernetes cluster management
# nuget package management
# library management
# watch management
# time management strategies
# logistics management
# campaign management
# bim 360 management
# modern management
# autocad mep management
# supplier relationship management
# identity and access management
# endpoint management
# switch management
# voip management
# agile management
# sdlc management
# cloud hadoop management
# service level management
# content management
# vulnerability management
# dhcp management
# queue management
#
# Cluster 6:
# devops practices
# devops principles
# devops security planning
# devops implementation
# devops pipeline
# devops concepts
# devops design
# azure devops
# devops automation
# cloud devops process
# devops tools
# devops architecture
# devops basics
# devops management
# devops testing
# devops fundamentals
# design and implement devops pipelines
# azure devops fundamentals
# aws devops
# devops
#
# Cluster 7:
# protect data
# data interpretation
# data preparation
# data pipeline management
# data streaming
# data parallelism
# data wrangling
# data management
# serverless data processing
# data quality
# data strategy development
# aws data management
# data processing
# data normalization
# data pipeline design
# data storytelling
# data acquisition
# data querying
# nosql data management
# parse json data
# cloud data management
# data annotation
# data visualization
# data preparation and processing
# data strategy
# algebraic data types
# data serialization
# data cleaning
# data exploration
# querying data
# create data visualizations
# data validation
# healthcare data protection
# encode data
# data loading
# real-time data streaming
# hadoop data processing
# data stewardship
# data analytics
# serializing data
# query data
# data backup
# data translation for aec
# data labeling
# data engineering
# analyze data accurately
# data pipeline engineering
# data structuring
# data mining in r
# data preprocessing
# data governance
# data extraction
# web data extraction
# data clustering
# data mining
# data warehousing
# data innovation
# data organization
# batch data engineering
# quantile and box-whisker plots in the wolfram language: data analysis  statistical visualization  data interpretation
# data binding
# acquire  prep  eda python data
# data generation
# delegation and data source management
# python data acquisition
# data pipelines
# data acquisition and exploration
# analyze data
# data protection
#
# Cluster 8:
# code reusability
# code sharing
# testing and code quality
# code quality assurance
# code testing
# debugging php code
# code analysis
# debug c code
# code linting
# code collaboration
# code debugging
# code reviewing
# debug code
# code architecture
# code comprehension
# code management
# debugging c code
# code quality
# write concurrent code
# debugging vue.js code
# debugging code
# code protection
# optimizing code
# no-code development
# code coverage
# error code diagnosis
# optimizing python code
# c code debugging
# g-code programming
# code bundling
# using visual studio code
# linting code
# code review techniques
# code efficiently
# code security
#
# Cluster 9:
# machine learning operations
# machine learning fundamentals
# machine learning models
# machine learning foundations
# machine learning engineering
# building scalable machine learning models
# machine operation
# machine learning model building
# machine learning model selection
# data analysis  machine learning  predictive modeling
# machine learning basics
# machine learning integration
# machine learning development
# cloud-based machine learning
# core ml machine learning
# machine learning algorithms
# machine learning model deployment
# machine learning deployment
# machine learning model engineering
# calculus for machine learning
# azure machine learning
# machine learning techniques
# nlp for machine learning
# machine learning problem framing
# python machine learning
# machine learning modeling
# machine learning  ai  recommender systems
# machine learning concepts
# machine learning for recommendations
# machine learning model development
# machine learning
# machine learning with spark
# data preparation  processing systems  machine learning
# machine learning valuation
#
# Cluster 10:
# creational design patterns
# c++ design patterns
# design patterns
# concurrency patterns
# behavioral design patterns
# design patterns implementation
# c# design patterns
# applying design patterns
# behavioral patterns
# fingerpicking patterns
#
# Cluster 11:
# manage virtual machines
# manage servers
# manage change effectively
# manage windows devices
# manage stress
# manage workloads
# manage dhcp
# manage operations
# manage supply chains
# manage construction activities
# manage data pipelines
# manage applications
# manage engineering teams
# manage hybrid environments
# manage users
# manage cloud finances
# manage code dependencies
#
# Cluster 12:
# sql queries
# sql development
# data analysis with sql
# spark sql querying
# sql programming
# sql analysis
# sql
# pl/sql programming
# sql data analysis
# ai and sql
# sql query optimization
# advanced sql querying
# sql basics
# sql querying
# sql optimization
# pl/sql development
# sql injection prevention
# data analytics with sql
#
# Cluster 13:
# manual testing techniques
# manual testing
#
# Cluster 14:
# sap integration
# signalr integration
# css integration
# icloud integration
# data integration
# cypress integration
# web page design  user interface  database integration
# kinesis integration
# firebase integration
# database integration
# library integration
# troubleshooting cloud integration
# retrofit integration
# python database integration
# ai integration
# enterprise app integration
# appium integration
# vue.js/laravel integration
# shared economy integration
# graphql integration
# continuous integration and deployment
# integration testing
# core ml integration
# continuous integration
# socket.io integration
# web service integration
# troubleshoot cloud integration
# azure integration
# cam integration
# cloud integration
#
# Cluster 15:
# kernel configuration
# linux kernel optimization
# linux kernel
# linux kernel configuration
# linux kernel development
# semantic kernel analysis
# kernel programming
# linux kernel management
# semantic kernel building
# kernel optimization
# kernel tuning
# semantic kernel development
# kernel logging
# kernel management
# linux kernel administration
# linux kernel tuning
# kernel module development
# kernel development
# kernel building
# linux kernel programming
#
# Cluster 16:
# html and css coding
# html coding fundamentals
# coding
# efficient coding
# html coding
# verilog hdl coding
# python coding
# secure coding
# hdl coding
# verilog coding
# quick coding
# xaml coding
# high-performance coding
# matlab coding
# html/css coding
# coding in python
#
# Cluster 17:
# building ai-based apps
# edge ai development
# ai modeling
# train generative ai models
# ai model building
# copiloting with ai
# building apps with ai tools
# ai tool application
# ai in finance
# ai development without coding
# ai strategy development
# ai-based app building
# ai programming
# ai foundations
# ai principles
# ai ethics
# ai app development
# ai principles  model building  data visualization
# ai-assisted coding
# ai techniques
# ai model training
# ai technology
# ai tool integration
# ai game development
# ai utilization
# ai algorithms
# ai development
# generative ai strategy
# ai strategy
# ai for iot
# ai tool usage
# cloud-based ai development
# generative ai
# ai fundamentals
# ai analysis
#
# Cluster 18:
# beam modeling
# parametric modeling
# building information modeling (bim)
# simulation modeling
# mathematical modeling
# predictive modeling
# stochastic modeling
# graph data modeling
# modeling techniques
# building information modeling
# advanced modeling techniques
# financial modeling
# classification modeling
# decision tree modeling
# modeling market prices using stochastic processes with wolfram language: stochastic modeling  financial analysis  data visualization
# 3d printing modeling
# data modeling
# solidworks modeling
# threat modeling
# shell modeling
# bim modeling
# inventor modeling
# advanced modeling
# domain modeling
# business modeling
# page object modeling
# cnc topographic site modeling
# statistical modeling
# polymer modeling
# stochastic process modeling
# building site modeling
# 3d modeling
# modeling data
# nlp modeling
# rhinocam modeling
# advanced 3d modeling
# automl modeling
# cassandra data modeling
#
# Cluster 19:
# threading and dispatch
# threading  synchronization  concurrency
# concurrency  synchronization  threading
# threading skills
# threading and grand central dispatch
# threading
# ios threading
# threading concepts
# threading techniques
# threading and concurrency
# threading and concurrency in android
#
# Cluster 20:
# microservices security
# microservices architecture
# azure microservices development
# java microservices development
# communicate with microservices
# java microservices
# dockerizing microservices
# graalvm microservices
# microservices
# developing microservices
# create microservices
# microservices deployment
# microservices development
# kubernetes microservices deployment
# creating microservices
# develop microservices
# cloud microservices development
# deploy microservices
# microservices design
# deploying microservices
#
# Cluster 21:
# office 365 proficiency
# gis software proficiency
# revit software proficiency
# php proficiency
# command-line proficiency
# solidworks proficiency
# github proficiency
# microsoft word proficiency
# software proficiency
# tableau proficiency
# powerpoint proficiency
# autocad proficiency
# python coding proficiency
# javascript proficiency
# mern stack proficiency
# coding proficiency
# microsoft office proficiency
# revit proficiency
# xcode proficiency
# reason software proficiency
# sql proficiency
# visual studio proficiency
# multithreading proficiency
# excel proficiency
# pcb design software proficiency
#
# Cluster 22:
# troubleshooting hardware
# develop fpga hardware
# hardware interfacing
# hardware maintenance
# hardware architecture understanding
# install hardware
# hardware troubleshooting
# hardware troubleshooting  component identification  system assembly
# hardware installation
# computer hardware troubleshooting
# repair hardware
# hardware design
# hardware diagnostics
# troubleshoot hardware
# computer hardware knowledge
# understanding computer hardware
# troubleshooting hardware and software
# computer hardware installation
# hardware programming
# hardware description language
#
# Cluster 23:
# stream data processing
# kafka stream processing
# lambda expressions  stream processing
# advanced java stream processing
# stream processing
# java stream processing
# lambda and stream operations
#
# Cluster 24:
# internal communication
# communication skills
# business communication
# stakeholder communication
# communication improvement
# cross-cultural communication
# communication
# time management  teamwork  communication
# communication security
# websocket communication
# effective communication
# real-time communication
# lean communication
# mindfulness in communication
# communication effectiveness
# influence and communication
# thread communication
# prioritization  planning  communication
# network communication
# assertive communication
# interpersonal communication
# socket communication
# grpc communication
# executive communication
# assertiveness and communication
# clear communication
#
# Cluster 25:
# eurorack modular synthesis
# synthesis fundamentals
# modular synthesis
# modular synthesis techniques
# eurorack synthesis
# analog synthesis
# asdr envelope synthesis
# advanced audio synthesis techniques
# audio synthesis techniques
# audio synthesis
# synthesis techniques
# sound synthesis
# understanding audio synthesis
# envelope synthesis
# modular synthesis fundamentals
# audio synthesis skills
# digital synthesis techniques
# audio synthesis fundamentals
#
# Cluster 26:
# problem-solving
# solving coding challenges
# creative problem-solving
# coding problem solving
# problem solving
# numerical problem-solving
# problem-solving skills
# java programming  object-oriented programming  problem-solving
# business problem solving
#
# Cluster 27:
# build asp.net core apps
# .net maui development
# asp.net development
# .net core development
# asp.net core
# asp.net core development
# asp.net deployment
# asp.net web development
# advanced .net programming
# .net core programming
# .net commands
# .net core fundamentals
# asp.net fundamentals
# .net development
# .net programming
# asp.net mvc development
# asp.net core fundamentals
# react and asp.net mvc development
# asp.net mvc 5 development
# .net library usage
# angular and asp.net development
# .net core basics
# asp.net web api development
#
# Cluster 28:
# restful web services
# creating web services
# web services
# soap web services
# web services management
# building restful web services
# web services development
#
# Cluster 29:
# graphic design principles
# object-oriented design principles
# six sigma principles
# site reliability engineering principles
# game design principles
# minimalist design principles
# accounting principles
# design principles
# lean principles
# software development principles
# software architecture principles
# pcb design principles
# implement lean principles
# software design principles
# web development principles
# gd&t principles
# motivation principles
# solid principles
# agile principles
# fpga design principles
# ux principles for non-designers
# construction estimating principles
# it architecture principles
# lean construction principles
# web design principles
# data engineering principles
# responsive web design principles
# ux design principles
#
# Cluster 30:
# setting up spring boot
# securing spring boot apps
# spring boot fundamentals
# tdd with spring boot
# dockerizing spring boot microservices
# spring boot essentials
# spring boot
# spring 6 and boot 3
# building microservices with spring boot
# spring boot application development
# spring boot development
# build restful apis with spring boot
# spring boot microservice creation
# securing spring boot microservices
# deploying spring boot apps
# spring boot deployment
# spring mvc
# writing kotlin spring boot apps
# spring boot microservices development
# spring boot microservices
# spring boot framework
# spring boot configuration
#
# Cluster 31:
# react application creation
#
# Cluster 32:
# leadership and adaptation
# servant leadership principles
# data leadership
# leadership branding
# global leadership
# leadership  change management  anti-racism
# situational leadership
# leadership development
# remote leadership
# leadership missteps avoidance
# ceo leadership
# motivational leadership
# collaboration  communication  leadership
# lean six sigma leadership
# sales leadership
# leadership strategy
# leadership principles
# ai leadership
# leadership communication
# engineering leadership
# hr leadership
# leadership skills
# cloud leadership
# technology leadership
# project leadership
# leadership
# leadership techniques
#
# Cluster 33:
# routing protocol management
# rip and eigrp routing
# advanced routing protocols
# routing
# bgp routing
# routing protocols
# routing configuration
# ip routing
# ospf routing
# vmware nsx-t routing
# rip routing
# switching and routing
# network routing
# eigrp routing
# ipv6 addressing and routing
# rails routing
# advanced routing
# routing and switching
# advanced ip routing
# routing protocol configuration
# layer 3 routing
# routing and switching configuration
# modulation routing
# cisco routing protocols
#
# Cluster 34:
# test planning and execution
# cucumber test automation
# test automation with python
# test failure analysis
# test case creation
# test reporting
# python test automation
# python programming for test automation
# soapui test automation
# c# test-driven development
# test automation
# test strategy development
# test-driven development
# test automation frameworks
# test case design
# test framework
# test case management
# test creation
# test execution
# python test design
# test management
# test planning
# test driven development
# test design
# test plan development
#
# Cluster 35:
# ruby installation
# installing ruby on rails
# web development  ruby on rails  mvc architecture
# hotwire  ruby on rails
# full-stack web development with ruby on rails
# ruby on rails debugging
# ruby on rails routing
# ruby on rails development
# ruby on rails web development
# ruby on rails controllers and views
# ruby on rails installation
# rails programming
# rails development
# debugging ruby on rails
# ruby on rails
# ruby on rails 7
#
# Cluster 36:
# circuitry skills
# prototyping skills
# management skills
# presentation skills
# troubleshooting skills
# business analysis skills
# facilitation skills
# teamwork skills
# influencing skills
# negotiation skills
# coaching skills
# advocacy skills
# influence skills
# maintenance skills
# workshop skills
# sap fiori end-user skills
# microsoft office skills
# c# interview skills
# aws development skills
# technology skills
# data analysis skills
# salesforce skills
# programming skills
#
# Cluster 37:
# aws deeplens basics
# filmmaking basics
# intellij basics
# git and github basics
# coffeescript basics
# python basics
# html basics
# python programming basics
# css basics
# electronics basics
# java programming basics
# data management basics
# scala basics
# linux basics
# notion basics
# go programming basics
# coding basics
# composition basics
# numpy basics
# photography basics
# web design basics
# cloud security basics
# javascript basics
# visual studio basics
# java basics
# programming basics
# cybersecurity basics
#
# Cluster 38:
# deploy django apps
# django framework utilization
# django deployment
# django development
# deploying django apps
#
# Cluster 39:
# windows server administration
# sql server administration
# windows server security
# tomcat server administration
# server administration  security  troubleshooting
# server security
# sql server database administration
# server administration
#
# Cluster 40:
# iot operating system fundamentals
# troubleshooting operating system issues
# operating system concepts
# operating system fundamentals
# iot operating systems
# operating system troubleshooting
# troubleshooting operating systems
# operating system management
# operating system optimization
# operating systems fundamentals
# operating system basics
# operating system installation
#
# Cluster 41:
# language generation
# c# language enhancements
# language transition
# language conversion
# natural language processing
# language modeling
# language understanding
# natural language understanding
# c language basics
# large language model training
#
# Cluster 42:
# azure virtual desktop configuration
# virtual presentation
# virtual instrumentation
# virtual machine creation
# virtual assistant
# virtual meeting facilitation
# virtual audience engagement
# aws virtual machine migration
# virtual machine management
# virtual desktop administration
# java virtual machine optimization
# virtual instrument creation
# virtual environment management
# virtual hiring
# virtual network management
#
# Cluster 43:
# concurrency in go
# c++ concurrency
# multithreading and concurrency
# multithreading  concurrency  synchronization
# concurrency  parallelism  scalability
# concurrency and parallelism in java
# java concurrency
# concurrency and parallelism
# concurrency management
# concurrency  synchronization  parallelism
# android concurrency
# go concurrency
# multithreading  concurrency  performance
# concurrency
# concurrency programming
# handle concurrency
# go concurrency and high-performance
# concurrency and multithreading
# concurrency  synchronization  performance
# concurrency  parallelism  synchronization
# concurrency control
# concurrency  synchronization  memory management
# concurrency principles
# java concurrency and parallelism
#
# Cluster 44:
# project planning
# project management skills
# hybrid project management
# github project management
# project workflow management
# project resource management
# rust project management
# react project building
# python project management
# agile project management
# project scheduling
# project management foundations
# project management
# international project management
#
# Cluster 45:
# ui programming
# ios programming
# programming
# perl programming
# parallel programming
# programming in php
# cam programming
# c++ programming
# websocket programming
# multithreading programming
# programming in c++
# spark programming
# recursive programming
# typescript programming
# event-driven programming
# python parallel programming
# c programming
# xaml programming
# fpga programming
# linq programming
# c# attribute programming
# scala programming
# object-oriented programming
# sas programming
# labview programming
# programming logic
# php programming
# efficient programming
# r programming
# task-based programming
# swift programming
# servlet programming
# tokio async programming
# micropython programming
# multithreaded programming
# thread programming
# reactive programming
# plc programming
# microcontroller programming
# c# programming
# aws lambda programming
# ruby programming
# gpio programming
# asynchronous programming
# basic programming
# go programming
# coffeescript programming
# abap programming
# matlab programming
# template programming
# c++ template programming
# python programming
# apache spark programming
# stl programming
# circuitpython programming
# python concurrent programming
# android concurrent programming
# cnc programming
# efficient python programming
# logic programming
# ladder logic programming
# async programming
# f# programming
# tkinter programming
# python programming  multithreading  multiprocessing
# android programming
# socket programming
# openflow programming
# hadoop programming
# system programming
# java object-oriented programming
# xcode programming
# pythonic programming
# attribute-based programming
# risc-v programming
# attribute programming
# concurrent programming
# advanced c programming
# arduino programming
# verilog programming
# sap programming
# elixir programming
# vhdl programming
#
# Cluster 46:
# eclipse ide
# java ide usage
# ide proficiency
# java ide
# java ide overview
# ide navigation
# ide usage
# c++ ide
# eclipse ide proficiency
#
# Cluster 47:
# resource planning
# azure resource management
# resource allocation
# cloud resource planning
# resource management
# cloud resource management
# enterprise resource planning
#
# Cluster 48:
# jsf 2.3 framework
# scrum framework
# angular framework
# spring framework
# .net framework
# integrate with entity framework core
# sharepoint framework development
# security framework understanding
# robot framework automation
# robot framework
# framework selection
# spring framework fundamentals
# developing sharepoint framework
# spring framework development
# agile scrum framework
# flask framework
# sharepoint framework understanding
# using testng framework
# spring framework mastery
# sharepoint framework
# rails web framework
# spring mvc framework
# testng framework
# entity framework core
# robot framework testing
# rails framework
# spring framework knowledge
#
# Cluster 49:
# java array manipulation
# matrix manipulation
# envelope manipulation
# data manipulation
# string manipulation
# object manipulation
# binary manipulation
# jquery dom manipulation
# json manipulation
# xml data manipulation
# javascript object manipulation
# css manipulation
# xml manipulation
# pandas data manipulation
# php data manipulation
# array manipulation
# audio manipulation
# image manipulation
# image manipulation with tensorflow
# sound envelope manipulation
# data manipulation  sql  spark
# dom manipulation
#
# Cluster 50:
# exception handling  debugging  error management
# debugging scripts
# debugging c programs
# c debugging
# kernel debugging
# rails debugging
# debugging logic
# debugging techniques
# javascript debugging
# debugging skills
# debugging software
# memory debugging
# c# debugging
# php debugging
# debugging
# testing and debugging
# c debugging techniques
# debugging applications
# debugging ruby
# java debugging
# c programming debugging
# javascript debugging techniques
# debugging javascript
# debugging web applications
#
# Cluster 51:
# predictive analytics
# querying databases
# mvc frameworks
# svg rollovers
# boundary setting
# advanced simulation
# angular
# configure vsphere 7
# using lombok
# promote sustainability
# rpm distribution
# messaging with jms
# productivity
# self-reliance
# it support
# eclipse navigation
# additive manufacturing
# coffeescript
# computational fluid dynamics
# logical reasoning
# tensorflow and pytorch
# testng
# etl
# concept mapping
# github collaboration
# photoshop rendering
# ssh tunneling
# plc sequencing
# linkedin advertising
# bug reporting
# risk reporting
# css box model
# reality capture
# apache installation
# lead lean six sigma programs
# object tracking
# aws deeplens
# cloud operations
# nlp pipeline construction
# pitch effectively
# use webpack
# git operations
# write compelling copy
# ci/cd
# working with go standard library
# html
# image recognition
# cloud library usage
# lean six sigma tools
# apollo navigation
# elasticsearch querying
# computational thinking
# robot interfacing
# cloud scaling
# upskilling and reskilling
# engineering calculations
# value estimation
# nlp with python
# meeting facilitation
# material selection
# lambda expressions
# json-b
# nlp with pytorch
# create electronic music
# unity game engine
# http request processing
# pcb layout
# mlops essentials
# css variables
# write shell scripts
# system maintenance
# system logging
# analyze c library functionality
# market to healthcare industry
# mindfulness
# watch operation
# asynchronous programming  event loop  promises
# c decision-making and looping
# dynamic content
# troubleshoot windows 11
# css layout
# lead with credibility
# scripting
# k-means clustering
# cybersecurity risk assessment
# vision processing
# python generators
# cloud collaboration
# xcode essentials
# package apps
# tool selection
# command-line interface
# validation
# authentication
# continuous delivery
# synchronization strategies
# xcode usage
# exception handling
# using ci tools
# creating pivot tables
# css styling
# xml querying
# electrical schematics
# cam operations
# git workflow
# synchronization
# vulnerability detection
# css display
# cybersecurity threat detection
# cultural sensitivity
# vulnerability assessment
# parsing protobuf messages
# asking questions
# demand forecasting
# campaign personalization
# ip subnetting
# python efficiency
# public speaking confidence
# fp with f# and c#
# clustering algorithms
# creating responsive websites
# rigging
# dast execution
# nosql databases
# nosql querying
# analyze wavelets
# high availability
# facial recognition
# numerical calculations
# electronic music composition
# regex pattern matching
# github navigation
# collaboration tools
# sketching
# financial accounting
# semiconductor physics
# fp in python
# websocket communications
# candidate screening  interviewing  sourcing
# designing and managing cloud architectures
# xml/json parsing
# request handling
# monitoring and metrics
# deploy faster
# source control
# analog interfacing
# template metaprogramming
# talent acquisition
# working with php and mysql
# aws lambda
# loop control
# e-commerce
# audio effects
# configure firewalls
# visual studio navigation
# ip connectivity
# kubernetes provisioning
# candidate sourcing
# sdks
# add dynamic content
# audio filtering
# financial record-keeping
# cost estimating
# time-lapse photography
# lazy evaluation
# property damage assessment
# factory simulation
# laser cutting
# change impact assessment
# revit worksharing
# configure webpack
# budgeting
# autocad annotation
# self-belief and entrepreneurship
# ci/cd pipelines
# mac support
# integrate graphql with spring
# cloud recruiting
# influence senior colleagues
# idea generation
# aws serverless
# influence and persuasion
# play mandolin
# drawing annotation
# heat stress prevention
# attribute handling
# document formatting
# solidworks cam
# c library usage
# 3d graphics rendering
# work organization
# cloud provisioning
# develop self-awareness
# object detection
# nlp with tensorflow
# implement authentication
# computer vision algorithms
# coaching challenge resolution
# containerization
# implement algorithms
# scrum methodologies
# json processing
# json parsing
# regular expression matching
# analog circuit interfacing
# self-belief
# thread synchronization
# edit ebooks
# macos installation
# interfacing electronics
# jetpack library usage
# webpack
# site reliability
# conflict resolution
# collaboration app setup
# serialization
# message brokering
# ar visualization
# communicating over rpc
# circuit interfacing
# emerging technology awareness
# signalr scaling
# user support
# core ml
# c# interviewing
# service-level agreements
# monitor servers
# forecasting with analytics
# merge conflict resolution
# matrix operations
# linq queries
# switching
# semiconductor fabrication
# stakeholder engagement
# jsp template processing
# reading mechanical drawings
# lombok annotations
# unlearn silence
# environmental stewardship
# deploy serverless architectures
# bias mitigation
# incident handling
# developing python guis
# go protocol buffer
# algorithmic thinking
# docker containerization
# schematic capture
# workflow mobilization
# protocol buffers
# automate tasks
# apache spark scaling
# guitar scales
# spark scaling
# xaml content
# sending messages
# photo organization
# intellij idea usage
# visual basic
# grand central dispatch
# bookkeeping
# gd&t
# feature engineering
# authentication and authorization
# recursion
# facial feature extraction
# mechanical  electrical  plumbing
# extension methods
# interview preparation
# requirements gathering
# brainstorming
# goal setting
# iphone and ipad essentials
# sound shaping
# github usage
# facial retouching
# jvm knowledge
# photography
# figma prototyping
# strategic thinking
# threat detection
# wan technologies
# form validation
# parallel processing
# use c++ with web servers and apis
# image segmentation
# linux command line
# producing a film
# sap bi/bw knowledge
# uncovering unconscious bias
# six sigma methodologies
# json binding
# image processing with openai
# dolby atmos mixing
# working with apis
# exploit vulnerabilities
# photography exposure
# public policy
# git version control
# powershell scripting
# sap navigation
# write unit tests
# model training
# recommendation algorithms
# swiftui
# ipv6 addressing
# model selection
# transformer models
# configure hyper-v
# critical thinking
# vpn technologies
# css variable usage
# perseverance
# cloud decision-making
# multithreading
# focus
# signal decomposition
# travel efficiency
# control flow
# creative thinking
# insider threat mitigation
# recognize hazards
# laser scanning
# container orchestration
# subnetting
# report generation
# cryptography
# hiring for cloud
# hadoop ecosystem
# file conversion
# remote desktop support
# switch statements
# iot ecosystem understanding
# tree traversal
# gans and diffusion models
# synthesize audio and sound
# enhanced concentration
# sourcing candidates
# file navigation
# lead generation
# regular expression mastery
# milling  lathe operation
# forecasting
# asdr envelopes
# secure devices
# distributed systems
# python
# supervised learning algorithms
# site reliability engineering
# communicate with websockets
# composite fabrication
# synthesizer envelope modulation
# maya
# build dynamic websites
# sight reading
# modular synthesizer setup
# use selinux
# cnc operation
# plc simulation
# os installation
# styling a table
# openshift container orchestration
# defect reporting
# foster inclusivity
# organizational alignment
# video conferencing
# self-confidence
# managing change
# storytelling
# event handling
# sensor interfacing
# scrum methodology
# self-discovery
# faster pandas
# recommendation systems
# hyperparameter tuning
# asynchronous programming  event-driven architecture  concurrency
# 3d graphics
# values alignment
# intellij idea
# linq for xml
# synthesizing asdr envelopes
# alias workflow
# information asset protection
# disability awareness
# creating python generators
# error avoidance
# bean validation
# camera operation
# layer 3 switching
# solution mapping
# cyber threat detection
# mental fortitude
# decision making
# command line navigation
# patching modular synthesizers
# 3d tracking
# staffing strategies
# ux prototyping
# visualization
# create ar experiences
# materials selection
# numerical computation
# apply continuous improvement
# eurorack patching
# configure dns
# git collaboration
# protocol buffer usage
# car physics simulation
# electronics soldering
# profiling tools
# sap erp navigation
# blood-borne pathogen safety
# event streaming
# regular expressions
# roi calculation
# online learning
# word processing
# pulse width modulation
# go protocol buffers
# css display properties
# requirements elicitation
# habit formation
# higher-order functions
# version control
# cloud governance tools
# agile methodologies  jira cloud
# switch statement logic
# incident response
# pattern recognition
# vocal control
# mentor junior managers
# accessibility standards
# package installation
# geometric dimensioning
# six sigma
# vulnerability scanning
# effective collaboration
# research methods
# image processing with tensorflow
# wordpress localization
# focus and concentration
# font selection and organization
# lead nurturing
# dependency injection
# modular patching
# iot foundations
# nlp workloads
# webpack usage
# clustering
# advanced modelling
# audio mixing
# sustainability knowledge
# developing fpga with verilog
# numerical operations with numpy
# cloud scalability
# github for job seeking
# it governance
# fashion illustration
# android multithreading
# continuous improvement
# css animations
# xcode interface
# recommender systems
# sustainability reporting
# agile methodology
# graphql
# troubleshoot os
# generator functions
# python serialization
# exam preparation
# construction estimating
# manufacturing processes
# fostering diversity
# camera mounting
# sheet metal fabrication
# verilog for fpga
# workplace inclusivity
# argumentation
# python recursion
# advanced apis
# video streaming
# algorithms
# ip addressing
# incident handling procedures
# envelope shaping
# decision-making
# identify threats
# metalworking knowledge
# quality assurance
# produce engaging online content
# sap fiori knowledge
# autodesk inventor
# differential calculus
# access control
# audio engineering
# eurorack expansion
# sd-wan foundations
# engineering thinking
# sap fiori navigation
# blueprint reading  schematic interpretation  design
# collaboration facilitation
# ethical hacking
# querying
# public speaking
# develop fpgas
# tuple handling
# mistake avoidance
# accounting cycle
# rest apis
# plc input sensing
# select appropriate databases
# raspberry pi computer vision
# conditional statements
# unified communications
# recommendation
# coping with stress
# json handling
# watch customization
# c++ template metaprogramming
# raspberry pi setup
# electronic prototyping
# user research
# lambda expression
# esg reporting
# bootstrap template customization
# model market prices
# write correctly
# jsf
# goal achievement
# object recognition
# http request handling
# augmented reality
# backward thinking
# arduino prototyping
# interfacing with analog devices
# testng assertions
# calling apis
# apple watch usage
# revit mep expertise
# json mapping
# senior influence
# prototyping
# time series forecasting
# camera settings
# dimensioning and tolerancing
# visual studio
# python scripting
# prototyping in figma
# go library knowledge
# electronics prototyping
# crud operations
# kubernetes cluster provisioning
# model evaluation
# accounts receivable
# reporting
# voice over ip
# agile methodologies
# linq
# use teradata vantage
# ci tools
# github mastery
# leading teams
# webinar hosting
# connectivity
# brand storytelling
# servlets
# quality control
# risk assessment
# xaml markup
# computer maintenance
# supervised learning
# numpy capabilities
# toolchain understanding
# protocol buffer
# cloud service selection
# augmented generation (rag)
# mandolin playing
# cybersecurity awareness
# reading comprehension
# visual studio interface
# eclipse usage
# intellij idea essentials
# go for python developers
# feedback delivery
# generating ideas
# managing github projects
# recommender system algorithms
# xcode navigation
# 3d printing
# vba
# c++ templates
# generative adversarial networks
# signal flow understanding
# xml parsing
# financial literacy
# jupyter vs. pycharm
# automl
# collaboration
# configuring cisco routers and switches
# looping
# linear algebra
# image processing
# websockets
# cloud innovation
# signal processing
# trauma-informed care
# modulation effects
# programmatic advertising
# photo sharing
# music sequencing
# use github for job search
# analytics
# tech recruiting
# apache kafka
# apache spark
# tableau visualization
# python interview preparation
# configure cisco equipment
# mechanics
# attribute usage
# use postman
# aws load balancing
# authorization
# 3d printing materials
# artificial intelligence
# microsoft office
# electrical panel installation
# visual prototyping
# mindset
# influencing and persuasion
# aws high availability
# troubleshoot cisco ios
# kubernetes orchestration
# apple watch expertise
# wan connectivity
# developing ethereum smart contracts
# defect tracking
# kafka message brokering
# enhance c#
# assertiveness
# accounts payable processing
# html markup
# biometric authentication
# designing and implementing wans
# call control
# etl pipelines
# decision making in c
# architect cloud solutions
# identify root causes
# pc maintenance
# financial reporting
# spark processing
# ios navigation
# image classification
# financial forecasting
# information organization
# module bundling
# engineering mindset
# analytics engineering
# nlp foundation
# dockerization
# c# enhancements
# additive manufacturing materials
# spreadsheet functions
# algorithmic trading
# gans
# basic computer operations
# threat mitigation
# recursive thinking
# query nosql databases
# pattern matching
# load balancing
# sap ariba supply chain collaboration
# audience segmentation
# mental health awareness
# computer vision
# manufacturing validation
# hadoop  spark  analytics
# singleton pattern
# using junit
# music notation
# parallelism
# linkedin recruiting
# remote recruiting
# accessibility advocacy
# lambda functions
# calculus
# cinema 4d
# remote collaboration
# kubernetes
# kanban methodology
# procurement
# simulation
# market research
# teamwork
# industry knowledge
# error handling
# javaserver faces jsf programming
# json-b serialization
# excel statistics
# community engagement
# bash shell scripting
#
# Cluster 52:
# process optimization
# development process management
# process analysis
# sales process management
# statistical process control
# process improvement
# business process analysis
# process automation
# sales process automation
# sales process optimization
#
# Cluster 53:
# cloud storage
# manage virtual storage
# storage configuration
# san storage management
# linux storage administration
# data storage optimization
# configure storage policies
# data storage
# cloud data storage
# linux storage device management
# iscsi storage area network management
# storage management
# data storage management
# design data storage solutions
# nas storage management
# virtual storage
# vsphere storage management
# cloud storage management
# data storage design
# storage optimization
#
# Cluster 54:
# digital marketing strategy  campaign management  analytics interpretation
# email marketing
# data analysis  google analytics  marketing
# marketing automation
# influencer marketing
# marketing tools management
# ecommerce marketing strategy
# marketing tool proficiency
# marketing plan creation
# marketing analytics
# marketing campaign management
# film marketing
# twitter marketing
# marketing campaign planning
# content marketing
# video marketing
# agile marketing principles
# marketing planning
# marketing principles
# agile marketing
# marketing ai analysis
# marketing strategy
#
# Cluster 55:
# database backup and recovery
# backup and recovery
# database recovery
# data backup and recovery
# cloud disaster recovery
# backup and recovery techniques
# disaster recovery
# disaster recovery implementation
# data recovery
#
# Cluster 56:
# java ee 8 fundamentals
# java ee fundamentals
# java ee development
# java ee application server management
# java ee packaging
# java ee essentials
# java ee server configuration
# java ee application server deployment
# java ee 7 web services
# java ee application server administration
# java ee 8 development
# java ee architecture
# java ee application deployment
# java ee application servers
# java ee web services
# java ee application development
# java ee frameworks
# java ee design patterns
# java ee framework usage
# java ee framework
#
# Cluster 57:
# mongodb management
# mongodb
# mongodb and node
# mongodb integration
# mongodb schema design
# mongodb database management
# mongodb  node  react
# mongodb data modeling
#
# Cluster 58:
# wireless network troubleshooting
# network design
# network troubleshooting
# network infrastructure design
# network design and troubleshooting
# enterprise network design
# cloud network design
# 5g network design
# network device troubleshooting
#
# Cluster 59:
# gui design and development
# gui development with tkinter
# gui testing
# python gui programming
# python gui development
# gui creation
# gui development
# gui design
# gui automation
# javafx gui design
# gui programming
# tkinter gui development
#
# Cluster 60:
# enterprise network security
# implementing network security measures
# wireless network management
# network security configuration
# 5g network planning
# 5g network strategy
# network security basics
# network security management
# network reconnaissance
# network engineering
# network security assessment
# network management
# network security implementation
# network security
# network security analysis
# wireless network security
# network simulation
# network requests
# wireless network setup
# network analysis
# network layer 3 technologies
# cryptography and network security
# network switching
# network programming
#
# Cluster 61:
# go data structure implementation
# data structure concepts
# data structure manipulation
# data structure management
# data structure fundamentals
# data structure design
# basic html structure
# data structure basics
# dynamic data structure
# ...
# platform development
# cloud platform knowledge
# cross-platform application development
# cross-platform java development
# c# cross-platform development
# cross-platform compatibility
# cross-platform app development
# sap cloud platform knowledge
# cross-platform collaboration
# platform navigation
# cloud platform development
#
# Cluster 106:
# digital marketing analysis
# digital illustration
# digital marketing certification
# digital detox
# digital audio workstation
# digital marketing strategy
# digital organization
# digital maturity assessment
# digital signal processing
# digital art
# digital well-being
# digital marketing
# digital literacy
# digital construction drawings
# digital collaboration
# digital forensics
# digital synthesis
# digital logic
# digital design
# digital logic design
#
# Cluster 107:
# microservice creation
# microservice design
# microservice architecture
# java microservice development
# grpc microservice development
# microservice development
# microservice security
# data microservice design
# microservice communication
# microservice deployment
#
# Cluster 108:
# javascript event handling
# javascript interoperability
# javascript programming
# tensorflow with javascript
# javascript development
# javascript framework
# javascript scoping rules
# javascript mastery
# javascript
# multithreading in javascript
# async javascript
# javascript looping
# javascript integration
# debug javascript
# javascript fluency
# javascript bundling
# understanding javascript scope
# javascript coding
# javascript async programming
# javascript compilation
# debug javascript code
# javascript animations
# javascript fundamentals
# html  css  javascript
# javascript scope
# javascript frameworks
# javascript optimization
# vanilla javascript development
# javascript objects
#
# Cluster 109:
# oracle autonomous database administration
# kubernetes administration
# systems administration
# network administration
# azure database administration
# jira administration
# aws cloud administration
# aws sysops administration
# security administration
# administration management
# cloud administration
# dns administration
# tomcat administration
# database administration
# windows administration
# cloud database administration
# teradata vantage administration
# microsoft 365 administration
# user account administration
# google workspace administration
# github administration
# system administration
# unix administration
# file system administration
# linux system administration
# openshift administration
# linux administration
# salesforce administration
# azure administration
# hadoop administration
#
# Cluster 110:
# use grpc
# grpc client/server development
# grpc in python
# grpc protocol
# grpc  protocol buffers  microservices
# grpc framework utilization
# grpc framework implementation
# grpc service development
# grpc client-server development
# grpc fundamentals
# grpc in go
# grpc framework usage
# grpc implementation
# grpc development
# grpc for python
# grpc
# grpc framework
# grpc python implementation
#
# Cluster 111:
# iot device management
# device driver
# linux device drivers
# writing linux device drivers
# device compatibility
# cisco device configuration
# device servicing
# device drivers
# iot device programming
# device maintenance
# cisco device repair
# device management
# device configuration
# android device management
# linux device driving
# cisco device maintenance
# write device drivers
# linux device driver development
# write linux device drivers
# device driver development
# linux device driver writing
# cisco device servicing
# linux device driver programming
#
# Cluster 112:
# kotlin
# manage data with kotlin
# kotlin fundamentals
# kotlin basics
# kotlin programming
# kotlin app development
# kotlin language
# kotlin development
#
# Cluster 113:
# testing techniques
# security testing
# hypothesis testing
# exploratory testing
# web application security testing
# rspec testing
# using python for testing
# python testing
# cypress testing
# alpha testing in agile
# python web testing
# testing
# usability testing
# automated security testing
# ruby testing
# exploratory testing techniques
# web testing
# agile testing
# unit testing
# appium testing
# automated testing
# android app security testing
# python for testing
# alpha testing
# testing tools
#
# Cluster 114:
# sales management
# sales analysis
# sales enablement
# sales closing
# sales dashboard creation
# sales coaching
# ai-powered sales
# sales order processing
# sales engineering
# sales negotiation
# sales development coaching
# salesforce sales automation
# sales techniques
# sales forecasting techniques
# sales prospecting
# sales forecasting
# sales strategy
# sales strategy design
# sales automation
# b2b sales strategy
#
# Cluster 115:
# network virtualization
# virtualization techniques
# cloud architecture  virtualization  data management
# virtualization using virtualbox
# virtualization management
# linux virtualization
# virtualization
# virtualization security management
#
# Cluster 116:
# gitops practices
# c++ best practices
# cloud security practices
# cloud recruiting best practices
# cybersecurity best practices
# c# coding best practices
# agile development practices
# security best practices
# agile practices
# sustainability practices
# data science best practices
# secure coding practices
# best practices
# internationalization best practices
#
# Cluster 117:
# embedded programming
# systems programming
# embedded c programming
# embedded system programming
# embedded systems design
# embedded systems development
# c programming for embedded systems
# embedded systems programming
# embedded systems
#
# Cluster 118:
# cloud computing principles
# aws cloud computing
# cloud computing basics
# quantum computing basics
# edge computing
# cloud computing concepts
# parallel computing
# cloud computing fundamentals
# azure cloud computing
# quantum computing
# cloud computing
# serverless computing
# quantum computing concepts
# serverless architecture  cloud computing
# using aws lambda for serverless computing
# cloud computing  devops
# scientific computing
# micropython physical computing
#
# Cluster 119:
# serverless react development
# react component lifecycle
# react  full-stack  hosting
# creating react apps
# react web development
# react development
# react framework
# react and javascript
# react full-stack
# create react apps
# react application development
# build react apps
# react native development
# react.js
# react fundamentals
#
# Cluster 120:
# building web applications
# building reactive web applications
# building web apps
# developing web applications using c#
# create web applications
# build ios apps with coreml
# develop web apps
# building full-stack web applications
# build web applications
# build android apps
# developing web apps
# deploy web apps
# creating progressive web apps
# build web apps
# build 3d models
# build full-stack web apps
# build databases
# build scalable applications
# build angular applications
# build web projects
#
# Cluster 121:
# big data
# big picture thinking
# big data architecture
# big data processing
# big data  architecting  engineering
# big data analysis
# big data analytics
# big data batch processing
# big data engineering
# big data management
#
# Cluster 122:
# compliance planning
# compliance auditing
# privacy law compliance
# software security compliance
# gaap compliance
# cloud security compliance
#
# Cluster 123:
# text summarization
# nlp text classification
# text prediction
# text analytics
# text analysis and processing
# text data analysis
# text classification
# text analysis
# text processing
# translate text and images
#
# Cluster 124:
# algorithm implementation
# stl algorithm usage
# java algorithm design
# ai algorithm development
# algorithm optimization
# algorithm design
# algorithm analysis
# recommendation algorithm design
#
# Cluster 125:
# aws cloud services
# azure services
# cloud security tools and services
# cloud services
# data services management
# certificate services management
# federation services
# edge services management
# use aws services
#
# Cluster 126:
# content creation
# xaml content creation
# model creation
# patch creation
# tensorflow model creation
# long document creation
# web component creation
# vue.js component creation
# portfolio creation
# complex model creation
# slide creation
# excel spreadsheet creation
# table creation
# html page creation
# documentary creation
# 2d drawing creation
# web service creation
# static site creation
# spreadsheet creation
# presentation creation
# dashboard creation
# pivot table creation
# instrument creation
# vfx creation
# object creation
#
# Cluster 127:
# implementing caching strategies
# service worker caching
# cloudfront caching
# serverless caching
# redis caching
# cloud caching
# caching and retrieval
# caching implementation
#
# Cluster 128:
# cad  bim  facilities management
# cad configuration
# cad drafting
# cad hardware configuration
# cad software
# cad standardization
# cad design
# cad software proficiency
# cad modeling
# cad modelling
# advanced cad modeling
# computer-aided design (cad)
# cad modeling proficiency
# cad import
#
# Cluster 129:
# selenium synchronization
# selenium test automation
# selenium
# selenium frameworks
# selenium automation frameworks
# selenium testing
# advanced selenium automation
# selenium webdriver
# selenium automation framework design
# selenium support classes
# selenium automation
#
# Cluster 130:
# optimize web performance
# performance testing
# linux performance optimization
# web performance optimization
# linux performance analysis
# optimize system performance
# system performance optimization
# optimizing cloud performance
# monitor system performance
# performance optimization
# java performance optimization
# performance optimization  resource management  system monitoring
# tune linux performance
# high-performance
# optimize storage performance
# python performance optimization
# performance measurement
# performance improvement
# live looping performance
# performance management
# performance analysis
# performance and load testing
#
# Cluster 131:
# css animation
# animation scouting
# animation development
# animation principles
# animation
# javascript animation
# animation techniques
# animation creation
# vfx animation
#
# Cluster 132:
# deep learning optimization
# deep learning model deployment
# deep learning on aws
# deep learning frameworks
# deep learning algorithms
# deep learning  tensorflow  model deployment
# deep learning deployment
# deep learning fundamentals
# deep learning model building
# deep learning techniques
# deep learning application deployment
# deep learning
# deep learning modeling
# deep learning models
#
# Cluster 133:
# ansible playbooks
# ansible system management
# ansible configuration management
# manage ansible
# ansible automation
#
# Cluster 134:
# css refactoring
# refactoring
# refactoring techniques
# java refactoring
# code refactoring
#
# Cluster 135:
# windows 10 network configuration
# configuring windows 10 networks
# implementing windows 10
# windows 10 deployment
# migrate to windows 10
# windows 10 administration
# windows 10 implementation
# windows installation
# windows 10 installation
# troubleshooting windows 10
# windows 10 configuration
#
# Cluster 136:
# collaboration techniques
# clustering techniques
# lighting techniques
# data preparation techniques
# synchronization techniques
# scanning techniques
# meta-analysis techniques
# computer vision techniques
# subnetting techniques
# tracking techniques
# interviewing techniques
# localization techniques
# questioning techniques
# patching techniques
# compositing techniques
# 3d printing techniques
# soldering techniques
# management techniques
# exception handling techniques
# negotiation techniques
# idea generation techniques
# multithreading techniques
# dockerization techniques
# fabrication techniques
# motivation techniques
# sampling techniques
# intervention techniques
# persuasion techniques
# mixing techniques
# data mining techniques
# advanced drum recording techniques
# brainstorming techniques
# feedback delivery techniques
# supervised learning techniques
# manufacturing techniques
# evaluation techniques
# additive manufacturing techniques
# facilitation techniques
# recording techniques
# malware analysis techniques
# coaching techniques
# java profiling techniques
# value estimation techniques
# simulation techniques
# advanced git techniques
# c# interview techniques
# eurorack patching techniques
# forecasting techniques
# visual effects techniques
# ethical hacking techniques
# exploitation techniques
# wavelet analysis techniques
#
# Cluster 137:
# cloud transformation
# organizational transformation
# agile transformation
# digital transformation strategy
# digital transformation
# data extraction and transformation
# data transformation
#
# Cluster 138:
# data science fundamentals
# data science myths
# data science understanding
# data science myths debunking
# data science-to-data engineering transition
# data science for sql
# github for data science
# data science with scala
# python data science testing
# data science
# data science techniques
# data science tool handling
# data science modeling
# data science job search strategies
# data science job seeking
# data science job search
# data science concepts
# ai and data science
# github usage for data science job searches
# data science functions
#
# Cluster 139:
# style web pages
# responsive web design
# real-time web development
# accessible web design
# php web development
# web development
# style web pages with css
# web resilience
# dynamic web content
# web app development
# dreamweaver web design
# web development tools
# web service design
# web development with gwt
# web design
# design web interfaces
# interacting with web elements
# c++ web development
# styling web pages
# web page development
# animate web elements
# jsf web development
# python xml/json/web
# web hosting
# dynamic web development
# web service development
# automate web development tasks
# web mvc
# web design fundamentals
# web scraping
# web development fundamentals
# restful web service
# restful web service design
#
# Cluster 140:
# automation scripting
# task automation
# build automation
# terraform automation
# python webdriver automation
# advanced automation scripting
# azure automation
# python automation
# automation programming
# automation testing
# automation
# web project workflow automation
# workflow automation
# grunt.js workflow automation
# cloud automation
# web automation
# office automation
# cypress automation
# jenkins automation
# industrial automation
# web browser automation
# ml pipeline automation
# network automation
# it automation fundamentals
# ci/cd automation
#
# Cluster 141:
# data structures  code architecture  testing
# c++ programming  data structures  algorithms
# tree data structures
# python data structures
# data structures and code architecture
# go data structures
# immutable data structures
# data structures
# javascript data structures
#
# Cluster 142:
# neural networks
# neural network modeling
# neural network development
# neural network training
# neural network implementation
# neural network design
# neural network programming
# neural network building
#
# Cluster 143:
# writing bdd scenarios
# bug writing
# writing tests
# test writing
# conversational ai writing
# sql query writing
# technical writing
# writing mastery
# writing automated tests
# test case writing
# writing testable code
# writing a strong hook
# narrative writing
# writing test cases
#
# Cluster 144:
# java modernization
# java lambda expressions
# java multithreading
# java syntax  java features  java development
# enterprise java development
# java enterprise edition development
# java lambdas
# java web app development
# java 9+ features
# java profiling
# developing java applications on aws
# aws java development
# java interoperability
# java 9+
# java 17 features
# java development with eclipse
# java cloud development
# java enterprise edition 8
# java collections
# java to python transition
# java development environment
# java web development
# java programming
# java algorithms
# java development
# java
# java to python conversion
#
# Cluster 145:
# social media strategy
# social media marketing
# social media management
# social media optimization
# web media creation
# social media leadership
# social media and digital hiring
#
# Cluster 146:
# logistic regression
# regression techniques
# regression analysis
# regression modeling
# linear regression
#
# Cluster 147:
# app penetration testing
# network penetration testing
# penetration testing
# network penetration
# web application penetration testing
#
# Cluster 148:
# azure ai
# azure signalr scaling
# azure signalr service
# microsoft azure fundamentals
# azure iot development
# design azure networks
# implement azure private access
# design azure arm templates
# azure fundamentals
# monitor azure solutions
# managing azure databases
# azure cloud fundamentals
# mlops  mlflow  azure
# azure synapse scaling
# azure ecosystem
#
# Cluster 149:
# c++ syntax
# xaml syntax
# java syntax
# c# syntax
# advanced c# syntax

# %% [markdown]
# We noticed that one cluster is very large and uniformative, this problem could not be fixed with tf-idf clustering:

# %%
# Find the index of the list with the maximum length
max_index = max(range(len(clustered_skills)), key=lambda i: len(clustered_skills[i]))

# Print the index of the list with the maximum length
print("Index of cluster with maximum length:", max_index)
# Out:
# Index of list with maximum length: 10

# %% [markdown]
# We will perform reclustering of this large, general cluster:

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Identify the cluster you want to redistribute
cluster_to_redistribute = max_index  # Adjust the cluster ID as needed

# Extract skills from the identified cluster
skills_to_redistribute = clustered_skills[cluster_to_redistribute]
#print(len(skills_to_redistribute))
# Vectorize all skills in the clusters
cluster_vectorized = {}
for index, cluster in enumerate(clustered_skills):
    if index != cluster_to_redistribute:
        cluster_vectorized[index] = vectorizer.transform(cluster)

# Initialize dictionary to store transformed skills
skill_transformed_dict = {}

for i, skill in enumerate(skills_to_redistribute):
    X = vectorizer.transform([skill])
    max_sim = -1
    max_cluster = None
    for index, cluster in enumerate(clustered_skills):
        if index != cluster_to_redistribute:
           X_cluster = cluster_vectorized[index]
           sim = cosine_similarity(X, X_cluster).mean()
           if sim > max_sim:
               max_sim = sim
               max_cluster = index
    skill_transformed_dict[skill] = max_cluster

# %%
copy_list = clustered_skills.copy()
for skill, cluster in skill_transformed_dict.items():
  copy_list[cluster].append(skill)

copy_list = [cluster for i,cluster in enumerate(copy_list) if i!=max_index]


print(copy_list)
# Out:
# [['parsing protobuf messages', 'sending messages', 'rigging', 'programmatic advertising', 'unlearn silence', 'servlets', 'facial retouching', 'rpm distribution', 'merge conflict resolution', 'conflict resolution', 'bias mitigation', 'logical reasoning', 'attributes', 'asking questions', 'organizational alignment', 'foster inclusivity', 'uncovering unconscious bias', 'generating ideas', 'mindset', 'bookkeeping', 'laser cutting', 'messaging with jms', 'focus', 'lombok annotations', 'linear algebra', 'enhanced concentration', 'trauma-informed care', 'recognize hazards', 'cinema 4d', 'vba', 'argumentation', 'e-commerce', 'mental fortitude', 'procurement', 'geometric dimensioning', 'sourcing candidates', 'dimensioning and tolerancing', 'identify root causes', 'camera settings', 'ssh tunneling', 'communicating over rpc', 'sketching', 'values alignment', 'schematic capture', 'goal achievement', 'photoshop rendering', 'exploit vulnerabilities', 'websockets', 'authorization', 'habit formation', 'pulse width modulation', 'camera mounting', 'enhance c#', 'workplace inclusivity', 'xml parsing', 'pitch effectively', 'guitar scales', 'requirements elicitation', 'mandolin playing', 'public speaking', 'edit ebooks', 'mental health awareness', 'fostering diversity', 'upskilling and reskilling', 'sight reading', 'conditional statements', 'ip addressing', 'linkedin advertising', 'c# attributes', 'mechanics', 'c# enhancements', 'play mandolin', 'grand central dispatch', 'testng assertions', 'containerization', 'identify threats', 'budgeting', 'leading teams', 'message brokering', 'candidate sourcing', 'mentor junior managers', 'testng', 'voice over ip', 'requirements gathering', 'sdks', 'regular expression matching', 'facial recognition', 'focus and concentration', 'maya', 'artificial intelligence'], ['data structure knowledge', 'dynamic data structure', 'data structure analysis', 'data structure implementation', 'data structure fundamentals', 'data structure basics', 'data structure creation', 'data structure manipulation', 'data structure concepts', 'go data structure implementation', 'data structure design', 'data structure management'], ['software troubleshooting', 'software development life cycle', 'rhinocam software', 'software development fundamentals', 'install software', 'software development tools', 'software design', 'software development principles', 'agile software development', 'software quality assurance', 'software architecture design', 'software architecture', 'altium software', 'debugging software', 'software architecture principles', 'software security compliance', 'legacy software management', 'software design principles', 'secure software development', 'software installation', 'software development', 'gaap compliance', 'accounting cycle'], ['container security', 'data security', 'wireless network security', 'information security auditing', 'laptop security management', 'it security management', 'network security concepts', 'security design', 'network security analysis', 'security planning', 'security auditing', 'security incident response', 'cryptography and network security', 'web security protocols', 'network security management', 'enterprise network security', 'network security', 'systems security', 'security audit', 'android security', 'saas security management', 'open source security', 'data analytics security', 'implement security', 'security protocols', 'asset security', 'implementing network security measures', 'microservice security', 'security operations management', 'security engineering', 'security operations', 'security policy development', 'spring security', 'saas security', 'systems and application security', 'data security design', 'security management', 'security concepts', 'aws security governance', 'security', 'web security', 'security governance', 'it security auditing', 'system security', 'incident response', 'compliance auditing', 'public policy', 'it governance'], ['deep learning  tensorflow  model depl ...

# %% [markdown]
# The new clusters:

# %%
clustered_skills = copy_list.copy()
for cluster_id, skills_in_cluster in enumerate(clustered_skills):
    print(f"Cluster {cluster_id}:")
    for skill in skills_in_cluster:
        print(skill)

    print()

# Find the index of the list with the maximum length
new_max_index = max(range(len(clustered_skills)), key=lambda i: len(clustered_skills[i]))
print(new_max_index)
print(len(clustered_skills[new_max_index]))
# Out:
# Cluster 0:
# parsing protobuf messages
# sending messages
# rigging
# programmatic advertising
# unlearn silence
# servlets
# facial retouching
# rpm distribution
# merge conflict resolution
# conflict resolution
# bias mitigation
# logical reasoning
# attributes
# asking questions
# organizational alignment
# foster inclusivity
# uncovering unconscious bias
# generating ideas
# mindset
# bookkeeping
# laser cutting
# messaging with jms
# focus
# lombok annotations
# linear algebra
# enhanced concentration
# trauma-informed care
# recognize hazards
# cinema 4d
# vba
# argumentation
# e-commerce
# mental fortitude
# procurement
# geometric dimensioning
# sourcing candidates
# dimensioning and tolerancing
# identify root causes
# camera settings
# ssh tunneling
# communicating over rpc
# sketching
# values alignment
# schematic capture
# goal achievement
# photoshop rendering
# exploit vulnerabilities
# websockets
# authorization
# habit formation
# pulse width modulation
# camera mounting
# enhance c#
# workplace inclusivity
# xml parsing
# pitch effectively
# guitar scales
# requirements elicitation
# mandolin playing
# public speaking
# edit ebooks
# mental health awareness
# fostering diversity
# upskilling and reskilling
# sight reading
# conditional statements
# ip addressing
# linkedin advertising
# c# attributes
# mechanics
# c# enhancements
# play mandolin
# grand central dispatch
# testng assertions
# containerization
# identify threats
# budgeting
# leading teams
# message brokering
# candidate sourcing
# mentor junior managers
# testng
# voice over ip
# requirements gathering
# sdks
# regular expression matching
# facial recognition
# focus and concentration
# maya
# artificial intelligence
#
# Cluster 1:
# data structure knowledge
# dynamic data structure
# data structure analysis
# data structure implementation
# data structure fundamentals
# data structure basics
# data structure creation
# data structure manipulation
# data structure concepts
# go data structure implementation
# data structure design
# data structure management
#
# Cluster 2:
# software troubleshooting
# software development life cycle
# rhinocam software
# software development fundamentals
# install software
# software development tools
# software design
# software development principles
# agile software development
# software quality assurance
# software architecture design
# software architecture
# altium software
# debugging software
# software architecture principles
# software security compliance
# legacy software management
# software design principles
# secure software development
# software installation
# software development
# gaap compliance
# accounting cycle
#
# Cluster 3:
# container security
# data security
# wireless network security
# information security auditing
# laptop security management
# it security management
# network security concepts
# security design
# network security analysis
# security planning
# security auditing
# security incident response
# cryptography and network security
# web security protocols
# network security management
# enterprise network security
# network security
# systems security
# security audit
# android security
# saas security management
# open source security
# data analytics security
# implement security
# security protocols
# asset security
# implementing network security measures
# microservice security
# security operations management
# security engineering
# security operations
# security policy development
# spring security
# saas security
# systems and application security
# data security design
# security management
# security concepts
# aws security governance
# security
# web security
# security governance
# it security auditing
# system security
# incident response
# compliance auditing
# public policy
# it governance
#
# Cluster 4:
# deep learning  tensorflow  model deployment
# deep learning deployment
# deep learning techniques
# deep learning on aws
# deep learning model deployment
# deep learning fundamentals
# deep learning optimization
# deep learning modeling
# deep learning frameworks
# deep learning model building
# deep learning
# deep learning application deployment
# deep learning models
# deep learning algorithms
# transformer models
# tensorflow and pytorch
# gans and diffusion models
# supervised learning algorithms
#
# Cluster 5:
# code protection
# code efficiently
# debugging php code
# code quality
# writing testable code
# debugging c code
# testing and code quality
# debugging vue.js code
# debug c code
# c code debugging
# code bundling
# debug code
# g-code programming
# linting code
# code architecture
# code linting
# debugging code
# manage code dependencies
# error code diagnosis
# code management
# write concurrent code
# code refactoring
# code comprehension
# code optimization
# code quality assurance
# code testing
# code security
# troubleshooting code
# code review techniques
# code sharing
# optimizing code
# code reviewing
# code analysis
# code reusability
# code coverage
# code collaboration
# code debugging
# no-code development
# quality control
# reading comprehension
# quality assurance
#
# Cluster 6:
# c programming for embedded systems
# embedded c programming
# embedded systems development
# embedded programming
# embedded systems programming
# embedded system programming
# embedded systems
# embedded systems design
# distributed systems
# recommender systems
#
# Cluster 7:
# configure storage policies
# storage optimization
# data storage management
# data storage optimization
# cloud data storage
# data storage design
# cloud storage management
# optimize storage performance
# cloud storage
# linux storage administration
# nas storage management
# vsphere storage management
# design data storage solutions
# manage storage arrays
# data storage
# storage management
# linux storage device management
# storage configuration
# san storage management
# iscsi storage area network management
#
# Cluster 8:
# cybersecurity career building
# career exploration
# cybersecurity career development
# career advancement
# career development
# cybersecurity career
# media and entertainment career
# career skills
# cybersecurity career planning
# career planning
# organizational planning
# capacity planning
# compliance planning
# active directory planning
# sap planning
# high availability planning
# microsoft entra id planning
# sdlc planning
# cybersecurity
# incident response planning
# cybersecurity awareness
# migration planning
# cybersecurity knowledge
# strategic planning
# material planning
# mrp planning
# cybersecurity threat detection
#
# Cluster 9:
# cloud security strategy
# strategy development
# analytics strategy
# business ai strategy
# business strategy development
# generative ai strategy
# cultural strategy
# pricing strategy
# data strategy
# test strategy development
# strategy planning
# cloud migration strategy
# ai strategy
# instrumentation strategy
# 5g strategy
# innovation strategy
# 5g network strategy
# ppc strategy
# xaas business strategy
# ai strategy development
# business strategy
# data strategy development
# cloud strategy planning
# international business
# business intelligence
# cultural sensitivity
# business continuity
# aws business solution exploration
# business acumen
#
# Cluster 10:
# autocad proficiency
# revit software proficiency
# cad software proficiency
# javascript proficiency
# php proficiency
# microsoft word proficiency
# software proficiency
# tableau proficiency
# microsoft office proficiency
# reason software proficiency
# pcb design software proficiency
# github proficiency
# xcode proficiency
# gis software proficiency
# office 365 proficiency
# powerpoint proficiency
# revit proficiency
# excel proficiency
# solidworks proficiency
# mern stack proficiency
# command-line proficiency
# sql proficiency
# microsoft office
# excel statistics
#
# Cluster 11:
# aws certification preparation
# green building certification
# comptia a+ certification
# istqb certification
# revit mep certification
# access certification
# lpic-1 certification
# ccnp certification
# aws certification
# pmp certification
# leed certification principles
# comptia certification
# certification preparation
# sscp certification
# inventor certification
# linux administration  red hat certification
# azure fundamentals certification preparation
# solidworks certification
# aws developer certification
# interview preparation
# exam preparation
# autodesk inventor
#
# Cluster 12:
# apache airflow management
# development process management
# remote log management
# crm management
# websocket management
# active directory management
# disability management
# desktop management
# stakeholder management
# calendar management
# heat stress management
# android device management
# azure resource management
# stress management
# watch management
# bug management
# autocad mep management
# mongodb management
# thread management
# unified communications management
# firewall management
# environmental management
# bim management
# certificate management
# autocad civil 3d management
# construction document management
# account management
# multicloud management
# asset management
# time management strategies
# pressure management
# technical debt management
# wordpress management
# vmware vsphere 7 drs management
# ci/cd pipeline management
# performance management
# patch management
# collaboration management
# git operations management
# user management
# construction management
# file management
# bim 360 management
# azure active directory management
# financial management
# hadoop cluster management
# energy management
# privacy management
# microsoft 365 management
# queue management
# icloud management
# supply chain management
# time management
# safety management
# accounts receivable management
# device management
# azure management
# os management
# switch management
# imposter syndrome management
# credit management
# container management
# incident management
# classroom management
# access management
# ngrx state management
# productivity management
# domain management
# external library management
# music business management
# vm management
# sdlc management
# campaign management
# agile management
# identity and access management
# memory management
# inventory management
# system management
# upward management
# dependabot dependency management
# routing protocol management
# voip management
# exception management
# human resources management
# supplier relationship management
# group policy management
# library management
# building management
# package management
# hybrid active directory management
# aws management
# vault management
# nuget package management
# dhcp management
# dependency management
# accounts payable management
# autocad mep & civil 3d management
# identity management
# gradle build management
# submittals management
# elasticsearch management
# domain name system management
# vulnerability management
# lifecycle management
# dns/dhcp management
# communications management
# ansible system management
# disk management
# lean management
# redux state management
# openshift management
# kanban management
# resource management
# gitops management
# facility management
# modern management
# servlet lifecycle management
# autocad  space management  facilities management
# hadoop management
# task management
# community management
# logistics management
# dns management
# change management
# operations management
# business management
# coping with stress
# active directory setup
# disability awareness
# accounts receivable
# watch customization
# blood-borne pathogen safety
# document formatting
# active listening
#
# Cluster 13:
# cloud computing fundamentals
# cybersecurity fundamentals
# blockchain fundamentals
# dl fundamentals
# nlp fundamentals
# microsoft azure fundamentals
# cryptography fundamentals
# azure cloud fundamentals
# typography fundamentals
# ios development fundamentals
# c# fundamentals
# python fundamentals
# java fundamentals
# c programming fundamentals
# banking fundamentals
# logic pro fundamentals
# aws cloud fundamentals
# cyber insurance fundamentals
# os fundamentals
# react fundamentals
# semiconductor fundamentals
# supply chain fundamentals
# sdn fundamentals
# cloud fundamentals
# electronics fundamentals
# switching fundamentals
# network fundamentals
# aws development fundamentals
# azure fundamentals
# microsoft security fundamentals
# css fundamentals
# cloud security fundamentals
# java programming fundamentals
# it fundamentals
# electronic fundamentals
# programming fundamentals
# cryptography
# blockchain interaction
# semiconductor physics
# cyber threat detection
# semiconductor fabrication
#
# Cluster 14:
# prioritization  planning  communication
# clear communication
# executive communication
# lean communication
# websocket communication
# socket communication
# communication
# mindfulness in communication
# communication improvement
# effective communication
# assertiveness and communication
# stakeholder communication
# microservice communication
# time management  teamwork  communication
# interpersonal communication
# network communication
# influence and communication
# thread communication
# communication security
# business communication
# grpc communication
# communication skills
# internal communication
# real-time communication
# cross-cultural communication
# assertive communication
# communication effectiveness
# websocket communications
# assertiveness
# mindfulness
#
# Cluster 15:
# ml pipeline automation
# task automation
# automation programming
# web automation
# python webdriver automation
# ansible automation
# network automation
# selenium automation framework design
# cloud automation
# cypress automation
# selenium automation frameworks
# python automation
# office automation
# azure automation
# ci/cd automation
# build automation
# industrial automation
# automation
# advanced selenium automation
# jenkins automation
# terraform automation
# web browser automation
# it automation fundamentals
# robot framework automation
# selenium automation
# automation testing
# process automation
# selenium frameworks
# selenium
# selenium webdriver
# ansible playbooks
# ci/cd
# robot interfacing
# ci/cd pipelines
#
# Cluster 16:
# manufacturing validation
# bean validation
# validation
# data validation
# form validation
# additive manufacturing
# manufacturing processes
# additive manufacturing materials
#
# Cluster 17:
# vulnerability analysis
# hadoop data analysis
# recommendation systems  data analysis  model evaluation
# geospatial analysis
# spatial analysis
# data analysis
# pricing analysis
# tolerance analysis
# nlp analysis
# construction productivity analysis
# risk analysis
# semantic analysis
# linux performance analysis
# simulation analysis
# data analysis techniques
# market analysis
# time-frequency analysis
# log file analysis
# fea analysis
# time series analysis
# finite element analysis (fea)
# data protection analysis
# remarketing optimization  conversion tracking  data analysis
# roi analysis
# cloud migration dependency analysis
# wavelet analysis
# quality data analysis
# algorithmic trading  financial modeling  data analysis
# data analysis expertise
# data analysis optimization
# accounting analysis
# performance analysis
# biometric analysis
# business analysis
# numerical analysis
# error analysis
# statistical analysis
# clustering  association  data analysis
# python data analysis
# predictive analysis
# nastran analysis
# exploratory data analysis
# excel analysis
# data analysis with r
# wavelet analysis methods
# circuit analysis
# data analysis and innovation
# log analysis
# cognitive analysis
# data analysis tool selection
# data privacy analysis
# descriptive analysis
# spark analysis
# algorithm analysis
# security analysis
# threat analysis
# data analysis with pandas
# business process analysis
# pandas analysis
# financial data analysis
# design analysis
# analysis
# decision tree analysis
# financial analysis
# engineering analysis
# ai-assisted data analysis
# cybersecurity analysis
# finite element analysis
# regression analysis
# process analysis
# data analysis tools
# material analysis
# roi calculation
# research methods
# extension methods
#
# Cluster 18:
# best practices
# cloud recruiting best practices
# cloud security practices
# agile development practices
# security best practices
# gitops practices
# internationalization best practices
# c++ best practices
# agile practices
# c# coding best practices
# data science best practices
# cybersecurity best practices
# sustainability practices
# linkedin recruiting
# promote sustainability
# agile methodology
# sustainability reporting
# tech recruiting
# agile transformation
#
# Cluster 19:
# network routing
# network reconnaissance
# network engineering
# network concepts
# network simulation
# neural network programming
# enterprise network design
# network routing concepts
# 5g network planning
# neural network implementation
# network penetration
# network layer 3 technologies
# network design
# neural network design
# neural network modeling
# network requests
# network programming
# network switching
# neural network training
# wireless network setup
# cloud network design
# neural network development
# network management
# neural network building
# network analysis
# 5g network design
# wireless network management
# routing and switching
# switching
# switching and routing
# vpn technologies
# layer 3 switching
# layer 3 routing
# neural networks
#
# Cluster 20:
# rails development
# ruby on rails
# ruby on rails controllers and views
# rails programming
# hotwire  ruby on rails
# ruby on rails development
# rails application development
# ruby installation
# full-stack web development with ruby on rails
# installing ruby on rails
# debugging ruby on rails
# rails web framework
# ruby on rails installation
# ruby on rails web development
# ruby on rails 7
# ruby on rails debugging
# rails routing
# web development  ruby on rails  mvc architecture
# ruby on rails routing
# rails framework
# routing
# ip routing
# ospf routing
# eigrp routing
# modulation routing
# vmware nsx-t routing
# routing protocols
# rip and eigrp routing
# rip routing
#
# Cluster 21:
# troubleshooting cloud integration
# mongodb integration
# azure integration
# vue.js/laravel integration
# sap integration
# integration testing
# ai integration
# python database integration
# cloud integration
# css integration
# firebase integration
# enterprise app integration
# icloud integration
# continuous integration
# kinesis integration
# graphql integration
# javascript integration
# signalr integration
# data integration
# ai tool integration
# troubleshoot cloud integration
# socket.io integration
# continuous integration and deployment
# database integration
# shared economy integration
# web page design  user interface  database integration
# appium integration
# library integration
# core ml integration
# retrofit integration
# cypress integration
# graphql
# apply continuous improvement
# continuous delivery
# continuous improvement
#
# Cluster 22:
# rust project management
# project management
# international project management
# react project building
# hybrid project management
# project planning
# project management foundations
# project management skills
# agile project management
# project scheduling
# project resource management
# python project management
# github project management
# resource allocation
# enterprise resource planning
# resource planning
#
# Cluster 23:
# cloud security tools and services
# java ee 7 web services
# web services
# java ee web services
# aws cloud services
# creating web services
# data services management
# azure services
# federation services
# cloud services
# soap web services
# restful web services
# web services management
# building restful web services
# certificate services management
# edge services management
# web services development
#
# Cluster 24:
# api documentation
# restful api development
# web api usage
# rest api consumption
# api management
# web api development
# rest api creation
# restful api design
# rest api integration
# api testing
# api authentication
# api security
# api development
# api integration
# web api design
# openai api integration
# api design
# grpc api development
# rest api development
# authentication
# biometric authentication
# implement authentication
# rest apis
# authentication and authorization
#
# Cluster 25:
# basic html structure
# html structure
# html markup
# html basics
# html
# html fundamentals
# html page creation
#
# Cluster 26:
# java lambdas
# enterprise java development
# java application development
# java to python migration
# java modernization
# java 8 migration
# java algorithm design
# java lambda expressions
# java microservice development
# java to python transition
# java
# java 9+
# java object-oriented programming
# aws java development
# java programming
# java migration strategies
# java syntax
# java syntax  java features  java development
# java collections
# java deployment
# java development environment
# java development with eclipse
# java algorithms
# java profiling
# java arrays
# java enterprise edition development
# java cloud development
# java enterprise edition 8
# java development
# java interoperability
# working with java arrays
# java 17 features
# java 9+ features
# java migration
# java refactoring
# java to python conversion
# java desktop application development
# refactoring
# manipulate arrays
#
# Cluster 27:
# .net library usage
# asp.net core fundamentals
# .net core development
# build asp.net core apps
# .net core fundamentals
# .net framework
# .net core basics
# .net 5 migration
# asp.net core development
# .net programming
# .net commands
# advanced .net programming
# asp.net core
# .net development
# .net core programming
# .net maui application creation
# .net maui development
# integrate with entity framework core
# core ml
# entity framework core
#
# Cluster 28:
# deploy node.js applications
# mongodb and node
# node.js application development
# databases for node.js
# node.js cli development
# node.js development
# advanced node.js
# node.js programming
# ember.js development
# react.js
# node.js deployment
# node development
# express api  node.js  typescript
# node.js testing and quality assurance
# mongodb  node  react
# node.js testing
# testing node.js
# node.js expertise
# selenium node.js testing
# node.js web development
# node.js integration
# gulp.js workflows
# node.js database management
# node.js scaling
# select appropriate databases
# express.js advanced concepts
# vue.js component creation
# mongodb
#
# Cluster 29:
# web design principles
# pcb design principles
# site reliability engineering principles
# ai principles
# agile principles
# lean construction principles
# gd&t principles
# fpga design principles
# lean principles
# green building principles
# accounting principles
# object-oriented design principles
# minimalist design principles
# ux design principles
# cloud computing principles
# ux principles for non-designers
# responsive web design principles
# construction estimating principles
# game design principles
# solid principles
# implement lean principles
# design principles
# graphic design principles
# web development principles
# motivation principles
# it architecture principles
# site reliability
# construction estimating
# cost estimating
# gd&t
#
# Cluster 30:
# customer service excellence
# phone-based customer service skills
# evaluate customer service
# customer service
# customer service skills
#
# Cluster 31:
# risk identification
# risk assessment
# information security risk management
# cybersecurity risk assessment
# security risk assessment
# network security assessment
# security vulnerability assessment
# privacy risk assessment
# risk reporting
# it risk management
# security assessment
# change impact assessment
# vulnerability assessment
# property damage assessment
# risk management
# cybersecurity risk management
# esg reporting
# reporting
# bug reporting
# vulnerability detection
# vulnerability identification
# hazard identification
# vulnerability scanning
# defect reporting
# threat identification
# phishing identification
# managing change
# opportunity identification
# cognitive biases identification
#
# Cluster 32:
# microprocessor architecture
# data architecture design
# webdriver architecture
# it architecture design
# cloud architecture design
# cloud architecture  design  management
# it architecture fundamentals
# data architecture
# swiftui architecture
# agile cloud architecture
# stateless application architecture
# architecture design
# security architecture
# cloud security architecture
# aws cloud architecture
# risc-v architecture
# application architecture
# wan architecture
# ios architecture
# technical architecture design
# azure architecture
# cloud architecture
# mvc architecture
# security architecture design
# cloud architecture fundamentals
# redux architecture
# microservice architecture
# swiftui
# wan connectivity
# wan technologies
#
# Cluster 33:
# digital signal processing
# digital detox
# digital marketing
# digital well-being
# digital transformation
# digital synthesis techniques
# digital logic
# digital construction drawings
# digital art
# digital marketing certification
# digital collaboration
# digital forensics
# digital literacy
# digital logic design
# digital marketing analysis
# digital maturity assessment
# digital synthesis
# digital design
# digital transformation strategy
# digital organization
# digital marketing strategy
# digital illustration
# switch statement logic
# work organization
# fashion illustration
# organizational transformation
#
# Cluster 34:
# sales techniques
# sales management
# sales negotiation
# sales automation
# sales analysis
# sales coaching
# ai-powered sales
# b2b sales strategy
# sales development coaching
# sales strategy design
# sales prospecting
# sales order processing
# sales closing
# sales process automation
# sales process optimization
# sales engineering
# sales leadership
# sales strategy
# sales enablement
# salesforce sales automation
# sales dashboard creation
# sales process management
# statistical process control
# coaching challenge resolution
# process improvement
#
# Cluster 35:
# react application development
# containerized application deployment
# app deployment
# application engineering
# aws deeplens deployment
# enterprise application development
# microservice deployment
# application delivery
# cloud application development
# docker deployment
# desktop application development
# application building
# react application creation
# aws deployment
# jsf application development
# container deployment
# web application deployment
# django deployment
# deployment strategies
# macos application management
# application servers
# microsoft 365 deployment
# application management
# java application deployment on aws
# application deployment
# kafka application development
# tensorflow deployment
# application development
# docker containerization
# feedback delivery
# jsf
#
# Cluster 36:
# financial forecasting
# demand forecasting
# forecasting with analytics
# sales forecasting
# sales forecasting techniques
# time series forecasting
# forecasting techniques
# forecasting
# financial record-keeping
# financial literacy
# financial reporting
# financial accounting
# demand planning
#
# Cluster 37:
# web service deployment
# cloud service management
# web service design
# restful web service design
# azure signalr service
# cloud service deployment
# web service development
# grpc service development
# cloud service selection
# web service creation
# web service architecture
# azure service fabric configuration
# web service integration
# it service management
# restful web service
# service level management
# service-level agreements
# font selection and organization
# signalr scaling
# material selection
#
# Cluster 38:
# java ee design patterns
# creational design patterns
# concurrency patterns
# applying design patterns
# behavioral patterns
# c++ design patterns
# fingerpicking patterns
# behavioral design patterns
# design patterns implementation
# design patterns
# c# design patterns
#
# Cluster 39:
# machine operation
# machine learning models
# machine learning basics
# core ml machine learning
# machine learning model deployment
# machine learning modeling
# azure machine learning
# machine learning algorithms
# machine learning  ai  recommender systems
# building scalable machine learning models
# machine learning model engineering
# machine learning model selection
# machine learning operations
# nlp for machine learning
# machine learning model building
# machine learning techniques
# data analysis  machine learning  predictive modeling
# machine learning with spark
# data preparation  processing systems  machine learning
# python machine learning
# machine learning development
# calculus for machine learning
# machine learning
# machine learning problem framing
# machine learning integration
# machine learning model development
# machine learning valuation
# machine learning engineering
# machine learning fundamentals
# machine learning deployment
# machine learning concepts
# machine learning foundations
# machine learning for recommendations
# cloud-based machine learning
# calculus
# supervised learning
# milling  lathe operation
# differential calculus
# watch operation
# online learning
# cnc operation
# camera operation
#
# Cluster 40:
# sql server database administration
# sql database development
# cloud sql database management
# oracle autonomous database administration
# azure database administration
# sql database management
# database administration
# cloud database administration
# azure sql database management
# azure vmware planning
# mlops  mlflow  azure
# managing azure databases
# azure signalr scaling
# azure synapse scaling
# implement azure private access
#
# Cluster 41:
# analyze data accurately
# analyze data
# analyze wavelets
# analyze c library functionality
# working with go standard library
# go library knowledge
# c library usage
# jetpack library usage
#
# Cluster 42:
# audio filtering
# audio troubleshooting
# digital audio workstation
# audio mixing
# audio engineering
# audio effects
# audio manipulation
# synthesize audio and sound
# sound shaping
# dolby atmos mixing
# modulation effects
#
# Cluster 43:
# audio production
# music production
# music production techniques
# media production
# game production
# 360 video production
# production planning and scheduling
# film production
# production planning
# video production
# audiobook production
# audio effects production
# garageband music production
# electronic music composition
# music notation
# create electronic music
# producing a film
#
# Cluster 44:
# linux basics
# programming basics
# java basics
# cloud security basics
# numpy basics
# python programming basics
# java programming basics
# sql basics
# go programming basics
# git and github basics
# c language basics
# aws deeplens basics
# cloud computing basics
# filmmaking basics
# electronics basics
# data management basics
# python basics
# scala basics
# coffeescript basics
# notion basics
# quantum computing basics
# network security basics
# intellij basics
# web design basics
# cybersecurity basics
# css basics
# composition basics
# electronics soldering
# coffeescript
# interfacing electronics
# numpy capabilities
#
# Cluster 45:
# front-end development
# back-end development
# front end development
# front-end ui development
# front-end design
# react front-end development
# react full-stack
#
# Cluster 46:
# kernel optimization
# semantic kernel building
# kernel management
# linux kernel administration
# linux kernel optimization
# kernel tuning
# semantic kernel analysis
# kernel configuration
# kernel debugging
# semantic kernel development
# kernel development
# linux kernel tuning
# kernel module development
# linux kernel development
# linux kernel configuration
# linux kernel management
# kernel programming
# kernel building
# kernel logging
# linux kernel programming
# linux kernel
# hyperparameter tuning
# module bundling
# system logging
#
# Cluster 47:
# aws cloud administration
# cloud administration
# salesforce administration
# server administration
# security administration
# teradata vantage administration
# user account administration
# unix administration
# jira administration
# windows administration
# azure administration
# systems administration
# system administration
# aws sysops administration
# linux system administration
# linux administration
# sql server administration
# google workspace administration
# dns administration
# tomcat administration
# tomcat server administration
# github administration
# hadoop administration
# administration management
# server administration  security  troubleshooting
# openshift administration
# microsoft 365 administration
# network administration
# file system administration
# file conversion
#
# Cluster 48:
# team adaptability
# virtual team management
# team advocacy
# team building
# team building strategies
# team coaching
# team development
# team accountability
# team collaboration
# team learning
# team management
# team perseverance
# accessibility advocacy
# collaboration
# effective collaboration
# collaboration facilitation
# perseverance
#
# Cluster 49:
# cad hardware configuration
# computer-aided design (cad)
# cad modelling
# cad drafting
# cad modeling
# cad design
# cad modeling proficiency
# cad software
# advanced cad modeling
# cad  bim  facilities management
# cad standardization
# cad import
# cad configuration
# advanced modelling
#
# Cluster 50:
# serverless development
# deploy serverless architectures
# serverless architecture design
# serverless architecture  cloud computing
# serverless architecture
# aws serverless
# serverless application
# serverless computing
# serverless react development
# serverless data processing
# aws serverless architecture
# serverless application development
# using aws lambda for serverless computing
# aws deeplens
# deploying aws
# aws high availability
# aws load balancing
# aws lambda
# deploy faster
#
# Cluster 51:
# ai concepts
# ai programming
# ai game development
# ai ethics
# ai application development
# edge ai application development
# ai tool usage
# generative ai
# conversational ai writing
# ai analysis
# azure ai
# ai techniques
# ai tool application
# ai-based app building
# ai fundamentals
# ai in finance
# ai foundations
# ai app development
# ai utilization
# edge ai development
# ai technology
# ai algorithm development
# copiloting with ai
# ai privacy
# ai algorithms
# ai development
# train generative ai models
# cloud-based ai development
# generative adversarial networks
# tool selection
#
# Cluster 52:
# ai implementation
#
# Cluster 53:
# azure virtual desktop configuration
# virtual audience engagement
# virtual presentation
# virtual instrument creation
# aws virtual machine migration
# manage virtual machines
# virtual assistant
# virtual network management
# virtual instrumentation
# virtual machine creation
# virtual machine management
# manage virtual storage
# virtual meeting facilitation
# virtual storage
# virtual hiring
# java virtual machine optimization
# virtual environment management
# virtual desktop administration
# presentation creation
# meeting facilitation
# instrument creation
#
# Cluster 54:
# multithreading techniques
# android multithreading
# multithreading programming
# java multithreading
# python programming  multithreading  multiprocessing
# multithreading in javascript
# multithreading concepts
# multithreading proficiency
# multithreading
# multithreading management
#
# Cluster 55:
# app development
# fpga development with verilog
# javaserver faces development
# blazor ui development
# microservice development
# gans development
# aws development
# ar development
# swift development
# employee development
# swift app development
# websocket development
# unity development
# angular development
# watchos app development
# fpga development
# business development
# scrum development
# 2d game development
# full-stack development
# workforce development
# cli app development
# strategic planning development
# metaverse development
# eclipse development
# blockchain development
# agile development methodologies
# graphical user interface development
# logic app development
# xcode development
# augmented reality development
# django development
# android app development
# apple tv app development
# responsive development
# aws lambda development
# verilog for fpga development
# xcode development environment
# website development
# sharepoint development
# tkinter development
# tensorflow development
# jsf development
# ajax development
# mern stack development
# ios development
# apple tvos app development
# graphql development
# php development
# ride-sharing app development
# android development
# quarkus development
# firebase app development
# react development
# iphone app development
# microprofile development
# swiftui development
# ios app development
# gwt development
# c++ development
# recommender system development
# ui development
# tvos development
# full stack development
# verilog development
# ios 17 app development
# angular full-stack development
# aws deeplens development
# ios 17 development
# desktop app development
# full-stack site development
# collaborative development
# business development planning
# postgresql client development
# lambda function development
# servlet development
# game development
# blazor development
# hotwire development
# ethereum development
# apollo development
# business case development
# go development
# cli development
# unity game development
# chatbot development
# sharepoint framework development
# spa development
# real-time app development
# apple tvos development
# jsf component development
# typescript development
# etl development
# agile development
# smart contract development
# playbook development
# elt development
# etl
# gans
# reality capture
# scrum methodology
#
# Cluster 56:
# nosql data management
# data streaming  analytics  azure
# data loading
# data labeling
# data normalization
# delegation and data source management
# healthcare data protection
# data pipeline management
# data extraction
# data serialization
# data cleaning
# web data extraction
# data pipelines
# data stewardship
# encode data
# data governance
# data transformation
# data mining in r
# data backup and recovery
# data streaming
# data exploration
# data recovery
# data processing
# data clustering
# data parallelism
# data warehousing
# data privacy compliance
# hadoop data processing
# data acquisition
# aws data management
# serializing data
# data preparation and processing
# data querying
# data privacy
# algebraic data types
# data backup
# data binding
# data interpretation
# data organization
# querying data
# data structuring
# data warehousing concepts
# data translation for aec
# data analytics
# query data
# protect data
# data wrangling
# data quality
# data mining
# data innovation
# data preparation
# manage data pipelines
# data preprocessing
# data extraction and transformation
# data storytelling
# data migration
# real-time data streaming
# data management
# create data visualizations
# data acquisition and exploration
# data protection
# data annotation
# azure data management
# drawing annotation
# facial feature extraction
# environmental stewardship
# event streaming
# storytelling
# brand storytelling
#
# Cluster 57:
# spring boot microservices development
# setting up spring boot
# securing spring boot apps
# spring mvc framework
# spring framework
# spring boot application development
# deploying spring boot applications
# spring boot development
# spring mvc
# spring framework development
# spring boot microservice creation
# securing spring boot microservices
# spring boot microservices
# spring boot framework
# dockerizing spring boot microservices
# spring boot essentials
# spring boot configuration
# deploying spring boot apps
# spring framework fundamentals
# building microservices with spring boot
# spring framework knowledge
# build restful apis with spring boot
# writing kotlin spring boot apps
# tdd with spring boot
# spring boot fundamentals
# spring framework mastery
# dockerizing spring boot applications
# deploy spring boot applications
# spring boot deployment
# spring 6 and boot 3
# spring boot
# boundary setting
# goal setting
# integrate graphql with spring
#
# Cluster 58:
# cloud security design
# hiring for cloud
# cloud security compliance
# cloud cost management
# cloud security concepts
# cloud transformation
# cloud provisioning
# agile methodologies  jira cloud
# cloud governance tools
# designing and managing cloud architectures
# hybrid cloud management
# cloud collaboration
# cloud security management
# cloud library usage
# aws cloud computing
# manage cloud finances
# cloud disaster recovery
# cloud innovation
# cloud security operations
# cloud security auditing
# cloud data management
# cloud scaling
# cloud security engineering
# optimizing cloud performance
# cloud decision-making
# google cloud security management
# cloud recruiting
# cloud migration
# design cloud architectures
# cloud security
# cloud resource management
# cloud operations
# azure cloud computing
# private cloud management
# cloud scalability
# cloud deployment
# cloud computing
# cloud application design
# cloud management
# cloud resource planning
# cloud governance concepts
# architect cloud solutions
# cloud hadoop management
# cloud design
# cloud planning
# azure cloud migration
# cloud security tools
# cloud computing concepts
# aws cloud development
# cloud development
# cloud system design
# cloud deployment planning
# cloud migration planning
# decision making
# decision-making
# decision making in c
#
# Cluster 59:
# angular and asp.net development
# asp.net web api development
# asp.net web development
# asp.net mvc development
# asp.net mvc 5 development
# react and asp.net mvc development
# asp.net deployment
# asp.net fundamentals
# asp.net development
# mvc frameworks
# angular
#
# Cluster 60:
# marketing ai analysis
# marketing campaign management
# agile marketing principles
# marketing principles
# marketing tools management
# marketing automation
# ecommerce marketing strategy
# marketing tool proficiency
# video marketing
# email marketing
# marketing plan creation
# marketing campaign planning
# agile marketing
# marketing strategy
# marketing analytics
# digital marketing strategy  campaign management  analytics interpretation
# influencer marketing
# twitter marketing
# data analysis  google analytics  marketing
# marketing planning
# content marketing
# film marketing
# campaign personalization
#
# Cluster 61:
# soldering techniques
# feedback delivery techniques
# negotiation techniques
# refactoring techniques
# additive manufacturing techniques
# visual effects techniques
# deployment techniques
# evaluation techniques
# simulation techniques
# subnetting techniques
# data preparation techniques
# patching techniques
# localization techniques
# facilitation techniques
# persuasion techniques
# motivation techniques
# green building techniques
# dockerization techniques
# backup and recovery techniques
# recording techniques
# exception handling techniques
# lighting techniques
# manufacturing techniques
# clustering techniques
# questioning techniques
# exploitation techniques
# value estimation techniques
# tracking techniques
# management techniques
# c# interview techniques
# wavelet analysis techniques
# data mining techniques
# meta-analysis techniques
# ethical hacking techniques
# fabrication techniques
# brainstorming techniques
# mixing techniques
# advanced git techniques
# malware analysis techniques
# advanced drum recording techniques
# java profiling techniques
# regression techniques
# sampling techniques
# scanning techniques
# interviewing techniques
# supervised learning techniques
# collaboration techniques
# intervention techniques
# compositing techniques
# coaching techniques
# threading techniques
# eurorack patching techniques
# dockerization
# subnetting
# candidate screening  interviewing  sourcing
# composite fabrication
# defect tracking
# value estimation
# ip subnetting
# wordpress localization
# ethical hacking
# brainstorming
# clustering
# laser scanning
# c# interviewing
# k-means clustering
#
# Cluster 62:
# json parsing
# json manipulation
# python xml/json/web
# json processing
# json binding
# parse json data
# xml/json parsing
# json mapping
# json-b
# json-b development
# json handling
# json-b serialization
# exception handling
# http request handling
# attribute handling
# tuple handling
# solution mapping
# linq for xml
# xml querying
# concept mapping
# request handling
# event handling
# serialization
# incident handling procedures
# error handling
# incident handling
#
# Cluster 63:
# analytics engineering
# data engineering fundamentals
# big data architecture
# data engineering concepts
# big data
# big data analytics
# data pipeline engineering
# big data management
# data engineering
# big data  architecting  engineering
# data engineering principles
# big data engineering
# batch data engineering
# big data processing
# big data analysis
# big data batch processing
# hadoop  spark  analytics
# manage engineering teams
# predictive analytics
# analytics
# engineering mindset
# site reliability engineering
# engineering calculations
# feature engineering
#
# Cluster 64:
# world building
# developing web apps
# build ios apps with coreml
# develop web apps
# circuit building
# build full-stack web apps
# building ai-based apps
# deploy django apps
# building modular synthesizers
# self-confidence building
# building web apps
# creating react apps
# culture building
# recommender system building
# package apps
# building resilience
# create react apps
# audience building
# partnership building
# build web apps
# building apps with ai tools
# deploying django apps
# confidence building
# build android apps
# community building
# creating progressive web apps
# power apps development
# building recommender systems
# senior relationship building
# deploy web apps
# build react apps
# building sortable tables
# self-reliance
# self-discovery
# self-confidence
# creating responsive websites
# creating pivot tables
# circuit interfacing
# self-belief
# public speaking confidence
# develop self-awareness
# self-belief and entrepreneurship
#
# Cluster 65:
# functional thinking
# recursive thinking
# engineering thinking
# functional thinking  lambda expressions  recursion
# backward thinking
# big picture thinking
# creative thinking
# computational thinking
# strategic thinking
# product-centric thinking
# algorithmic thinking
# critical thinking
# algorithmic trading
# computational fluid dynamics
#
# Cluster 66:
# test-driven development
# test creation
# test automation frameworks
# test planning
# test case creation
# python test automation
# test management
# test case writing
# test execution
# test automation with python
# test writing
# test failure analysis
# c# test-driven development
# test case management
# test driven development
# python test design
# test automation
# test framework
# soapui test automation
# selenium test automation
# test planning and execution
# test case design
# test reporting
# python programming for test automation
# writing test cases
# cucumber test automation
# test design
# test plan development
# narrative writing
# writing a strong hook
# technical writing
# bug writing
# writing bdd scenarios
# writing tests
# dast execution
# writing automated tests
# writing mastery
#
# Cluster 67:
# python functional programming
# basic programming concepts
# functional programming  lambda expressions  recursion
# javascript functional programming
# programming concepts
# functional programming
# java functional programming
# functional programming principles
# evolutionary concepts
# functional programming concepts
# functional constructs
# routing concepts
# recursion
# quantum computing concepts
# linear algebra concepts
# artificial intelligence concepts
# physics concepts
# threading concepts
# tensorflow concepts
#
# Cluster 68:
# kubernetes
# kubernetes deployment
# kubernetes management
# kubernetes fundamentals
# kubernetes cluster management
# kubernetes security
# kubernetes administration
# kubernetes orchestration
# kubernetes microservices deployment
# kubernetes provisioning
# kubernetes cluster provisioning
# openshift container orchestration
# container orchestration
#
# Cluster 69:
# customer experience
# manage customer relationships
# customer relationship management
# customer satisfaction
# customer expansion
# customer engagement
# customer onboarding
# customer experience management
# customer segmentation
# customer relations
# customer retention
# customer centricity
# audience segmentation
# stakeholder engagement
# community engagement
#
# Cluster 70:
# solving coding challenges
# coding in python
# ai development without coding
# matlab coding
# hdl coding
# secure coding practices
# python coding
# coding proficiency
# quick coding
# ai-assisted coding
# secure coding
# python coding proficiency
# verilog hdl coding
# coding
# verilog coding
# coding basics
# javascript coding
# high-performance coding
# secure devices
# high availability
# verilog for fpga
# developing fpga with verilog
#
# Cluster 71:
# concurrency management
# android concurrency
# concurrency  parallelism  scalability
# concurrency programming
# threading and concurrency
# threading and concurrency in android
# concurrency and multithreading
# java concurrency and parallelism
# concurrency control
# concurrency principles
# c++ concurrency
# concurrency in go
# go concurrency and high-performance
# concurrency
# multithreading  concurrency  performance
# concurrency and parallelism in java
# handle concurrency
# go concurrency
# concurrency and parallelism
# java concurrency
# multithreading and concurrency
# vocal control
# version control
# asynchronous programming  event-driven architecture  concurrency
# parallelism
# call control
# loop control
# source control
#
# Cluster 72:
# basic computer operations
# computer architecture
# computer vision
# computer hardware knowledge
# vision processing
# raspberry pi computer vision
# computer maintenance
# computer vision techniques
# computer vision algorithms
# computer hardware installation
# computer-aided design
# raspberry pi setup
# pc maintenance
# system maintenance
# hardware maintenance
# hardware installation
#
# Cluster 73:
# computer troubleshooting
# macos troubleshooting
# troubleshooting techniques
# linux troubleshooting
# midi troubleshooting
# agile troubleshooting
# troubleshooting hardware
# network device troubleshooting
# troubleshooting pc issues
# computer hardware troubleshooting
# troubleshooting os
# advanced troubleshooting
# troubleshooting  wiring  soldering
# device troubleshooting
# troubleshooting cisco devices
# troubleshooting vsphere
# troubleshooting computer issues
# wireless network troubleshooting
# troubleshooting networks
# troubleshooting windows 11
# version control  collaboration  troubleshooting
# basic vsphere troubleshooting
# hardware troubleshooting  component identification  system assembly
# windows 11 troubleshooting
# troubleshooting macos issues
# troubleshooting
# troubleshooting windows
# hardware troubleshooting
# vmware troubleshooting
# windows troubleshooting
# network troubleshooting
# ios device troubleshooting
# pc troubleshooting
# troubleshooting hardware and software
# system troubleshooting
# wireless troubleshooting
# cloud troubleshooting
# network design and troubleshooting
#
# Cluster 74:
# tkinter gui development
# gui programming
# gui creation
# javafx gui design
# gui testing
# python gui development
# gui development with tkinter
# ...
# natural language processing
#
# Cluster 112:
# hardware architecture understanding
# signal flow understanding
# toolchain understanding
# sharepoint framework understanding
# language understanding
# security framework understanding
# understanding computer hardware
# natural language understanding
# understanding azure architecture
# azure architecture understanding
# signal decomposition
# control flow
# hardware diagnostics
# hardware interfacing
# sharepoint framework
# repair hardware
# install hardware
# develop fpga hardware
# troubleshoot hardware
# developing sharepoint framework
#
# Cluster 113:
# java microservices development
# azure microservices development
# develop microservices
# deploy microservices
# graalvm microservices
# microservices architecture
# cloud microservices development
# developing microservices
# java microservices
# microservices development
# grpc  protocol buffers  microservices
# deploying microservices
# creating microservices
# microservices security
# communicate with microservices
# dockerizing microservices
# microservices
# microservices deployment
# create microservices
# microservices design
# communicate with websockets
# go protocol buffers
# protocol buffers
#
# Cluster 114:
# kotlin language
# manage data with kotlin
# kotlin app development
# kotlin programming
# kotlin development
# kotlin fundamentals
# kotlin
# kotlin basics
# manage stress
# manage ansible
# manage users
# manage active directory
# manage change effectively
# manage workloads
# manage dhcp
# manage construction activities
# manage supply chains
#
# Cluster 115:
# php data manipulation
# java arrays manipulation
# sound envelope manipulation
# java array manipulation
# xml manipulation
# javascript object manipulation
# data manipulation
# envelope manipulation
# object manipulation
# jquery dom manipulation
# array manipulation
# binary manipulation
# dom manipulation
# string manipulation
# xml data manipulation
# image manipulation with tensorflow
# css manipulation
# image manipulation
# matrix manipulation
# pandas data manipulation
# faster pandas
# object tracking
# object recognition
# object detection
#
# Cluster 116:
# page object modeling
# stochastic process modeling
# parametric modeling
# rhinocam modeling
# bim modeling
# regression modeling
# business modeling
# polymer modeling
# stochastic modeling
# cnc topographic site modeling
# financial modeling
# modeling techniques
# data modeling
# classification modeling
# statistical modeling
# building information modeling
# automl modeling
# building site modeling
# predictive modeling
# inventor modeling
# modeling market prices using stochastic processes with wolfram language: stochastic modeling  financial analysis  data visualization
# cassandra data modeling
# nlp modeling
# language modeling
# advanced 3d modeling
# graph data modeling
# building information modeling (bim)
# advanced modeling techniques
# simulation modeling
# decision tree modeling
# domain modeling
# modeling data
# beam modeling
# mathematical modeling
# advanced modeling
# shell modeling
# 3d modeling
# ai modeling
# threat modeling
# mongodb data modeling
# solidworks modeling
# logistic regression
# threat mitigation
# linear regression
# threat detection
# insider threat mitigation
#
# Cluster 117:
# product lifecycle management
# product development
# product roadmap creation
# product ideation
# product management
# product planning
# product strategy
# product visioning
# react component lifecycle
#
# Cluster 118:
# grpc protocol
# grpc
# grpc for python
# grpc framework utilization
# grpc framework
# grpc framework implementation
# grpc fundamentals
# grpc implementation
# grpc development
# grpc microservice development
# grpc framework usage
# grpc in python
# grpc in go
# grpc python implementation
# protocol buffer
# jsf 2.3 framework
# react framework
# angular framework
# using testng framework
# scrum framework
# framework selection
# django framework utilization
# agile scrum framework
# robot framework
# go protocol buffer
# flask framework
# testng framework
#
# Cluster 119:
# parallel computing
# parallel processing
# parallel programming
# python parallel programming
# scientific computing
# quantum computing
# micropython physical computing
# edge computing
#
# Cluster 120:
# cross-platform compatibility
# platform development
# platform navigation
# cross-platform collaboration
# azure data platform management
# cloud platform development
# sap cloud platform knowledge
# cloud platform knowledge
# cross-platform device management
# c# cross-platform development
# cross-platform development
# cross-platform app development
# cross-platform java development
# cross-platform application development
# sap ariba supply chain collaboration
# sap navigation
# sap erp navigation
# industry knowledge
# sap bi/bw knowledge
# sustainability knowledge
# metalworking knowledge
# sap fiori navigation
# jvm knowledge
# sap fiori knowledge
#
# Cluster 121:
# xaml programming
# xaml coding
# xaml syntax
# xaml markup
# xaml content creation
# xaml content
# c++ syntax
# c# syntax
# advanced c# syntax
#
# Cluster 122:
# java ee 8 development
# java ee frameworks
# java ee development
# java ee application server deployment
# java ee architecture
# jakarta ee servlet development
# java ee application server administration
# java ee framework usage
# java ee framework
# java ee fundamentals
# java ee application deployment
# java ee packaging
# java ee 8 fundamentals
# java ee application server management
# java ee server configuration
# java ee application development
# java ee application servers
# java ee essentials
# jakarta ee application development
# iphone and ipad essentials
# xcode essentials
# mlops essentials
#
# Cluster 123:
# risc-v assembly programming
# write assembly
# system assembly
# coding in assembly language
# component assembly
# assembly language programming
# assembly language integration
# assembly language  microprocessors  architecture
# modular synthesizer assembly
# assembly language
# programming in assembly language
# assembly programming
# c# language enhancements
# language transition
# language conversion
# hardware description language
#
# Cluster 124:
# workflow mobilization
# workflow optimization
# workflow management
# workflow automation
# grunt.js workflow automation
# alias workflow
# web project workflow automation
# project workflow management
# git workflow
# git collaboration
# git version control
#
# Cluster 125:
# multithreading  concurrency  synchronization
# selenium synchronization
# concurrency  synchronization  parallelism
# synchronization strategies
# concurrency  synchronization  performance
# concurrency  parallelism  synchronization
# concurrency  synchronization  memory management
# concurrency  synchronization  threading
# thread synchronization
# synchronization
# synchronization techniques
# threading  synchronization  concurrency
# threading
# threading and grand central dispatch
# ios threading
# threading and dispatch
#
# Cluster 126:
# javascript framework
# javascript mastery
# javascript
# javascript looping
# javascript basics
# javascript compilation
# javascript objects
# javascript optimization
# vanilla javascript development
# javascript programming
# javascript fluency
# full-stack javascript development
# javascript animations
# javascript frameworks
# javascript event handling
# debug javascript
# javascript interoperability
# javascript development
# javascript async programming
# async javascript
# understanding javascript scope
# javascript fundamentals
# react and javascript
# debug javascript code
# javascript scoping rules
# javascript bundling
# tensorflow with javascript
# javascript scope
# c decision-making and looping
# looping
# regular expression mastery
#
# Cluster 127:
# virtualization security management
# cloud architecture  virtualization  data management
# virtualization management
# virtualization techniques
# virtualization
# linux virtualization
# network virtualization
# virtualization using virtualbox
# using c# attributes
# using lombok
# using ci tools
# using junit
#
# Cluster 128:
# cloud infrastructure automation
# oracle cloud infrastructure operations
# cloud infrastructure
# cloud infrastructure provisioning
# manage cloud infrastructure
# cloud infrastructure architecture
# cloud infrastructure management
# cloud infrastructure knowledge
# cloud infrastructure operations
# scalable cloud infrastructure
# matrix operations
# crud operations
# manage operations
# numerical operations with numpy
# git operations
#
# Cluster 129:
# social media strategy
# social media and digital hiring
# social media optimization
# web media creation
# social media leadership
# social media management
# social media marketing
#
# Cluster 130:
# supply chain optimization
# route optimization
# performance optimization  resource management  system monitoring
# algorithm optimization
# job search optimization
# road optimization
# data optimization
# productivity optimization
# simulation optimization
# seo optimization
# process optimization
# cost optimization
# system performance optimization
# graalvm optimization
# apple device optimization
# campaign optimization
# linux optimization
# redis optimization
# performance optimization
# query optimization
# linux performance optimization
# optimization techniques
# web optimization
# search engine optimization
# google ads optimization
# design optimization
# web tool optimization
# python performance optimization
# java optimization
# system optimization
# network optimization
# web performance optimization
# java performance optimization
# pandas optimization
# optimize system performance
# productivity
# performance improvement
# performance measurement
# monitor system performance
# high-performance
# live looping performance
#
# Cluster 131:
# web and mobile testing
# appium mobile testing
# mobile application development
# javascript  game development  mobile programming
# build mobile apps
# developing mobile apps with xamarin
# mobile testing
# mobile app development
# android development  aws integration  mobile app creation
# mobile automation
# java for all platforms desktop  web  and mobile development
# mobile app design
# troubleshooting mobile devices
# mobile development
# mobile app testing
# collaboration app setup
# app migration planning
#
# Cluster 132:
# plc troubleshooting
# plc sequencing
# plc input sensing
# plc programming
# plc simulation
# factory simulation
# music sequencing
# advanced simulation
# car physics simulation
# simulation
#
# Cluster 133:
# unit testing
# alpha testing in agile
# network penetration testing
# performance testing
# testing tools
# unit testing  debugging  troubleshooting
# software testing fundamentals
# usability testing
# software testing tools
# manual testing
# selenium testing
# software testing techniques
# performance and load testing
# secure software testing
# rspec testing
# web application security testing
# robot framework testing
# agile testing
# software testing tool selection
# web application penetration testing
# exploratory testing
# manual testing techniques
# web testing
# appium testing
# penetration testing
# software testing
# android app security testing
# exploratory testing techniques
# hypothesis testing
# ruby testing
# cypress testing
# security testing
# automated testing
# testing
# alpha testing
# app penetration testing
# testing techniques
# automated security testing
# load balancing
#
# Cluster 134:
# advanced automation scripting
# bash shell scripting
# scripting
# python scripting
# powershell scripting
# automation scripting
# advanced routing
# advanced ip routing
# advanced apis
# advanced routing protocols
#
# Cluster 135:
# solidworks cam
# cam software usage
# cam integration
# cam programming
# cam operations
# cam fundamentals
#
# Cluster 136:
# lean six sigma tools
# six sigma methodologies
# lean six sigma leadership
# lead lean six sigma programs
# lean six sigma management
# six sigma
# six sigma principles
# ci tools
# scrum methodologies
# agile methodologies
# profiling tools
# collaboration tools
#
# Cluster 137:
# add dynamic content
# dynamic content
# dynamic web content
# content management
# produce engaging online content
# website content management
# content creation
# build dynamic websites
#
# Cluster 138:
# windows server management
# c++ server development
# windows server administration
# server-side programming
# managing windows server 2022
# server security
# server-side development
# windows server security
# grpc client/server development
# hybrid server management
# server configuration
# web server configuration
# web server management
# sql server management
# windows server configuration
# server migration
# java server faces
# server management
# grpc client-server development
# server maintenance
# windows server installation
# web server development
#
# Cluster 139:
# networking design
# cloud networking
# networking
# azure networking design
# enterprise networking
# azure networking
# low-power wireless networking
# networking fundamentals
# azure networking solutions design
# networking concepts
# networking configuration
# linux networking
# networking skills
# cisco networking
# storage networking
# networking  communication  job search
# linux networking configuration
# wireless networking
# troubleshoot cisco ios
# monitor azure solutions
#
# Cluster 140:
# mobile endpoint management
# endpoint management
# endpoint security design
# endpoint security
#
# Cluster 141:
# photography exposure
# photography basics
# photography
# time-lapse photography
#
# Cluster 142:
# react native development
# cloud native development
# cloud-native application development
# deploying cloud native java apps
# cloud-native app development
# cloud native application design
# cloud native application development
# kubernetes and cloud-native security
# cloud native
# java development for cloud-native applications
# cloud-native development
# cloud-native java development
#
# Cluster 143:
# model deployment
# model development
# large language model training
# automl model building
# model evaluation
# ml model building
# model management
# model market prices
# model optimization
# model selection
# model design
# nlp model building
# model building
# ai model building
# css box model
# complex model creation
# model training
# ai model training
# model creation
# tensorflow model creation
# slide creation
# patch creation
# nlp with tensorflow
# market to healthcare industry
# portfolio creation
# 2d drawing creation
# spreadsheet creation
# lazy evaluation
# dashboard creation
# automl
# excel spreadsheet creation
# object creation
# pivot table creation
# long document creation
# table creation
# static site creation
# documentary creation
# market research
# microservice creation
#
# Cluster 144:
# security program development
# information security program management
# privacy program development
# information security program
# cybersecurity program management
# security program management
# program planning
# program management
# information asset protection
# information organization
# privacy law compliance
#
# Cluster 145:
# database querying
# database migration
# database query optimization
# aws database management
# java database access
# database access
# apache ignite database management
# database design
# distributed database management
# database backup and recovery
# oracle database multitenant architecture
# java database management
# database programming
# vector database management
# cloud database management
# mongodb database management
# sqlite database management
# database design and deployment
# database selection
# aws database design
# database security
# azure database management
# database recovery
# nosql database management
# database optimization
# database connectivity
# nosql database migration
# cloud database migration
# oracle database management
# database access with hibernate
# database management
# ip connectivity
# query nosql databases
# disaster recovery
# access control
# nosql databases
# connectivity
# backup and recovery
#
# Cluster 146:
# use grpc
# use github for job search
# use postman
# use teradata vantage
# use webpack
# use selinux
# use aws services
# rpa use case analysis
# use c++ with web servers and apis
# monitor servers
# working with apis
# calling apis
# manage servers
#
# Cluster 147:
# envelope synthesis
# audio synthesis skills
# asdr envelope synthesis
# modular synthesis
# audio synthesis techniques
# audio synthesis fundamentals
# modular synthesis fundamentals
# eurorack synthesis
# synthesis techniques
# eurorack modular synthesis
# audio synthesis
# advanced audio synthesis techniques
# modular synthesis techniques
# understanding audio synthesis
# analog synthesis
# synthesis fundamentals
# sound synthesis
# modular patching
# analog circuit interfacing
# modular synthesizer setup
# synthesizing asdr envelopes
# eurorack expansion
# envelope shaping
# eurorack patching
# analog interfacing
# interfacing with analog devices
# asdr envelopes
# patching modular synthesizers
# synthesizer envelope modulation
#
# Cluster 148:
# efficient python programming
# efficient coding
# efficient programming
#
# 12
# 134

# %% [markdown]
# # Giving a Name to each Cluster with Gemini API:

# %%
import time
model = genai.GenerativeModel('gemini-pro')
clusters = {}
for cluster_id, skills_in_cluster in enumerate(clustered_skills):
    prompt = "name this skill cluster, give unique name:" + str(skills_in_cluster)
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            # Only one candidate for now.
            candidate_count=1,
            temperature=0.7
        )
    )
    time.sleep(1.5)
    clusters[cluster_id] = response.parts[0].text

# %% [markdown]
# Handling Duplicate Names (if exist):

# %%
def print_duplicates(lst):
    seen = set()
    duplicates = set()

    for index,item in enumerate(lst):
        if item in seen:
            duplicates.add((item,index))
        else:
            seen.add(item)

    for dup in duplicates:
      prompt = f"give this skill cluster: {clustered_skills[dup[1]]}, a different name than:"+str(dup[0])
      response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            # Only one candidate for now.
            candidate_count=1,
            temperature=0.7
        )
    )
    time.sleep(1.5)
    clusters[dup[1]] = response.parts[0].text



# Example usage:

print_duplicates(list(clusters.values()))

# %%
for key,val in clusters.items():
    clusters[key]=val.replace('*', '')
# Out:
# 149

# %%
print(copy_list)
print(clusters)
# Out:
# [['parsing protobuf messages', 'sending messages', 'rigging', 'programmatic advertising', 'unlearn silence', 'servlets', 'facial retouching', 'rpm distribution', 'merge conflict resolution', 'conflict resolution', 'bias mitigation', 'logical reasoning', 'attributes', 'asking questions', 'organizational alignment', 'foster inclusivity', 'uncovering unconscious bias', 'generating ideas', 'mindset', 'bookkeeping', 'laser cutting', 'messaging with jms', 'focus', 'lombok annotations', 'linear algebra', 'enhanced concentration', 'trauma-informed care', 'recognize hazards', 'cinema 4d', 'vba', 'argumentation', 'e-commerce', 'mental fortitude', 'procurement', 'geometric dimensioning', 'sourcing candidates', 'dimensioning and tolerancing', 'identify root causes', 'camera settings', 'ssh tunneling', 'communicating over rpc', 'sketching', 'values alignment', 'schematic capture', 'goal achievement', 'photoshop rendering', 'exploit vulnerabilities', 'websockets', 'authorization', 'habit formation', 'pulse width modulation', 'camera mounting', 'enhance c#', 'workplace inclusivity', 'xml parsing', 'pitch effectively', 'guitar scales', 'requirements elicitation', 'mandolin playing', 'public speaking', 'edit ebooks', 'mental health awareness', 'fostering diversity', 'upskilling and reskilling', 'sight reading', 'conditional statements', 'ip addressing', 'linkedin advertising', 'c# attributes', 'mechanics', 'c# enhancements', 'play mandolin', 'grand central dispatch', 'testng assertions', 'containerization', 'identify threats', 'budgeting', 'leading teams', 'message brokering', 'candidate sourcing', 'mentor junior managers', 'testng', 'voice over ip', 'requirements gathering', 'sdks', 'regular expression matching', 'facial recognition', 'focus and concentration', 'maya', 'artificial intelligence'], ['data structure knowledge', 'dynamic data structure', 'data structure analysis', 'data structure implementation', 'data structure fundamentals', 'data structure basics', 'data structure creation', 'data structure manipulation', 'data structure concepts', 'go data structure implementation', 'data structure design', 'data structure management'], ['software troubleshooting', 'software development life cycle', 'rhinocam software', 'software development fundamentals', 'install software', 'software development tools', 'software design', 'software development principles', 'agile software development', 'software quality assurance', 'software architecture design', 'software architecture', 'altium software', 'debugging software', 'software architecture principles', 'software security compliance', 'legacy software management', 'software design principles', 'secure software development', 'software installation', 'software development', 'gaap compliance', 'accounting cycle'], ['container security', 'data security', 'wireless network security', 'information security auditing', 'laptop security management', 'it security management', 'network security concepts', 'security design', 'network security analysis', 'security planning', 'security auditing', 'security incident response', 'cryptography and network security', 'web security protocols', 'network security management', 'enterprise network security', 'network security', 'systems security', 'security audit', 'android security', 'saas security management', 'open source security', 'data analytics security', 'implement security', 'security protocols', 'asset security', 'implementing network security measures', 'microservice security', 'security operations management', 'security engineering', 'security operations', 'security policy development', 'spring security', 'saas security', 'systems and application security', 'data security design', 'security management', 'security concepts', 'aws security governance', 'security', 'web security', 'security governance', 'it security auditing', 'system security', 'incident response', 'compliance auditing', 'public policy', 'it governance'], ['deep learning  tensorflow  model depl ...
# {0: 'Technical Proficiency', 1: 'Data Structures and Algorithms', 2: 'Software Engineering', 3: 'Cybersecurity', 4: 'Deep Learning Expertise', 5: 'Code Engineering', 6: 'Embedded Systems', 7: 'Cloud and Linux Storage Management', 8: 'Cybersecurity Career Advancement', 9: 'Business Strategy and Planning', 10: 'Technical Software Proficiency', 11: 'IT Certification Preparation', 12: 'IT Management', 13: 'IT Fundamentals', 14: 'Communication and Interpersonal Skills', 15: 'Automation Engineering', 16: 'Data Validation and Manufacturing', 17: 'Data Analytics Suite', 18: 'Software Development Best Practices', 19: 'Network Expertise', 20: 'Ruby on Rails Development', 21: 'Integration Expertise', 22: 'Project Management and Resource Allocation', 23: 'Cloud and Web Services Technologies', 24: 'API Development and Integration', 25: 'HTML Fundamentals', 26: 'Java Mastery', 27: '.NET Development Fundamentals', 28: 'Node.js Full-Stack Development', 29: 'Engineering and Design Best Practices', 30: 'Customer Service Excellence', 31: 'Risk and Vulnerability Management', 32: 'Cloud and Enterprise Architecture', 33: 'Digital Literacy and Technology', 34: 'Sales Management and Optimization', 35: 'Application Development and Deployment', 36: 'Forecasting and Financial Management', 37: 'Cloud and Web Service Management', 38: 'Software Design Patterns', 39: 'Machine Learning and Data Science', 40: 'Database Expertise', 41: 'Data Analysis and Library Expertise', 42: 'Audio Engineering and Production', 43: 'Content Creation and Production', 44: 'Foundation Skills', 45: 'Front-End Development Cluster', 46: 'Linux Kernel Mastery', 47: 'IT Administration', 48: 'Team Dynamics and Collaboration', 49: 'Computer-Aided Design (CAD) Expertise', 50: 'Serverless Architecting and Development', 51: 'AI Expertise', 52: 'AI Deployment', 53: 'Virtualization Expertise', 54: 'Concurrency and Multithreading', 55: 'Software Engineering Cluster', 56: 'Data Engineering and Management', 57: 'Spring Boot Expertise', 58: 'Cloud Engineering and Management', 59: 'ASP.NET and Angular Development', 60: 'Marketing Tech and Strategy', 61: 'Technical Techniques', 62: 'JSON Expertise', 63: 'Big Data and Data Engineering', 64: 'App Development and Building', 65: 'Computational Reasoning', 66: 'Test Engineering', 67: 'Functional Programming and Programming Concepts', 68: 'Kubernetes Cluster Management and Orchestration', 69: 'Customer Relationship Management (CRM)', 70: 'Coding Expertise', 71: 'Concurrency Management', 72: 'Computer Technology', 73: 'Troubleshooting Proficiency', 74: 'GUI Development and Automation', 75: 'Operating Systems Expertise', 76: 'Webpack Configuration and Usage', 77: 'Ideation and Prototyping', 78: 'Front-End Web Development', 79: 'Design Engineering', 80: 'Data Foundations and Algorithmics', 81: 'Data Manipulation and Querying', 82: 'Linux Device Driver Development', 83: 'Implementation Skills', 84: 'Configuration Management', 85: 'IoT Mastery', 86: 'Leadership Excellence', 87: 'Animation Mastery', 88: 'Infrastructure Engineering', 89: 'Debugging and Troubleshooting', 90: '3D Printing and Visualization', 91: 'Data Science and Technology', 92: 'Caching and Data Retrieval', 93: 'Web Development', 94: 'Visual Media Management', 95: 'Programming Paradigms', 96: 'Recommendation Systems and Algorithms', 97: 'Problem-Solving and Computation', 98: 'Natural Language Processing (NLP) and Text Analytics', 99: 'Infrastructure Monitoring', 100: 'Windows 10 Administration and Deployment', 101: 'Interpersonal and Communication Skills', 102: 'Electrical Design and MEP Expertise', 103: 'Data Visualization and Analysis', 104: 'DevOps Engineering', 105: 'Cisco Device Management and Maintenance', 106: 'Intelligent Content Creation', 107: 'Web Development Expertise', 108: 'Python Development', 109: 'Technical Support and User Experience', 110: 'IDE Proficiency and Navigation', 111: 'Java Stream Processing', 112: 'Hardware and Software Engineering', 113: 'Microservices Developm ...

# %%
cluster_dict ={}
for index,cluster in enumerate(copy_list):

  cluster_dict[clusters[index]] = cluster

print(cluster_dict)
# Out:
# {'Technical Proficiency': ['parsing protobuf messages', 'sending messages', 'rigging', 'programmatic advertising', 'unlearn silence', 'servlets', 'facial retouching', 'rpm distribution', 'merge conflict resolution', 'conflict resolution', 'bias mitigation', 'logical reasoning', 'attributes', 'asking questions', 'organizational alignment', 'foster inclusivity', 'uncovering unconscious bias', 'generating ideas', 'mindset', 'bookkeeping', 'laser cutting', 'messaging with jms', 'focus', 'lombok annotations', 'linear algebra', 'enhanced concentration', 'trauma-informed care', 'recognize hazards', 'cinema 4d', 'vba', 'argumentation', 'e-commerce', 'mental fortitude', 'procurement', 'geometric dimensioning', 'sourcing candidates', 'dimensioning and tolerancing', 'identify root causes', 'camera settings', 'ssh tunneling', 'communicating over rpc', 'sketching', 'values alignment', 'schematic capture', 'goal achievement', 'photoshop rendering', 'exploit vulnerabilities', 'websockets', 'authorization', 'habit formation', 'pulse width modulation', 'camera mounting', 'enhance c#', 'workplace inclusivity', 'xml parsing', 'pitch effectively', 'guitar scales', 'requirements elicitation', 'mandolin playing', 'public speaking', 'edit ebooks', 'mental health awareness', 'fostering diversity', 'upskilling and reskilling', 'sight reading', 'conditional statements', 'ip addressing', 'linkedin advertising', 'c# attributes', 'mechanics', 'c# enhancements', 'play mandolin', 'grand central dispatch', 'testng assertions', 'containerization', 'identify threats', 'budgeting', 'leading teams', 'message brokering', 'candidate sourcing', 'mentor junior managers', 'testng', 'voice over ip', 'requirements gathering', 'sdks', 'regular expression matching', 'facial recognition', 'focus and concentration', 'maya', 'artificial intelligence'], 'Data Structures and Algorithms': ['data structure knowledge', 'dynamic data structure', 'data structure analysis', 'data structure implementation', 'data structure fundamentals', 'data structure basics', 'data structure creation', 'data structure manipulation', 'data structure concepts', 'go data structure implementation', 'data structure design', 'data structure management'], 'Software Engineering': ['software troubleshooting', 'software development life cycle', 'rhinocam software', 'software development fundamentals', 'install software', 'software development tools', 'software design', 'software development principles', 'agile software development', 'software quality assurance', 'software architecture design', 'software architecture', 'altium software', 'debugging software', 'software architecture principles', 'software security compliance', 'legacy software management', 'software design principles', 'secure software development', 'software installation', 'software development', 'gaap compliance', 'accounting cycle'], 'Cybersecurity': ['container security', 'data security', 'wireless network security', 'information security auditing', 'laptop security management', 'it security management', 'network security concepts', 'security design', 'network security analysis', 'security planning', 'security auditing', 'security incident response', 'cryptography and network security', 'web security protocols', 'network security management', 'enterprise network security', 'network security', 'systems security', 'security audit', 'android security', 'saas security management', 'open source security', 'data analytics security', 'implement security', 'security protocols', 'asset security', 'implementing network security measures', 'microservice security', 'security operations management', 'security engineering', 'security operations', 'security policy development', 'spring security', 'saas security', 'systems and application security', 'data security design', 'security management', 'security concepts', 'aws security governance', 'security', 'web security', 'security governance', 'it security auditing', 'system security', 'incident response ...

# %% [markdown]
# Saving Clusters to CSV:

# %%
def dict_to_csv(dictionary, filename):
    max_length = max(len(lst) for lst in dictionary.values())
    df = pd.DataFrame({k: pd.Series(v[:max_length]) for k, v in dictionary.items()})
    df.to_csv(filename, index=False)

dict_to_csv(cluster_dict,'all_clustered_skills.csv')

# %% [markdown]
# Downloading Clusters from CSV:

# %%
# Load CSV file into DataFrame
df = pd.read_csv('all_clustered_skills.csv')

# Initialize clustered_skills as a list of empty lists
num_clusters = len(df.columns)
clustered_skills = [[] for _ in range(num_clusters)]

# Iterate over each column (cluster) in the DataFrame
for cluster_id, column_name in enumerate(df.columns):
    cleaned_list = [x for x in df[column_name].tolist() if not pd.isna(x)]
    clustered_skills[cluster_id] = [column_name,cleaned_list]
# Create a dictionary to store clusters
clustered_dict = {cluster[0]: cluster[1] for cluster in clustered_skills}
print(len(clustered_dict))
#print(clustered_dict)

# %%
skill_dict = {}
for key, values in clustered_dict.items():
    for value in values:
        skill_dict[value] = key

print(skill_dict)
print(skill_dict["data strategy"])
# Out:
# {'parsing protobuf messages': 'Technical Proficiency', 'sending messages': 'Technical Proficiency', 'rigging': 'Technical Proficiency', 'programmatic advertising': 'Technical Proficiency', 'unlearn silence': 'Technical Proficiency', 'servlets': 'Technical Proficiency', 'facial retouching': 'Technical Proficiency', 'rpm distribution': 'Technical Proficiency', 'merge conflict resolution': 'Technical Proficiency', 'conflict resolution': 'Technical Proficiency', 'bias mitigation': 'Technical Proficiency', 'logical reasoning': 'Technical Proficiency', 'attributes': 'Technical Proficiency', 'asking questions': 'Technical Proficiency', 'organizational alignment': 'Technical Proficiency', 'foster inclusivity': 'Technical Proficiency', 'uncovering unconscious bias': 'Technical Proficiency', 'generating ideas': 'Technical Proficiency', 'mindset': 'Technical Proficiency', 'bookkeeping': 'Technical Proficiency', 'laser cutting': 'Technical Proficiency', 'messaging with jms': 'Technical Proficiency', 'focus': 'Technical Proficiency', 'lombok annotations': 'Technical Proficiency', 'linear algebra': 'Technical Proficiency', 'enhanced concentration': 'Technical Proficiency', 'trauma-informed care': 'Technical Proficiency', 'recognize hazards': 'Technical Proficiency', 'cinema 4d': 'Technical Proficiency', 'vba': 'Technical Proficiency', 'argumentation': 'Technical Proficiency', 'e-commerce': 'Technical Proficiency', 'mental fortitude': 'Technical Proficiency', 'procurement': 'Technical Proficiency', 'geometric dimensioning': 'Technical Proficiency', 'sourcing candidates': 'Technical Proficiency', 'dimensioning and tolerancing': 'Technical Proficiency', 'identify root causes': 'Technical Proficiency', 'camera settings': 'Technical Proficiency', 'ssh tunneling': 'Technical Proficiency', 'communicating over rpc': 'Technical Proficiency', 'sketching': 'Technical Proficiency', 'values alignment': 'Technical Proficiency', 'schematic capture': 'Technical Proficiency', 'goal achievement': 'Technical Proficiency', 'photoshop rendering': 'Technical Proficiency', 'exploit vulnerabilities': 'Technical Proficiency', 'websockets': 'Technical Proficiency', 'authorization': 'Technical Proficiency', 'habit formation': 'Technical Proficiency', 'pulse width modulation': 'Technical Proficiency', 'camera mounting': 'Technical Proficiency', 'enhance c#': 'Technical Proficiency', 'workplace inclusivity': 'Technical Proficiency', 'xml parsing': 'Technical Proficiency', 'pitch effectively': 'Technical Proficiency', 'guitar scales': 'Technical Proficiency', 'requirements elicitation': 'Technical Proficiency', 'mandolin playing': 'Technical Proficiency', 'public speaking': 'Technical Proficiency', 'edit ebooks': 'Technical Proficiency', 'mental health awareness': 'Technical Proficiency', 'fostering diversity': 'Technical Proficiency', 'upskilling and reskilling': 'Technical Proficiency', 'sight reading': 'Technical Proficiency', 'conditional statements': 'Technical Proficiency', 'ip addressing': 'Technical Proficiency', 'linkedin advertising': 'Technical Proficiency', 'c# attributes': 'Technical Proficiency', 'mechanics': 'Technical Proficiency', 'c# enhancements': 'Technical Proficiency', 'play mandolin': 'Technical Proficiency', 'grand central dispatch': 'Technical Proficiency', 'testng assertions': 'Technical Proficiency', 'containerization': 'Technical Proficiency', 'identify threats': 'Technical Proficiency', 'budgeting': 'Technical Proficiency', 'leading teams': 'Technical Proficiency', 'message brokering': 'Technical Proficiency', 'candidate sourcing': 'Technical Proficiency', 'mentor junior managers': 'Technical Proficiency', 'testng': 'Technical Proficiency', 'voice over ip': 'Technical Proficiency', 'requirements gathering': 'Technical Proficiency', 'sdks': 'Technical Proficiency', 'regular expression matching': 'Technical Proficiency', 'facial recognition': 'Technical Proficiency', 'focus and concentration': 'Technical Proficiency', 'maya': 'Technical Profic ...
# Business Strategy and Planning

# %% [markdown]
# # Cleaning the Degree Field

# %%
def split_and_clean_string(string):
    processed_strings = []
    #for string in given_string:
      # Lowercase the string
    string = string.lower()
      # Delete all digits
    string = re.sub(r'\d', '', string)
    #string = re.sub(r'[^\w\s,]', '', string)
      # Delete "gpa" and "%" substrings
    string = string.replace('gpa', '').replace('%', '').replace("\\", "").replace(".", "").replace("/", "").replace(":", "").replace("*", "").replace("&", "")
      #processed_strings.append(string)
    return eval(string)

# Apply the function to the column of strings using apply
model_df['degree_field'] = model_df['degree_field'].apply(lambda x: split_and_clean_string(x))

# %%
df = pd.read_csv('all_clustered_degree.csv')

# Initialize clustered_skills as a list of empty lists
num_clusters = len(df.columns)
clustered_degree = [[] for _ in range(num_clusters)]

# Iterate over each column (cluster) in the DataFrame
for cluster_id, column_name in enumerate(df.columns):
    cleaned_list = [x for x in df[column_name].tolist() if not pd.isna(x)]
    clustered_degree[cluster_id] = [column_name,cleaned_list]
# Create a dictionary to store clusters
clustered_degree_dict = {cluster[0]: cluster[1] for cluster in clustered_degree}
print(len(clustered_degree_dict))
#print(clustered_dict)

# %%
degree_dict = {}
for key, values in clustered_degree_dict.items():
    for value in values:
        degree_dict[value] = key

print(degree_dict["electrical and electronics engineering"])

def transform_list(lst):
    return [degree_dict.get(item,item) for item in lst]

# Apply the function to create the new column
model_df['degree_field'] = model_df['degree_field'].apply(lambda x: transform_list(x))

# %% [markdown]
# # Performing Clustering on Degree Field:

# %%
random.seed(42)

deg1 = model_df['degree_field'].tolist()
flat_deg1 = [item for sublist in deg1 for item in sublist]
print(flat_deg1)
unique_values = list(set(flat_deg1))
unique_values = [value for value in unique_values if value is not None]
print(unique_values)
vectorizer = TfidfVectorizer(max_df=0.4, min_df=2, lowercase=True)
X = vectorizer.fit_transform(unique_values)

# Step 3: Clustering
num_clusters = 150  # Adjust the number of clusters as needed
kmeans = KMeans(n_clusters=num_clusters, init='k-means++', max_iter=200, n_init=20)
kmeans.fit(X)
# Step 4: Interpretation and printing clusters
cluster_labels = kmeans.labels_  # Get cluster labels for each data point

clustered_degree = [[] for _ in range(num_clusters)]
for deg, label in zip(unique_values, cluster_labels):
    clustered_degree[label].append(deg)

# Print each cluster separately
for cluster_id, deg_in_cluster in enumerate(clustered_degree):
    print(f"Cluster {cluster_id}:")
    for deg in deg_in_cluster:
        print(deg)

    print()
# Out:
# ['business analytics', 'electrical and electronics engineering', 'electrical and electronics engineering', 'mechatronics, robotics, and automation engineering', 'computer science, minor in mathematics', 'management information systems, general', 'computer science', 'information science and engineering', 'electrical and computer engineering', 'mathematics', 'statistics', 'industrial engineering', 'electrical and computer engineering', 'computer science', 'attended as part of the congress-bundestag youth exchange', 'computer speech and language', 'computer science', 'computer science', 'computer science', 'computer engineering', 'electrical enginneering', 'tele-communication engineering', 'theoretical physics', 'theoretical physics', 'e-commerce engineering', 'electrical and electronics engineering', 'electrical engineering', 'logistics technology', 'computer engineering', 'computer science', 'information technology engineering', 'computer science', 'computer science', 'computer science', 'computer science', 'computer science', 'computer engineering', 'computer science', 'informatyka', 'prawo', 'pre-law studies', 'technology management', 'information technology', 'computer software engineering', 'machine learning', 'computer engineering', 'data management and data analytics', 'medical billing and coding', 'computer science', 'computer science', 'computer science', 'computer science', 'computer science', 'computational and applied mathematics', 'business administration', 'information technology', 'computer science', 'business administration and management, general', 'computer science', 'computer software engineering', 'computer science', 'information science and engineering', 'computer science and economics', 'electronics and communication', 'specialization in nvh(noise vibration and harshness)', 'mechanical engineering', 'engineering', 'mechanical engineering', 'project management', 'computer science  engineering', 'discrete algorithms', 'computer science', 'computer science', 'applied mathematics and informatics', 'computer software engineering', 'electrical and electronics engineering', 'mpc', 'sociology', 'applied mathematics', 'economics', 'applied mathematics and economics', 'computer networking', 'electrical engineering', 'applied mathematics', 'computational mathematics', 'information technology', 'electrical and electronics engineering', 'computer software engineering', 'computer science', 'a', 'electrical and electronics engineering', 'electrical engineering', 'information systems', 'computer science', 'mathematics', 'mathematics', 'mathematics', 'honors', 'economics', 'computer science', 'electronics engineering', 'logistics, materials, and supply chain management', 'secondary ed history', '', 'computer science', 'electronics and communications engineering', 'mpc - mathematics, physics and chemistry', 'computer science', 'computer engineering', 'computer engineering', 'electrical and electronics engineering', 'analytics', 'computer science', 'biochemistry and molecular biology', 'clinical medicine', 'business administration, management and operations', 'robotics and artificial intelligence', 'engineering', 'computer science', 'computer science', 'computer science', 'management science  engineering', 'economics', 'electronics engineering', 'biomedical engineering and mathematics', 'computer science', 'computer science', 'computer engineering', 'computer science', 'english', 'computer science', 'computer science', 'information technology', 'computer and information science', 'computer engineering', 'computer engineering', 'schooling', 'computer science', 'electrical and computer engineering', 'mechanical engineering', 'computer science', 'information system', 'operations research', 'mathematics, philosophy', 'computer science', 'information management', 'data science', 'electronics and telecommunication', 'mathematics and science', '', 'computer science', 'brain and cognitive sciences', 'industrial system engineering', ' ...
# ['', 'mathematical and computational science', 'bachelors in technology', 'electrical and system engineering', 'java and cloud computing(aws)', 'electronics and computer tech', 'information systems and management', 'sciences', 'information systems, economics, physics, applicable mathematics, english', 'computer engineering (computer systems)', 'game design and development', 'mechanical engineering, computer science', 'control and instrumentation engineering', 'masters in computer applications', 'german studies', 'internet technologies', 'mechanical engineering, electromechanical', 'ece', 'computer science (mcit)', 'vlsi', 'math statistics and probability', 'electrical and computer engineering - software engineering  system', 'biomedical engineering and mathematics', 'uctech school of design', 'na', 'electronics and telecommunications', 'electronics and communication engineering', 'electromagnetic field and microwave techniques', 'nanotechnology', 'computer networks', 'english literature, political science', 'computer engineer', 'innovation, entrepreneurship, strategy, management, technology', 'business administration and finances', 'organic chemistry', 'german', 'economics and finance', 'organizational leadership', 'environmental geo-science', 'computer vision', 'selling skills and sales operations', 'communications; communication and culture; recruitment chairman', 'philosophy with honors', 'applied data science', 'applied economics and statistics', 'computational biology', 'international baccalaureate', 'computer engineering computer science', 'faculty of economics and administrative sciences', 'applied mathematics and informatics', 'industrial distribution', 'pre-law studies', 'computer programmingprogrammer, general', 'fiber optics', 'opto-electronics information science and engineering', 'electronics and telecommunication', 'actuarial science with computer science minor', 'management science', 'natural science and mathematics', 'telecommunications certificate', 'higher educationhigher education administration', 'electronics technology  systems', 'science stream', 'construction management', 'health sciences,', 'electronics and information science', 'condensed matter and materials physics', 'technology education; graphic communications', "digital modeling in virtual reality at université d'angers", 'engineering', 'electrical and communications engineering', 'businesscommerce, general', 'game design  development', 'technology management', 'business administration and international studies', 'electronics and computer technology engineering', 'statistics and econometrics', 'accounting and finance', 'junior highintermediatemiddle school education and teaching', 'spécialité physique', 'industrial and system engineering', 'information and communication technology', 'communications and signal processing', 'aerospace, aeronautical and astronauticalspace engineering', 'electrical power engineering', 'communication', '| entrepreneurship, strategic management, philosophy of language, data science, physicaldigital art', 'physik', 'computer science (games)', 'electrical', 'radiologic technologyscience - radiographer', 'oregon transfer degre', 'infantry', 'materials science  engineering', 'computer science  electrical engineering', 'electric information engineering', 'mathematics and engineering, control and communications', 'concentrations in small business  political science', 'computer networking and telecommunication systems', 'computer science engineering', 'wireless communications', 'linux  cloud infrastructure technologies  kubernetes  dockers', 'ethnics studies', 'information system', 'cybersecurity, information security', 'security and risk analysis', 'human resources management', 'th standard', 'master in industrial management', 'double electrical engineering and physics', 'information and communication engineering', 'instrumentation and control engineering', 'computer software engineering', 'mit media lab', 'quantitative psych ...
# Cluster 0:
#
# ece
# na
# electromagnetic field and microwave techniques
# german
# organizational leadership
# environmental geo-science
# computer vision
# selling skills and sales operations
# fiber optics
# spécialité physique
# | entrepreneurship, strategic management, philosophy of language, data science, physicaldigital art
# physik
# radiologic technologyscience - radiographer
# oregon transfer degre
# infantry
# mit media lab
# global business  marketing
# mba
# hvacr
# computer coding
# quantitative methods and causal inference in social science
# microelectronics and semiconductor
# a+
# bachelor of applied science in organizational leadership
# ib
# attended as part of the congress-bundestag youth exchange
# oracle intensive program
# public policy analysis
#  ( courses)
# applied science degree - network technician
# classics
# product innovation
# realtime d reconstruction
# aviation
# ingenieria en sistemas de informacion
# mathematic and economic
# certified installer  tuner
# geology
# emergency care attendant (emt ambulance)
# dual degree for bsc organisational communication
# clinical medicine
# autodesk inventor professional
# cse
# informatyka
# rf and microwave engineering
# -
# secondary
# leadership in the public sector
# visiting student
# energy efficiency
# computer and network
# cisco certified internetwork expert (ccie routing  switching) lab training
# pre-engineering
# electric and computer engineering
# java
# aeronautics
# robotics and artificial intelligence
# advertising
# interdisciplinary program with focus in communications, fine arts photography, sociology
# administrative of justice
# urban economic development
# hypokhâgne, khâgne
# college,  years
# mathsscience
# science degree - network administration
# geophysics and seismology
# bachelor's degree
# high schoolsecondary certificate programs
# cinema
#
# prawo
# artificial intelligence
# eie
# finance and transportation  logistics
# architectural engineering
# business analysis
# public health
# cs
# apprentissage statistique
# internet of things engineering
# meteorology
# sociology
# optoelectronic engineering
# medical billing and coding
# hs
# pcmb
# a
# criminology
# medieninformatik
# with distinction
# paralegal
# eecs - solid state physics
# eee
# rf engineering
# registered nursingregistered nurse
# heating, air conditioning, ventilation and refrigeration maintenance technologytechnician
# fire sciencefire-fighting
# 電機工程學系
# private pilot
# internet of things
# cisco certified internetwork expert (ccie voice) lab training
# masters of engineering
# nsw
# nanomicrofabrication, nanowire field-effect transistor
# transportation engineering
# discrete algorithms
# east asian languages, literatures, and linguistics
# regulargeneral high schoolsecondary diploma program
# educationinstructional practice
# alumni
# corporate innovation and entrepreneurship
# visual effects  animation
# mandarin level ii  iii
# engenharia elétrica e eletrônica
# certified
# particle theory
# a+ certification
# geophysics
# computer support specialist
# programación informática, aplicaciones específicas  programmingcomputer architechture, engines
# electrical engineering (rf and microwave)
# gifted program
# electrochemistry
# communiication
# optoelectronics
# public policy
# pure science
#  c
# environmental science
# completed
# computer engineering with hardware concentration
# advanced engineering
# transportation planning and management
# senior
# none
# pastry
# microsoft
# aaaaa
# computers
# unix systems administration
# biostatistics
# electronica
# electrician
# puc
# react
# chemical and biological engineering
# interdisciplinary studies with a depth study in film, computing, and new digital media
# android developement
# economics with financial applications, public policy
# east asian languages and cultures
# oracle cloud
# junior
# packaging value chain
# engenharia de computação
# graduate
# mechano-infomatics
# personal computer technician
# graduate diploma of counselling and psychotherapy
# english with concentration in professional and new media writing
# info
# cityurban, community and regional planning
# school of earth sciences interdisciplinary program in earth energy and environmental science
# orcale
# cumulative   (converts to )
# eecs
# board examinations
# physics part ii  spanish part b
# mobile app testing using appium
# healthhealth care administrationmanagement
# engineering, ai  ml techniques
# forestry
# computer science, concentrating on ai
# chemcial and biomolecular engineering
# electonics
# remote sensing
# study abroad
# double option in "computer information systems" and "production operation mgmt"
# automotivecollision and repair technologytechnicianmanagement
# faculty of foreign languages
# e-commerceelectronic commerce
# packaging science
# pcmc
# computer sc
# geological and earth sciencesgeosciences
# astrophysics
# computer aided drafting
# metallurgical engineering
# robotics
# e-commerce engineering
# pre-health
# microelectronics
# environment and sustainability
# biomathematics
# computer sc  engineering
# microsoft datacenter academy student
# metrology
# material science
# linguistics; russian language and culture
# is-expert - distributed systems
# biochemistry
# product development
# computer science, commerce (double degree)
# softwarové inženýrství
# php,dbms,quantitative techniques,hr mgmt, marketing mgmt,economics,operating system
# schooling
# core musical skills
# electronical
# radio, television  film
# non-medical
# (sardar patel college of engineering)
# training and assessment
# iim-lucknow noida campus
# mscs
# pharmaceutics
# lab technician
# computer science - artificial intelligence
# pcms
# physics, government policy
# educational theatre
# chemical and biomolecular engineering
# petroleum engineering(reservoir simulation)
# japanese, java
# workforce development and training
# d modeling and animation
# chemical and biomolecular engineering, high honors, quantitative finance minor
# media planning, buying  analysis; social media management
# ee
# remote sensing and geophysics
# pcme
# major biomedical eng; minor mechanical eng
# all
# cybernetics
# marketing
# electro-magnetics
# computer science, creative writing
# journalism
# lean six sigma
# computer engineering  society
# d animation
# high schoolsecondary diplomas and certificates
# dynamics and controls
# (ongoing)
# communication and media studies (focus sales  marketing)
# businessoffice automationtechnologydata entry
# n
# stem track
# statistics with emphasis on health science
# public administration
# concentrations in intelligence and theory
# electricalelectronics engineering
# military science
# cis
# genetics
# physics, with certificate in finance, application of computing, applied and computational maths
# application development
# mpc
# 通信工程
# cello performance
# computaional and mathematical engineering
# precision instrument
# computer application
# big data in culture and society
# bioinformatics
# business journalism
# aviation maintenance technology
# technology management - microsoft software and systems academy
# professional certificate
# percentage -
# tertiary entrance rank
# uai
# stem
# law
# outstanding
# petroleum engineering
# primary educatiion till th
#  (dean's list)
# non medical
# bigdata
# energy, environment, and natural resources law
# pharmacology
# entrepreneurial and small business operations
# l (l) tats cable systems  installer-maintainer
# computer systems engineering concentration in internet of things
# creative writing; geographic information systems (gis)
# chemical engineering
# fullstack
# finance and financial management services
# electric engineering
# exchange student- artificial intelligence
#
# Cluster 1:
# electrical and communications engineering
# broadcast communications
# strategic marketing communications
# cisco unified communications
# electrical, electronic and communications engineering technologytechnician
# literature and communications
# network communications and management
# electrical, electronic and communications engineering
#
# Cluster 2:
# natural science and mathematics
# computer engineering, computer science, and mathematics
# mathematics, computer science
# computer science  mathematics
# mathematics and science
# science and mathematics
# computer science and mathematics
# computer science and engineering, mathematics
# computer science; mathematics
# mathematics and computer science
# pure mathematics, computer science
# computer science, mathematics
# mathematics and computer science, computer engineering
# computer engineering; mathematics
#
# Cluster 3:
# space science and engineering
# engineering science and ocean engineering
# nutrition and dietetics
# religion and christian ministry
# polymer science and chemical engineering
# engineering science
# polymer science and engineering
# mining and mineral engineering
# managment science and engineering
# nanoscale science and engineering
# laser and optical engineering
# material science and engineering
#
# Cluster 4:
# electronics technology  systems
# electronics and computer technology engineering
# electronics engineering technology (major), computer science (minor)
# computer electronics technology
# computer engineering technology
# computer science and technology
# electronics design technology
# electronics technology
# electronics and computer technology
#
# Cluster 5:
# double electrical engineering and physics
# nonlinear physics
# public finance (minor physics)
# chemical physics
# engineering physics
# systems engineering, with physics minor
# applied physics
# physics
# engineering physicsapplied physics
# physics; lei zhou
# physics and computer science
# computer science, physics
# physics with electrical engineering
# computer science and physics
#
# Cluster 6:
# geographical information systems
# computer science, information systems
# business information systems
# information systems and decision sciences
# information systems
# accouting information systems
# marketing, information systems
# computer science and information systems
# computer and information systems
# systems and information engineering
# information systems engineering
# computer information systems
# computer science; information systems
#
# Cluster 7:
# maths, physics, chemistry
# maths, physics and chemistry
# maths, physics
# physics, chemistry, maths, economics
# science, maths, hindi, english, social science
# english, physics, chemistry, biology, maths
# english, physics, chemistry, maths and computer science
# maths, physics  chemistry
# maths - science
# science maths
#
# Cluster 8:
# electrical and computer engineering - software engineering  system
# computer software engineering
# computer systems and software
# software development
# computer software engineering and electronics engineering
# computer science  software engineering
# software  teaching
# electrical engineering (computer hardware and software)
# software and robotics
# software engineering; as computer programming; computer programing and engineering
# computer engineering, software engineering
# software engineering technology
# software engineering
# software engineering and systems
# computer science and software engineering
# computer science - software engineering
# electrical and software engineering
# software systems
# computer science, specialty software engineering
#
# Cluster 9:
# mathematics and engineering, control and communications
# control engineering
# ee control theory
# electricalelectronics engineering - control systems (aircraftspacecraft controls)
# electrical engineering (signals, control, and optimization)
# mechanical engineering; mechatronic and intelligent control
# electrical and control engineering
# process equipment and control engineering
# computer science, specialty modeling, cognition and control (mc)
# control science and engineering
# automotic control engineering
#
# Cluster 10:
# information system
# communication  information system
# information management and information system
# information system management
# signal  system
# computer information system - data analytics
# geographical information system
# system software
# very large information system
# network and system administrationadministrator
# earth system science
# unix system administraton
# communication and information system
#
# Cluster 11:
# electrical and system engineering
# industrial and system engineering
# electrical and electronic engineering; computer science and industrial system engineering
# industrial system engineering
#
# Cluster 12:
# computer science  electrical engineering
# electrical  computer engineering
# electrical engineering computer science
# computer engineering, electrical engineering, minor in computer science
# electrical and computer
# electrical and computer engineering (computer vision)
# electrical and computer engineering (ece)
# electrical and computer engineering, systems and computer engineering
# electrical computer digital engineering
# college of electrical engineering  computer science
# electrical and computer engineering, computer science
# electrical engineering (computer network)
# electrical  computer
# electrical engineering  computer science
# electrical engineering and computer science
# electrical and computer engineering (computer engineering)
# electrical engineering and computer sciences
# electrical and computer engineering
# electrical engineering, computer science
# electrical engineering and computer science (eecs)
#
# Cluster 13:
# business analytics and information systems
# analytics
# predictive analytics
# business information  analytics
# marketing analytics
# business analytics
# customer analytics
# advanced analytics
#
# Cluster 14:
# information technology operations management
# operations management and information systems
# operations  information management
# engineering  operations management
# information systems and operations management
# cyberelectronic operations and warfare
# operations management and supervision
# finance, information and operations management, ecommerce management
#
# Cluster 15:
# information and communication technology
# computer science and information technology
# information systems technology
# electromechanical engineering technology
# textile technology
# geo-information science and technology
# information systems and technology (application development concentration)
# multimedia technology
# information technology engineering
# information technology management
# professional information engineering technology
# information technology  management
# electrical engineering and information technology
# applied information technology
# business, technology
# technology entrepreneurship certificate
# information communication and technology
# logistics technology
# computer information technology
# information technology infrastructure
# instructional technology
# food science and technology
# information technology
# information technology - computer network systems
# intelligent science and technology
#
# Cluster 16:
# management science
# aviation management
# infomation management
# theatre management and producing
# engineering management
# engineerng management
# commercial management and quantity surveying
# management science  engineering
# management
# management science and engineering
# engineeringindustrial management
# management, emphasis in experience industry, event and venue management track
# management for scientists and engineers
# reliability engineering and asset management
#
# Cluster 17:
# information systems, economics, physics, applicable mathematics, english
# physics , math , chemistry and english
# mathematics, computer science, physics, chemistry and english
# english, science and mathematics with biotechnology
# subjects chemistry, physics, mathematics, biology, english
# economics, english, chemistry, mathematics, physics
# journalism and english
# english
# english and italian
#
# Cluster 18:
# applied data science
# engineering and applied science
# applied computer science
# applied science and technology
# computer applied technology
# pure and applied science
# applied physics  computer science (minor)
# applied science technology
# applied learning and development
#
# Cluster 19:
# sciences
# faculty of economics and administrative sciences
# health sciences,
# computer sciences
# computational data sciences
# computer and information sciences and support services
# biological sciences and biotechnology
# animal sciences
# mathematics,sciences
# health servicesallied healthhealth sciences, general
# biological sciences
# planetary sciences (subdiscipline of physics)
# brain and cognitive sciences
# major  sciences; minor  mathematics
# opticsoptical sciences
# atmospheric sciences and meteorology
# ceramic sciences and engineering
# environmental sciences
# mathematics and computer sciences
# social sciences
# mathematical sciences
# physical sciences
# computer and information sciences
# pharmaceutical sciences
#
# Cluster 20:
# biomedical engineering and mathematics
# major electrical engineering minor biomedical engineering
# biomedical engineering  computer science
# mechanical engineering, minor biomedical engineering
# electrical engineering, biomedical engineering
# electrical and biomedical engineering
# electrical engineering, specialization in biomedical engineering
# biomedical engineeringbioengineering
# biomedical engineering  computer engineering
# biomedical engineering
# biomedical engineering (mdde)
#
# Cluster 21:
# quantitative psychology
# computer science  psychology
# social organizational psychology
# economics and psychology
# psychology
# honors computer science and psychology
# industrial and organizational psychology
# cognitive psychology
# psychology  computer science
# psychology and social behavior
# computer science, psychology
#
# Cluster 22:
# robotic systems engineering
# systems
# comuter and systems engineering
# systems engineering
# systems and entrepreneurial engineering
#
# Cluster 23:
# cybersecurity, information security
# security and risk analysis
# information security and forensics
# computer information systems; network security
# homeland security
# computer science, security
# network security
# infromation security
# information security
# security management
# security  risk analysis
# certificate in information security management
#
# Cluster 24:
# economics and finance
# economics  computer science
# economics and computer science
# economics, mathematics
# economics financial markets option
# computer science and economics
# economics and management
# finance and economics
# computer science, russian, economics
# mathematics and economics
# economics
# econometrics and quantitative economics
# mathematics, economics
# economics; minor - business
# computer science and government modified with economics
# management and economics
# computer science, economics
# economics, applied economics, econometrics
#
# Cluster 25:
# mechanical engineering, computer science
# mechanical engineering, electromechanical
# mechanical engineering - thermal energy
# electro mechanical technology
# major mechanical engineering minor computer science
# mechanical engineering robotics
# computer science and mechanical engineering
# mechanical engineering
# mechanical engineering and computer science
# mechanical drafting and mechanical drafting cadcadd
# mechanical
# mechanical engineering mechanical engineering; technology ug
# mechanical engineering major and business management minor
# mechanical engineeringmathematics
# mechanical engineering and mathematics
#
# Cluster 26:
# electronics and communication engineering
# electronics  communication
# electronics  communication enggineering
# electronics  communication engineering
# electronics and communication
#
# Cluster 27:
# higher educationhigher education administration
# technology education; graphic communications
# junior highintermediatemiddle school education and teaching
# economics of education
# special education and teaching
# religious education
# education
# elementary education
# primary education
# general education
#
# Cluster 28:
# data science  engineering
# data science and engineering
# data analysis
# data analytics (big data)
# data modelingwarehousing and database administration
# data analyst
# data theory
# data processing
# data science, data analytics, software
# data management and data analytics
# information management - data science
# data science
#
# Cluster 29:
# computer engineering (computer systems)
# computer commucations
# computer science and systems
# computer scienceengineering
# computer technologycomputer systems technology
# systems engineering, computer science minor
# computer and systems engineering
# computer engineering - computer systems
# computer
# computer science (distributed systems group)
# computer systems engineering
# computer science, computer  systems engineering
# computer and video imaging
# computer science, systems option
# computer science - intelligent systems track
#
# Cluster 30:
# business administration and finances
# business administration
# economics and business administration
# business, management, marketing, and related support services
# business administration, marketing
# business administration and management, general
# business administration and team and project management
# business administration, management and operations
# business, management
# business administration and management
# mba business management
# business administration and management,
# business
# business administration and management, marketing
# business administration management
# business management
# business entrepreneurial  management
# business administration, honors, concentrations in finance and management information systems
#
# Cluster 31:
# computer programming
# c programming language
# computer programming and analysis
# programming, mcad
# computer programming and information technology
# python  programming specialization
# computer programming language design and implementation
#
# Cluster 32:
# aerospace, aeronautical and astronauticalspace engineering
# mechanical  aerospace engineering
# mechanical and aerospace engineering
# aerospace, aeronautical and astronautical engineering
# aerospace
# aerospace engineering
#
# Cluster 33:
# theoretical linguistics
# theoretical physics
# linguistics
# computational linguistics
# theoretical mathematics
# theoretical and mathematical physics
# theoretical computer science
# linguistics and computer science
#
# Cluster 34:
# computer programmingprogrammer, general
# businesscommerce, general
# military intelligence, general
# computer and information systems, general
# information systems, general
# marketingmarketing management, general
# general management
# general engineering
# computer science (general)
# computer and information sciences, general
# geologyearth science, general
# finance, general
# biologybiological sciences, general
#
# Cluster 35:
# fashionapparel design
# electrical and computer engineering, integrated circuit design
# multimediaweb design
# computer science, design
# digital hardware design
# design engineering
# asic design and test
# autodesk inventor molde design
# system design and management
# graphic design
# systems design engineering
# product design and development
# computer-aided drafting  design
# dramadirecting and design
# electrical engineering (digital design)
#
# Cluster 36:
# computer science, music composition
# music performance, (guitar)
# music theory and studio recording
# music theory and composition
# music
# music performance
# music theory
# music performance, general
# computer science and music
# audio and music engineering
#
# Cluster 37:
# accounting and finance
# accounting and businessmanagement
# accounting and computer science
# accounting  mathematics
# accounting- tax
# accounting
# business administration | accounting | cis
# accounting and analytics
#
# Cluster 38:
# electronic information science and technology
# electronic science and technology
# electronic information technology
# electronic information science  technology
# electronic systems technology
#
# Cluster 39:
# computer networking and telecommunication systems
# information and telecommunication systems
# computer systems networking and telecommunications
#
# Cluster 40:
# condensed matter and materials physics
# materials science  engineering
# materials science
# materials science and engineering  mathematics
# materials science and engineering
# materials
# structures and materials in aeronautics and astronautics engineering
# materials engineering
# materials science and scientific computing
# materials science  mechanical engineering
# chemical engineering and materials science
# metallurgical and materials engineering
# materials science engineering
#
# Cluster 41:
# computer graphics
# interactive computer graphics
#
# Cluster 42:
# computer networks
# php, dbms, networks, erp, oops
# computer networks and cybersecurity
# complex networks
# computer systems and networks
#
# Cluster 43:
# electronics and telecommunication
# telecommunication engineering
# electronics  telecommunication
# telecommunication
# electronics and telecommunication engineering
#
# Cluster 44:
# german studies
# pre-law studies
# ethnics studies
# criminal justice  legal studies (ba) biblical studies (ba)
# integrated studies computer science  business leadership
# biblical studies
# classical studies
# national security studies
# russian, east european and eurasian studies
# french studies
# entrepreneurshipentrepreneurial studies
# computer science and french studies
# mass communicationmedia studies
# environmental studies
# jewishjudaic studies
# pre-pharmacy studies
# economics and east asian studies
# communication and media studies
# general studies
# filmcinemavideo studies
# aviation studies (management and law)
# military strategic studies, general
# multi-interdisciplinary studies, business
# intelligence studies
# multiinterdisciplinary studies
#
# Cluster 45:
# major in biomedical engineering with a minor in business
# computer science w minor in economics
# businesscorporate communications minor in global business
# statistics with a graduate minor in computational science
# computer science with minor in business administration
# computer engineering, with minor in applied mathematics
# concentration in marketing with a minor in leadership studies
# human development and family sciences | minor in business administration | minor in entrepreneurship
# aerospace engineering with a minor in computer science
# major in computer science, minor in data science
# concentration in engineering
# computer science with minor in japanese
# computer science, minor in mathematics
# computer science; minor in business economics
# computer science with minor in math
# major in electrical engineering, minor in computer science
# electronics, minor in management
# economics, minor in mathematics
# computer science  data science, minor in entrepreneurship
# mathematics and computer science; minor in spanish
# industrial engineering, minor in computer science, applications in data science certificate
#
# Cluster 46:
# industrial distribution
# chemical and industrial engineering
# industrial and operations engineering  data science
# industrial  systems engineering
# industrial engineering
# industrial and systems engineering
# industrial electronics
# industrial engineering  economics (minor)
# industrial manufacturing and systems engineering
# industrial technology
# industrial management
#
# Cluster 47:
# computational biophysics
# biophysics
#
# Cluster 48:
# actuarial science with computer science minor
# computer science with cybersecurity minor
# information secuity with cisco minor
# science with computer science
# computer science with co-op
#
# Cluster 49:
# philosophy
# mathematics, philosophy
# mathematics; minor, philosophy
# computer science, philosophy
#
# Cluster 50:
# communications and signal processing
# signal processing, communications and networks
# signal processing, instrumentation, automation, data analysis, algorithms
# image processing
# signal processing
# communication and signal processing
# telecommunications and signal processing
# ee, signal processing
# image processing and computer vision
# electrical and computer engineering, digital signal processing
# communications, signal processing and networking
# electrical engineering (signal processing)
# communications, signal processing, networks
# electrical and electronic engineering, msc in communication and signal processing
#
# Cluster 51:
# organic chemistry
# materials chemistry
# medicinal chemistry
# computer science, chemistry
# chemistry
# inorganic chemistry
# polymer chemistry
# physical chemistry
# chemistry; minors business, math
# chemistry and chemical engineering
# applied chemistry
#
# Cluster 52:
# web development
# fullstack web development
# full stack web development
# web development and administration
#
# Cluster 53:
# electrical
# electrical enginneering
# electrical engineering
# electrical engineering (network safety)
# electrical engineering  mathmatics
# electrical engineeringcomputer science
# electrical  renewable energy engineering
#
# Cluster 54:
# technology management
# technology management mba
# computer engineering | hoeft technology  management class xxvi
# management and technology
# computerinformation technology administration and management
#
# Cluster 55:
# information systems and decision sciences, concentration mis
# management information systems (mis) and business management
# finance  mis
# mis and marketing
# management information systems (mis)
#
# Cluster 56:
# msc mathematics and be electronics  instrumentation engineering
# electronics  instrumentation
# electronics and instrumentation of engineering
# electronics and instrumentation engineering
# instrumentation technologytechnician
# instrumentation engineering
# electronics and instrumentation
# instrumentation
#
# Cluster 57:
# bachelors in technology
# master in industrial management
# engineering technology in computers
# bachelor of technology in computer science
# master of science in information technology
# master's of science in technology commercialization
# master of science in business analytics
#
# Cluster 58:
# comparative literature
# english language and literature, general
# english literature
# english and french language and literature
# english language and literature
# japanese language and literature
#
# Cluster 59:
# business administration, finance  international business concentrations
# bachelor of business administration marketing and finance
# introduction to economics, business and finance
# business and finance
# business administration, finance concentration
# business administration, finance
# business administration - finance
# mathematics in finance
# finance and international business
# business- finance
# business administration, information system and finance
# finance
# finance  international business
# economics  business finance
# finance, corporate finance
# business finance data science
#
# Cluster 60:
# ingeniería mecatrónica
# ingeniería
# ingeniería mecatronica
#
# Cluster 61:
# computational biology
# mathematics and biology
# oncology and cancer biology
# mathematical biology
# geology-biology
# biology, general
# mathematics-chemistry-biology-entrepreneurship
# biochemistry and molecular biology
# english, biology
# biology, chemistry, naval science
# mathematics, biology
# biology
# computer science and biology
#
# Cluster 62:
# engineering
# structural engineering
# electical engineering
# biomedicalmedical engineering
# electricalelectronic engineering
# vehicle engineering
# electrial engineering
# elecrical engineering
# plastics engineering
# nuclear engineering
# reverse engineering  exploitation
# mechanicalmanufacturing engineering
# biosystems engineering
#
# Cluster 63:
# optics applied mathematics
# applied mathematics and economics
# mathematics, arithmetic geometry
# applied mathematics
# applied mathematics and a specialization in computing
# electricalcomputer engineering, mathematics
# mathematics
# mathematics, advanced
# applicable mathematics
# applied mathematics, minor cs
# mathematics and applied mathematics
# mathematics (intensive)
# applied computational mathematics
# applied mathematics and computer science
# computational and applied mathematics
# mathematics, cs certificate
# pure mathematics
#
# Cluster 64:
# vlsi
# electrical engineering - vlsi
# vlsi design tools and techlonogy
# computer engineering (vlsi)
# vlsi systems
# vlsi design
# computer engineering, vlsi design concentration
# electrical and computer engineering - major in vlsi
# cmos vlsi
# electrical engineering (vlsi)
#
# Cluster 65:
# electronics and computer tech
# opto-electronics information science and engineering
# electronics and information science
# science and electronics
# electronics and computer science
# electronics and science
#
# Cluster 66:
# industrial and systems engineering, supply chain and transportation
# supply chain management
# logistics  supply chain analytics
# integrated supply chain management; engineering coursework - top  nationally ranked program
# logistics and supply chain management
# supply chain management and management information systems
# operations and supply chain management
# logistics, materials, and supply chain management
# business honors, supply chain management
#
# Cluster 67:
# computer science (mcit)
# computer science (games)
# computer science, min
# computer science
# honours computer science
# computer science, business
# computer science and cognitive science
# masters of science, computer science,
# computer science and robotics
# computer science and statistical science
# computer science and bioinformatics
# bsc computer science
# computer science and business
# computer science and italian
# computer science (harvey mudd college)
# computer science and engineereing
# computer science, finance
# transfer, computer science
# computer science - computer security
# icse - computer science
# computer science, entrepreneurship
# computer science  entrepreneurship
# computer science, cognitive science
# computer science, gold medalist
# computer science (data science concentration)
#
# Cluster 68:
# computer engineer
# electrical engineer
# computer sciences engineer
# front-end engineer
# hybrid cloud engineer
# network engineer
# automation engineer technologytechnician
# computaer engineer
#
# Cluster 69:
# applied economics and statistics
# probability  statistics, applied mathematics, architecture
# applied statistics  computer science
# chemical engineering, applied statistics and informatics
# applied statistics
# applied statistics and data management
# applied mathematics and statistics  data science, distinction in both majors
#
# Cluster 70:
# java and cloud computing(aws)
# information and computing science
# parallel computing
# information  computing science
# high performance embedded computing
# scientific computing
# computing security
# computing systems
# mathematics and computing
# computing science  information systems
# engineering  computing
# cloud computing and software as a service
# computing and information technology
# computing
#
# Cluster 71:
# science stream
# physicsmaterial science
# compute science
# science
# kinesiology and exercise science
# mathcomputer science
# compuer science
# nursing science
# englishcomputer science
#
# Cluster 72:
# networking, and administration
# computer networking systems
# applied networking  system administration, communications
# computer networking
# networking
# system, networking, and lanwan managementmanager
# information networking
# computer networking and server administration
# computer science and networking
# engineering and applied science; telecommunications and networking
# cisco networking
# computer systems networking
# computer repair, networking
#
# Cluster 73:
# marketing, sales, art
# art history, criticism and conservation
# art
# art practice
# majored in art and minored in art history
# concentration in art history and languages
#
# Cluster 74:
# control and instrumentation engineering
# instrumentation and control engineering
# electronics instrumentation and control
# electronics and instrumentation control
# instrumentation and control
#
# Cluster 75:
# criminal justice
# criminal justice political science
# criminal justicelaw enforcement administration
# criminal justicepolice science
# criminal justicesociology
# criminal justice and corrections
#
# Cluster 76:
# master of financial management
# university of pennsylvania
# master of science (ms), management of information technology
# master of information systems management
# msc - master of computer sciences
# master of computational data science
#
# Cluster 77:
# astronomy, physics, and mathematics
# physics, astronomy
# astronomy minor
# astronomy
# astronomy  physics
# mathematics, astronomy, physics
#
# Cluster 78:
# project management
# project lead the way program
# network security  agile project management
# project management certification
# information technology  project management
# chemical engineering; project management
# business analytics and project management
# business administration - project management
# engineering project management initiating and planning
# information technology project management
#
# Cluster 79:
# electronics engineering
# electronics and computers
# engineering, radiophysics and electronics
# micro electronics
# electronics and computer engineering
# computer electronics engineering
# electronics
#
# Cluster 80:
# korean language
# computer speech and language
# english language and literatureletters
# language and information technologies
# english language program
#
# Cluster 81:
# game design and development
# game design  development
# electronic game design
# computer science and game design
# computer science (game development)
# game development
#
# Cluster 82:
# electric information engineering
# information sciencestudies
# information retrieval
# optoelectronic information science and engineering
# information science  engineering
# computer information science
# computer science  information engineering (another major finance)
# information science and engineering
# computer and information science
# information science engineering
# geographic information science and cartography
# computer science and information engineering
# information science
# information engineering
#
# Cluster 83:
# digital modeling in virtual reality at université d'angers
# digital currency
# digital media design
# digital communications
# communications in digital media
# dynamic digital media
# digital gaming and simulation
# digital communications  electro-optics
#
# Cluster 84:
# cybersecurity and forensics
# information systems, cybersecurity
# computer software and cybersecurity
# cybersecurity
# software engineering (cybersecurity)
# foundations of cybersecurity
# cybersecurity analytics
# major in cybersecurity
# cybersecurity engineering
# computer and information science and cybersecurity
#
# Cluster 85:
# industrial eng - operations mgmt  research
# operations research and statistics
# ml and operations research
# operations research and information engineering
# industrial engineering and operations research
# industrial engineering  operations research
# operations research
#
# Cluster 86:
# electrical power engineering
# power systems
# power electronics and motion control
# electric power engineering
# power converters and drives
# power and energy systems
# power electronics
# automotive motorsports  clean power systems
#
# Cluster 87:
# media arts  sciences
# liberal arts and sciencesliberal studies
# aassociate of arts
# animation arts  design
# arts and sciences
# liberal arts and sciences, general studies and humanities
# media arts and sciences
#
# Cluster 88:
# bs of computer engineering and bs of computer science
# bs finance
# computer science (bs) and environmental science (bs)
# computer science bs
#
# Cluster 89:
# computer science and automation
# automation science and electrical engineering
# electrical engineering and automation
# software testing and automation specialization
# automation
# automation and robotics
# mechanical and automation engineering
# mechanical engineering and automation
# mechanical  automation engineering
#
# Cluster 90:
# mathematical and computational science
# computational science and engineering
# computational modelling and simulation
# computational mathematics
# computational science  engineering
# computational science
# computer science and computational mathematics
# computational engineering
#
# Cluster 91:
# cyber security  forensics emphasis
# network and cyber security
# cyber security and digital forensics
# cyber security engineering
# cyber security analytics
# cyber security
#
# Cluster 92:
# math statistics and probability
# statistics and econometrics
# computer science  statistics
# data science and statistics
# econometrics and quantitative economics, mathematics, computer science, statistics
# mathematics  statistics
# computer science and statistics (double)
# concentration statistics
# statistics and computer science
# psycholgoy, statistics
# statistics
# mathematics (statistics track)  economics
# data science, mathematics, statistics
# mathematics and statistics
# economics and statistics
# industrial statistics
# calculus  statistics
#
# Cluster 93:
# sound artsaudio production
# production engineering
# production management
#
# Cluster 94:
# electronic and information engineering
# electrical and electronic engineering
# electronic engineering
# electrical and electronic engineering, computational electromagentics
# electronic publishing specialist
# electronic and computer engineering
# electrical  electronic engineering
# electronic circuits and systems
# finance(dual major), electronic and communication engineering
# microelectronics and solid electronic
#
# Cluster 95:
# information systems and management
# management information systems
# management information systems and finance
# information systems management
# business management, minor management information systems
# management - management of information systems - risk management
# management of information and communications systems
# information management and systems
# management information systems, computer science and accounting minors
# management information systems and services
# management information systems, general
# information management
# information management  information systems
# management - information systems
#
# Cluster 96:
# computer science, finance, math
#  , sat  (math , reading , writing )
# math and science
# mathematics and applied math
# math computer science
# applied math
# computer science, applied math and statistics
# computer science, applied math
# physics, latin, applied math
# applied and computational mathematical sciences discrete math and algorithms
# math, physics, electronics
#
# Cluster 97:
# electrical and electronics
# electrical engineering (electronics)
# electrical and electronics engineering, specification in robotics
# electrical  electronics eng
# electrical  electronics engineering
# electrical engineering, electronics circuits and system
# management science and innovation; electrical and electronics engineering
# electrical and electronics engineering
# electrical engineering electronics
#
# Cluster 98:
# specialization in nvh(noise vibration and harshness)
# mechanical engineer with a specialization in design
# mathematics with a specialization in actuarial science
# computer science (specialization in ai and os)
# electronics and communications engineering with minor specialization in computer science
# actuarial science
#
# Cluster 99:
# th standard
# aisse  (cbse)
# cbse th standard
# cbse
#
# Cluster 100:
# nanotechnology
# nanotechnology engineering
#
# Cluster 101:
# uctech school of design
# high school diploma
# computer science (school of engineering)
# school of computing, informatics, and decision systems engineering
# computer science (school of engineering), english
# school
# grade school
#
# Cluster 102:
# mathematics, physics and chemistry
# mathematics physics chemistry
# physics, chemistry, mathematics, electronics
# mathematics, physics, chemistry, biology and languages
# physics, chemistry, mathematics, knowledge  inquiry
# mathematics,physics and chemistry
# physics, chemistry,mathematics,economics
# math,physics,chemistry and computers
# (physics, chemistry, mathematics, electronics)
# mpc - mathematics, physics and chemistry
# math, physics, chemistry
# mathematics, physics, chemistry
#
# Cluster 103:
# computer engineering computer science
# computer science engineering
# computer science (engineering)
# computer engineering, computer science
# computer science  engineering
# computer engineering and computer science
# chemical engineering and computer science
# computer engineering
# computer engineering | computer science - intelligence
# engineering; computer science
# computer science and engineering
# computer engineering  computer science, german certificate
# cse (computer science and engineering)
#
# Cluster 104:
# sport and entertainment management
# sport management
#
# Cluster 105:
# construction management
# community development w areas of building construction and acocunts registrar
# construction engineering
# construction technology and management
#
# Cluster 106:
# electrical and computer engineering (specialization in embedded systems)
# embedded system design
# hardware and embedded design
# software engineering, application programming, embedded systems, security
# embedded systems
# electrical engineering, specializing in embedded systems
# embedded systems design
# embedded systems  vlsi design
# embedded systems engineering
#
# Cluster 107:
# chinese
# chinese language and culture
# traditional chinese medicine and chinese herbology
# chinese language and literature
# chinese business environment  german
#
# Cluster 108:
# english (teaching chinese as a foreign language)
# teaching english as a second or foreign languageesl language
# teaching english as a second language
#
# Cluster 109:
# communications; communication and culture; recruitment chairman
# communication
# information and communication engineering
# communication engineering
# dsp  communication systems
# organizational communication
# strategic communication, advertising
# tele-communication engineering
# communication theory and systems
# digital communication and mediamultimedia
# communication systems engineering
# computer and communication
# electrical engineering; communication system
#
# Cluster 110:
# masters in computer applications
# computer applications
# computer programming, specific applications
# intermediate applications developer
# web applications and services
# communication applications technology
# computer science applications
#
# Cluster 111:
# human resources management
# human resources managementpersonnel administration, general
# human environmental science
# human resources management and services
# natural resources
# human computer interaction
# informed leadership combating human trafficking globally
# human resources
#
# Cluster 112:
# innovation, entrepreneurship, strategy, management, technology
# product management strategy
# strategy
# corporate strategy and finance
# marketing, strategy, product management
# operationslogistics and business strategy
# finance strategy
# strategy  management consulting, marketing
# business strategy and marketing
#
# Cluster 113:
# specialization machine learning
# deep learning
# computer science, deep learning
# computer science - machine learning
# machine learning engineer
# machine learning and computer vision
# electrical and computer engineering (machine learning specialization)
# statistics and machine learning
# machine learning, modeling and simulation
# machine learningdata science
# computer vision and machine learning
# electrical and computer engineering (machine learning track)
# optimization and learning
# statistics, machine learning
# machine tool technology
# research - machine learning
# machine learning
#
# Cluster 114:
# mechanical engineering, summa cum laude
# computer science (magna cum laude)
# magna cum laude
# business management, cum laude
# civil engineering - magna cum laude
# systems and computing engineering - summa cum laude
#
# Cluster 115:
# software quality assurance
# software engineering and quality testing
# software quality assurance course
# quality control
#
# Cluster 116:
# business intelligence and data analytics
# chemical engineering and data analytics
# data analytics
# information systems management, business intelligence and data analytics
# data science  analytics
# business data analytics
# wharton's business analytics from data to insights
# data analytics engineering
# computer science and business data analytics
# mba with emphasis in business analytics  data science
# data science - business  industrial analytics
# concentration in data analytics, research, and assessment
# computer science and data analytics
#
# Cluster 117:
# wireless communications
# wireless communication
# electronics  electrical communication engineering, micro-specialization in embedded wireless system
# wireless hacking
# electrical engineering - wireless communications
# wireless networks, computer science
# wireless embedded systems
#
# Cluster 118:
# , nancy-metz valedictorian
#  (valedictorian)
#
# Cluster 119:
# computer science vision, graphics, interaction, and robotics track
# vision, graphics, interaction, and robotics track
#
# Cluster 120:
# philosophy with honors
# pass with honors
# electrical engineering with honors
# computer science (turing scholar honors program)
# honors
#
# Cluster 121:
# international baccalaureate
# business administration and international studies
# international transactions and comparative law
# international trade
# international relations and affairs
# organizational and international business
# marketing, international business
# international economics
# international relations
# international business and economics
# international business
# international management
# international economic law
# marketing and international business
# international public healthinternational health
# international educational development
#
# Cluster 122:
# internet technologies
# linux  cloud infrastructure technologies  kubernetes  dockers
# multimedia and creative technologies
# geographic information science and technologies
# computer science (multimedia  creative technologies)
# business information technologies
# information technologies
#
# Cluster 123:
# bioengineering and biomedical engineering
# bioengineering
# bioengineering and biomedical engineering and minor in computer science
#
# Cluster 124:
# technical operator
# management informations systems, computer science, technical communication
# technical management
#
# Cluster 125:
# pcm with computer science
# pcm
# non-medical (pcm)
# science (pcm)
#
# Cluster 126:
# applied mathematics and informatics
# computational informatics
# informatics
# information technology and informatics
# pcm with informatics practices
# biomedical informatics
#
# Cluster 127:
# materials and metallurgical engg
# computer science  engg
# computer science and engg
# electrical and computer engg
#
# Cluster 128:
# analog  mixed signal ic design
# analog ic design
# mixed signal vlsi
# rfmixed signal ic design
# analog and mixed signals
#
# Cluster 129:
# computer science and history
# history, computer science
# computer science and history of science
# secondary ed history
# history, business
# history
#
# Cluster 130:
# mathematics and physics
# physics, mathematics
# physics, computer science, mathematics
# physics (minar mathematics)
# computer science, mathematics, physics
# mathematics, physics, and engineering
# sciences - physics, biology, mathematics
# mathematics and physics majors, computer science minor
#
# Cluster 131:
# computational neuroscience
# neuroscience
# neuroscience and photography
#
# Cluster 132:
# electronics and telecommunications
# telecommunications certificate
# telecommunications management
# telecommunications engineering
# electronics and telecommunications engg
# electronics  telecommunications
# telecommunications
# electronics and telecommunications engineering
#
# Cluster 133:
# it
# it management
# it strategic management
# it security
# it engineering
# it support
# business and it
# it operating systems and programming
#
# Cluster 134:
# civil engineering
# architectural and civil engineering
# earthquake engineering in civil engineering
# civil and environmental engineering
#
# Cluster 135:
# physics and math (double major)
# computer science and data science (double major)
# double major in mathematics and data science
# double major in applied mathematics and statistics
# double major in computer science and information systems
# dual major in computer science  engineering and mathematics
# double major in cybersecurity and network engineering
#
# Cluster 136:
# engineering mechanics
# mechanics and automotive
# mechanical and automotive engineering
# automotive engineering technologytechnician
# automotive engineering
#
# Cluster 137:
# with specialization in product design and manufacturing
# (structures, materials and manufacturing)
# manufacturing and mechanical engineering
# computational design and manufacturing
# mechanical engineering computational mechanics and manufacturing
# propulsion and additive manufacturing
#
# Cluster 138:
# cognitive science  neuroscience
# cognitive neuroscience
# cognitive neuropsychology and neuroscience
# cognitive science
#
# Cluster 139:
# spanish languge and multicultural studies
# spanish
# biology and spanish literature
# computer science  spanish
#
# Cluster 140:
# electronics and communications
# electrical, electronics and communications engineering
# electronics and tele-communications engineering
# electronics  communications engineering
# electronics and communications engineering
# electronics and tele communications
#
# Cluster 141:
# mathematics teacher education
# social studies teacher education
# history teacher education
#
# Cluster 142:
# user experience and web design
# user experience (ux) design minor; e-commerce web developer certification
# web design
# user experience design
#
# Cluster 143:
# vlsi and computer architecture
# computer vision, history of architecture
# digital communication, computer architecture
# electrical and computer engineering - computer architecture and embedded systems
# architecture
# electrical engineering with focus on vlsi and computer architecture
# computer architecture  embedded system
# interior architecture  design
#
# Cluster 144:
# mpsi et mp
# mpsi - psi
#
# Cluster 145:
# data analytics  visualization
# data analytics and visualization
#
# Cluster 146:
# sciences pures et appliquée, programme eureka
# programmation sémantique, preuves et langages
# formation et enseignement secondaires
#
# Cluster 147:
# mechatronics, robotics, and automation engineering
# mechatronics engineering – co-operative program
# mechatronics design
# mechatronics engineering
# mechatronics technology
# mechatronics
#
# Cluster 148:
# assurance
# cybersecurity and informarion assurance
# computer and information systems securityinformation assurance
# information sciences - cybersecurity and information assurance
# information security and assurance
# information sciences, cybersecurity and information assurance
#
# Cluster 149:
# english literature, political science
# concentrations in small business  political science
# political science and government
# political science
# psychology and political science with a minor in business
# political science, computer science

# %% [markdown]
# Re-Clustering Largest Cluster:

# %%
# Find the index of the list with the maximum length
max_index = max(range(len(clustered_degree)), key=lambda i: len(clustered_degree[i]))

# Print the index of the list with the maximum length
print("Index of cluster with maximum length:", max_index)

import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Identify the cluster you want to redistribute
cluster_to_redistribute = max_index  # Adjust the cluster ID as needed

# Extract skills from the identified cluster
degree_to_redistribute = clustered_degree[cluster_to_redistribute]
#print(len(skills_to_redistribute))
# Vectorize all skills in the clusters
cluster_vectorized = {}
for index, cluster in enumerate(clustered_degree):
    if index != cluster_to_redistribute:
        cluster_vectorized[index] = vectorizer.transform(cluster)

# Initialize dictionary to store transformed skills
degree_transformed_dict = {}

for i, deg in enumerate(degree_to_redistribute):
    X = vectorizer.transform([deg])
    max_sim = -1
    max_cluster = None
    for index, cluster in enumerate(clustered_degree):
        if index != cluster_to_redistribute:
           X_cluster = cluster_vectorized[index]
           sim = cosine_similarity(X, X_cluster).mean()
           if sim > max_sim:
               max_sim = sim
               max_cluster = index
    degree_transformed_dict[deg] = max_cluster
# Out:
# Index of cluster with maximum length: 0

# %%
copy_list = clustered_degree.copy()
for deg, cluster in degree_transformed_dict.items():
  copy_list[cluster].append(deg)

copy_list = [cluster for i,cluster in enumerate(copy_list) if i!=max_index]


print(copy_list)

clustered_degree = copy_list.copy()
for cluster_id, deg_in_cluster in enumerate(clustered_degree):
    print(f"Cluster {cluster_id}:")
    for deg in deg_in_cluster:
        print(deg)

    print()

# Find the index of the list with the maximum length
new_max_index = max(range(len(clustered_degree)), key=lambda i: len(clustered_degree[i]))
print(new_max_index)
print(len(clustered_degree[new_max_index]))
# Out:
# [['electrical and communications engineering', 'broadcast communications', 'strategic marketing communications', 'cisco unified communications', 'electrical, electronic and communications engineering technologytechnician', 'literature and communications', 'network communications and management', 'electrical, electronic and communications engineering', '', 'na', 'spécialité physique', 'physik', 'radiologic technologyscience - radiographer', 'infantry', 'hvacr', 'a+', 'ib', ' ( courses)', 'classics', 'realtime d reconstruction', 'ingenieria en sistemas de informacion', 'certified installer  tuner', 'emergency care attendant (emt ambulance)', 'informatyka', '-', 'visiting student', 'hypokhâgne, khâgne', 'mathsscience', 'cinema', ' ', 'prawo', 'eie', 'apprentissage statistique', 'sociology', 'hs', 'pcmb', 'a', 'criminology', 'medieninformatik', 'paralegal', 'eee', 'registered nursingregistered nurse', 'fire sciencefire-fighting', '電機工程學系', 'private pilot', 'nsw', 'nanomicrofabrication, nanowire field-effect transistor', 'alumni', 'mandarin level ii  iii', 'engenharia elétrica e eletrônica', 'certified', 'geophysics', 'programación informática, aplicaciones específicas  programmingcomputer architechture, engines', 'electrochemistry', 'communiication', 'optoelectronics', ' c', 'completed', 'senior', 'none', 'pastry', 'microsoft', 'aaaaa', 'biostatistics', 'electronica', 'electrician', 'puc', 'react', 'android developement', 'engenharia de computação', 'mechano-infomatics', 'info', 'orcale', 'board examinations', 'forestry', 'electonics', 'remote sensing', 'study abroad', 'pcmc', 'astrophysics', 'biomathematics', 'microsoft datacenter academy student', 'metrology', 'softwarové inženýrství', 'schooling', 'core musical skills', 'electronical', 'radio, television  film', 'iim-lucknow noida campus', 'mscs', 'pharmaceutics', 'lab technician', 'pcms', 'pcme', 'all', 'cybernetics', 'lean six sigma', '(ongoing)', 'businessoffice automationtechnologydata entry', 'n', 'genetics', '通信工程', 'precision instrument', 'percentage - ', 'tertiary entrance rank ', 'uai ', 'stem', 'outstanding', " (dean's list)", 'bigdata', 'pharmacology'], ['natural science and mathematics', 'computer engineering, computer science, and mathematics', 'mathematics, computer science', 'computer science  mathematics', 'mathematics and science', 'science and mathematics', 'computer science and mathematics', 'computer science and engineering, mathematics', 'computer science; mathematics', 'mathematics and computer science', 'pure mathematics, computer science', 'computer science, mathematics', 'mathematics and computer science, computer engineering', 'computer engineering; mathematics'], ['space science and engineering', 'engineering science and ocean engineering', 'nutrition and dietetics', 'religion and christian ministry', 'polymer science and chemical engineering', 'engineering science', 'polymer science and engineering', 'mining and mineral engineering', 'managment science and engineering', 'nanoscale science and engineering', 'laser and optical engineering', 'material science and engineering', 'electromagnetic field and microwave techniques', 'microelectronics and semiconductor', 'mathematic and economic', 'geophysics and seismology', 'medical billing and coding', 'east asian languages and cultures', 'automotivecollision and repair technologytechnicianmanagement', 'geological and earth sciencesgeosciences', 'environment and sustainability', 'training and assessment', 'd modeling and animation', 'remote sensing and geophysics', 'high schoolsecondary diplomas and certificates', 'dynamics and controls'], ['electronics technology  systems', 'electronics and computer technology engineering', 'electronics engineering technology (major), computer science (minor)', 'computer electronics technology', 'computer engineering technology', 'computer science and technology', 'electronics design technology', 'electronics technology', 'electronics and computer technology'], ['double ele ...
# Cluster 0:
# electrical and communications engineering
# broadcast communications
# strategic marketing communications
# cisco unified communications
# electrical, electronic and communications engineering technologytechnician
# literature and communications
# network communications and management
# electrical, electronic and communications engineering
#
# na
# spécialité physique
# physik
# radiologic technologyscience - radiographer
# infantry
# hvacr
# a+
# ib
#  ( courses)
# classics
# realtime d reconstruction
# ingenieria en sistemas de informacion
# certified installer  tuner
# emergency care attendant (emt ambulance)
# informatyka
# -
# visiting student
# hypokhâgne, khâgne
# mathsscience
# cinema
#
# prawo
# eie
# apprentissage statistique
# sociology
# hs
# pcmb
# a
# criminology
# medieninformatik
# paralegal
# eee
# registered nursingregistered nurse
# fire sciencefire-fighting
# 電機工程學系
# private pilot
# nsw
# nanomicrofabrication, nanowire field-effect transistor
# alumni
# mandarin level ii  iii
# engenharia elétrica e eletrônica
# certified
# geophysics
# programación informática, aplicaciones específicas  programmingcomputer architechture, engines
# electrochemistry
# communiication
# optoelectronics
#  c
# completed
# senior
# none
# pastry
# microsoft
# aaaaa
# biostatistics
# electronica
# electrician
# puc
# react
# android developement
# engenharia de computação
# mechano-infomatics
# info
# orcale
# board examinations
# forestry
# electonics
# remote sensing
# study abroad
# pcmc
# astrophysics
# biomathematics
# microsoft datacenter academy student
# metrology
# softwarové inženýrství
# schooling
# core musical skills
# electronical
# radio, television  film
# iim-lucknow noida campus
# mscs
# pharmaceutics
# lab technician
# pcms
# pcme
# all
# cybernetics
# lean six sigma
# (ongoing)
# businessoffice automationtechnologydata entry
# n
# genetics
# 通信工程
# precision instrument
# percentage -
# tertiary entrance rank
# uai
# stem
# outstanding
#  (dean's list)
# bigdata
# pharmacology
#
# Cluster 1:
# natural science and mathematics
# computer engineering, computer science, and mathematics
# mathematics, computer science
# computer science  mathematics
# mathematics and science
# science and mathematics
# computer science and mathematics
# computer science and engineering, mathematics
# computer science; mathematics
# mathematics and computer science
# pure mathematics, computer science
# computer science, mathematics
# mathematics and computer science, computer engineering
# computer engineering; mathematics
#
# Cluster 2:
# space science and engineering
# engineering science and ocean engineering
# nutrition and dietetics
# religion and christian ministry
# polymer science and chemical engineering
# engineering science
# polymer science and engineering
# mining and mineral engineering
# managment science and engineering
# nanoscale science and engineering
# laser and optical engineering
# material science and engineering
# electromagnetic field and microwave techniques
# microelectronics and semiconductor
# mathematic and economic
# geophysics and seismology
# medical billing and coding
# east asian languages and cultures
# automotivecollision and repair technologytechnicianmanagement
# geological and earth sciencesgeosciences
# environment and sustainability
# training and assessment
# d modeling and animation
# remote sensing and geophysics
# high schoolsecondary diplomas and certificates
# dynamics and controls
#
# Cluster 3:
# electronics technology  systems
# electronics and computer technology engineering
# electronics engineering technology (major), computer science (minor)
# computer electronics technology
# computer engineering technology
# computer science and technology
# electronics design technology
# electronics technology
# electronics and computer technology
#
# Cluster 4:
# double electrical engineering and physics
# nonlinear physics
# public finance (minor physics)
# chemical physics
# engineering physics
# systems engineering, with physics minor
# applied physics
# physics
# engineering physicsapplied physics
# physics; lei zhou
# physics and computer science
# computer science, physics
# physics with electrical engineering
# computer science and physics
# eecs - solid state physics
# public policy
# physics, government policy
#
# Cluster 5:
# geographical information systems
# computer science, information systems
# business information systems
# information systems and decision sciences
# information systems
# accouting information systems
# marketing, information systems
# computer science and information systems
# computer and information systems
# systems and information engineering
# information systems engineering
# computer information systems
# computer science; information systems
# creative writing; geographic information systems (gis)
#
# Cluster 6:
# maths, physics, chemistry
# maths, physics and chemistry
# maths, physics
# physics, chemistry, maths, economics
# science, maths, hindi, english, social science
# english, physics, chemistry, biology, maths
# english, physics, chemistry, maths and computer science
# maths, physics  chemistry
# maths - science
# science maths
# physics, with certificate in finance, application of computing, applied and computational maths
#
# Cluster 7:
# electrical and computer engineering - software engineering  system
# computer software engineering
# computer systems and software
# software development
# computer software engineering and electronics engineering
# computer science  software engineering
# software  teaching
# electrical engineering (computer hardware and software)
# software and robotics
# software engineering; as computer programming; computer programing and engineering
# computer engineering, software engineering
# software engineering technology
# software engineering
# software engineering and systems
# computer science and software engineering
# computer science - software engineering
# electrical and software engineering
# software systems
# computer science, specialty software engineering
#
# Cluster 8:
# mathematics and engineering, control and communications
# control engineering
# ee control theory
# electricalelectronics engineering - control systems (aircraftspacecraft controls)
# electrical engineering (signals, control, and optimization)
# mechanical engineering; mechatronic and intelligent control
# electrical and control engineering
# process equipment and control engineering
# computer science, specialty modeling, cognition and control (mc)
# control science and engineering
# automotic control engineering
# ee
#
# Cluster 9:
# information system
# communication  information system
# information management and information system
# information system management
# signal  system
# computer information system - data analytics
# geographical information system
# system software
# very large information system
# network and system administrationadministrator
# earth system science
# unix system administraton
# communication and information system
#
# Cluster 10:
# electrical and system engineering
# industrial and system engineering
# electrical and electronic engineering; computer science and industrial system engineering
# industrial system engineering
#
# Cluster 11:
# computer science  electrical engineering
# electrical  computer engineering
# electrical engineering computer science
# computer engineering, electrical engineering, minor in computer science
# electrical and computer
# electrical and computer engineering (computer vision)
# electrical and computer engineering (ece)
# electrical and computer engineering, systems and computer engineering
# electrical computer digital engineering
# college of electrical engineering  computer science
# electrical and computer engineering, computer science
# electrical engineering (computer network)
# electrical  computer
# electrical engineering  computer science
# electrical engineering and computer science
# electrical and computer engineering (computer engineering)
# electrical engineering and computer sciences
# electrical and computer engineering
# electrical engineering, computer science
# electrical engineering and computer science (eecs)
# ece
# eecs
#
# Cluster 12:
# business analytics and information systems
# analytics
# predictive analytics
# business information  analytics
# marketing analytics
# business analytics
# customer analytics
# advanced analytics
#
# Cluster 13:
# information technology operations management
# operations management and information systems
# operations  information management
# engineering  operations management
# information systems and operations management
# cyberelectronic operations and warfare
# operations management and supervision
# finance, information and operations management, ecommerce management
# selling skills and sales operations
# entrepreneurial and small business operations
#
# Cluster 14:
# information and communication technology
# computer science and information technology
# information systems technology
# electromechanical engineering technology
# textile technology
# geo-information science and technology
# information systems and technology (application development concentration)
# multimedia technology
# information technology engineering
# information technology management
# professional information engineering technology
# information technology  management
# electrical engineering and information technology
# applied information technology
# business, technology
# technology entrepreneurship certificate
# information communication and technology
# logistics technology
# computer information technology
# information technology infrastructure
# instructional technology
# food science and technology
# information technology
# information technology - computer network systems
# intelligent science and technology
#
# Cluster 15:
# management science
# aviation management
# infomation management
# theatre management and producing
# engineering management
# engineerng management
# commercial management and quantity surveying
# management science  engineering
# management
# management science and engineering
# engineeringindustrial management
# management, emphasis in experience industry, event and venue management track
# management for scientists and engineers
# reliability engineering and asset management
# aviation
# transportation planning and management
# educational theatre
#
# Cluster 16:
# information systems, economics, physics, applicable mathematics, english
# physics , math , chemistry and english
# mathematics, computer science, physics, chemistry and english
# english, science and mathematics with biotechnology
# subjects chemistry, physics, mathematics, biology, english
# economics, english, chemistry, mathematics, physics
# journalism and english
# english
# english and italian
# english with concentration in professional and new media writing
# journalism
#
# Cluster 17:
# applied data science
# engineering and applied science
# applied computer science
# applied science and technology
# computer applied technology
# pure and applied science
# applied physics  computer science (minor)
# applied science technology
# applied learning and development
# applied science degree - network technician
#
# Cluster 18:
# sciences
# faculty of economics and administrative sciences
# health sciences,
# computer sciences
# computational data sciences
# computer and information sciences and support services
# biological sciences and biotechnology
# animal sciences
# mathematics,sciences
# health servicesallied healthhealth sciences, general
# biological sciences
# planetary sciences (subdiscipline of physics)
# brain and cognitive sciences
# major  sciences; minor  mathematics
# opticsoptical sciences
# atmospheric sciences and meteorology
# ceramic sciences and engineering
# environmental sciences
# mathematics and computer sciences
# social sciences
# mathematical sciences
# physical sciences
# computer and information sciences
# pharmaceutical sciences
# meteorology
# healthhealth care administrationmanagement
#
# Cluster 19:
# biomedical engineering and mathematics
# major electrical engineering minor biomedical engineering
# biomedical engineering  computer science
# mechanical engineering, minor biomedical engineering
# electrical engineering, biomedical engineering
# electrical and biomedical engineering
# electrical engineering, specialization in biomedical engineering
# biomedical engineeringbioengineering
# biomedical engineering  computer engineering
# biomedical engineering
# biomedical engineering (mdde)
# major biomedical eng; minor mechanical eng
#
# Cluster 20:
# quantitative psychology
# computer science  psychology
# social organizational psychology
# economics and psychology
# psychology
# honors computer science and psychology
# industrial and organizational psychology
# cognitive psychology
# psychology  computer science
# psychology and social behavior
# computer science, psychology
# organizational leadership
#
# Cluster 21:
# robotic systems engineering
# systems
# comuter and systems engineering
# systems engineering
# systems and entrepreneurial engineering
# unix systems administration
# is-expert - distributed systems
# l (l) tats cable systems  installer-maintainer
# computer systems engineering concentration in internet of things
#
# Cluster 22:
# cybersecurity, information security
# security and risk analysis
# information security and forensics
# computer information systems; network security
# homeland security
# computer science, security
# network security
# infromation security
# information security
# security management
# security  risk analysis
# certificate in information security management
#
# Cluster 23:
# economics and finance
# economics  computer science
# economics and computer science
# economics, mathematics
# economics financial markets option
# computer science and economics
# economics and management
# finance and economics
# computer science, russian, economics
# mathematics and economics
# economics
# econometrics and quantitative economics
# mathematics, economics
# economics; minor - business
# computer science and government modified with economics
# management and economics
# computer science, economics
# economics, applied economics, econometrics
# php,dbms,quantitative techniques,hr mgmt, marketing mgmt,economics,operating system
#
# Cluster 24:
# mechanical engineering, computer science
# mechanical engineering, electromechanical
# mechanical engineering - thermal energy
# electro mechanical technology
# major mechanical engineering minor computer science
# mechanical engineering robotics
# computer science and mechanical engineering
# mechanical engineering
# mechanical engineering and computer science
# mechanical drafting and mechanical drafting cadcadd
# mechanical
# mechanical engineering mechanical engineering; technology ug
# mechanical engineering major and business management minor
# mechanical engineeringmathematics
# mechanical engineering and mathematics
#
# Cluster 25:
# electronics and communication engineering
# electronics  communication
# electronics  communication enggineering
# electronics  communication engineering
# electronics and communication
# dual degree for bsc organisational communication
# communication and media studies (focus sales  marketing)
#
# Cluster 26:
# higher educationhigher education administration
# technology education; graphic communications
# junior highintermediatemiddle school education and teaching
# economics of education
# special education and teaching
# religious education
# education
# elementary education
# primary education
# general education
# junior
#
# Cluster 27:
# data science  engineering
# data science and engineering
# data analysis
# data analytics (big data)
# data modelingwarehousing and database administration
# data analyst
# data theory
# data processing
# data science, data analytics, software
# data management and data analytics
# information management - data science
# data science
# big data in culture and society
#
# Cluster 28:
# computer engineering (computer systems)
# computer commucations
# computer science and systems
# computer scienceengineering
# computer technologycomputer systems technology
# systems engineering, computer science minor
# computer and systems engineering
# computer engineering - computer systems
# computer
# computer science (distributed systems group)
# computer systems engineering
# computer science, computer  systems engineering
# computer and video imaging
# computer science, systems option
# computer science - intelligent systems track
# computer coding
# computer and network
# computer support specialist
# personal computer technician
# computer sc
# computer aided drafting
# computer application
#
# Cluster 29:
# business administration and finances
# business administration
# economics and business administration
# business, management, marketing, and related support services
# business administration, marketing
# business administration and management, general
# business administration and team and project management
# business administration, management and operations
# business, management
# business administration and management
# mba business management
# business administration and management,
# business
# business administration and management, marketing
# business administration management
# business management
# business entrepreneurial  management
# business administration, honors, concentrations in finance and management information systems
# global business  marketing
# business analysis
# public administration
# business journalism
#
# Cluster 30:
# computer programming
# c programming language
# computer programming and analysis
# programming, mcad
# computer programming and information technology
# python  programming specialization
# computer programming language design and implementation
# public policy analysis
#
# Cluster 31:
# aerospace, aeronautical and astronauticalspace engineering
# mechanical  aerospace engineering
# mechanical and aerospace engineering
# aerospace, aeronautical and astronautical engineering
# aerospace
# aerospace engineering
#
# Cluster 32:
# theoretical linguistics
# theoretical physics
# linguistics
# computational linguistics
# theoretical mathematics
# theoretical and mathematical physics
# theoretical computer science
# linguistics and computer science
# east asian languages, literatures, and linguistics
#
# Cluster 33:
# computer programmingprogrammer, general
# businesscommerce, general
# military intelligence, general
# computer and information systems, general
# information systems, general
# marketingmarketing management, general
# general management
# general engineering
# computer science (general)
# computer and information sciences, general
# geologyearth science, general
# finance, general
# biologybiological sciences, general
#
# Cluster 34:
# fashionapparel design
# electrical and computer engineering, integrated circuit design
# multimediaweb design
# computer science, design
# digital hardware design
# design engineering
# asic design and test
# autodesk inventor molde design
# system design and management
# graphic design
# systems design engineering
# product design and development
# computer-aided drafting  design
# dramadirecting and design
# electrical engineering (digital design)
# autodesk inventor professional
#
# Cluster 35:
# computer science, music composition
# music performance, (guitar)
# music theory and studio recording
# music theory and composition
# music
# music performance
# music theory
# music performance, general
# computer science and music
# audio and music engineering
# particle theory
# cello performance
#
# Cluster 36:
# accounting and finance
# accounting and businessmanagement
# accounting and computer science
# accounting  mathematics
# accounting- tax
# accounting
# business administration | accounting | cis
# accounting and analytics
# cis
#
# Cluster 37:
# electronic information science and technology
# electronic science and technology
# electronic information technology
# electronic information science  technology
# electronic systems technology
#
# Cluster 38:
# computer networking and telecommunication systems
# information and telecommunication systems
# computer systems networking and telecommunications
#
# Cluster 39:
# condensed matter and materials physics
# materials science  engineering
# materials science
# materials science and engineering  mathematics
# materials science and engineering
# materials
# structures and materials in aeronautics and astronautics engineering
# materials engineering
# materials science and scientific computing
# materials science  mechanical engineering
# chemical engineering and materials science
# metallurgical and materials engineering
# materials science engineering
# aeronautics
#
# Cluster 40:
# computer graphics
# interactive computer graphics
#
# Cluster 41:
# computer networks
# php, dbms, networks, erp, oops
# computer networks and cybersecurity
# complex networks
# computer systems and networks
#
# Cluster 42:
# electronics and telecommunication
# telecommunication engineering
# electronics  telecommunication
# telecommunication
# electronics and telecommunication engineering
#
# Cluster 43:
# german studies
# pre-law studies
# ethnics studies
# criminal justice  legal studies (ba) biblical studies (ba)
# integrated studies computer science  business leadership
# biblical studies
# classical studies
# national security studies
# russian, east european and eurasian studies
# french studies
# entrepreneurshipentrepreneurial studies
# computer science and french studies
# mass communicationmedia studies
# environmental studies
# jewishjudaic studies
# pre-pharmacy studies
# economics and east asian studies
# communication and media studies
# general studies
# filmcinemavideo studies
# aviation studies (management and law)
# military strategic studies, general
# multi-interdisciplinary studies, business
# intelligence studies
# multiinterdisciplinary studies
# pre-health
#
# Cluster 44:
# major in biomedical engineering with a minor in business
# computer science w minor in economics
# businesscorporate communications minor in global business
# statistics with a graduate minor in computational science
# computer science with minor in business administration
# computer engineering, with minor in applied mathematics
# concentration in marketing with a minor in leadership studies
# human development and family sciences | minor in business administration | minor in entrepreneurship
# aerospace engineering with a minor in computer science
# major in computer science, minor in data science
# concentration in engineering
# computer science with minor in japanese
# computer science, minor in mathematics
# computer science; minor in business economics
# computer science with minor in math
# major in electrical engineering, minor in computer science
# electronics, minor in management
# economics, minor in mathematics
# computer science  data science, minor in entrepreneurship
# mathematics and computer science; minor in spanish
# industrial engineering, minor in computer science, applications in data science certificate
# leadership in the public sector
# graduate
# concentrations in intelligence and theory
#
# Cluster 45:
# industrial distribution
# chemical and industrial engineering
# industrial and operations engineering  data science
# industrial  systems engineering
# industrial engineering
# industrial and systems engineering
# industrial electronics
# industrial engineering  economics (minor)
# industrial manufacturing and systems engineering
# industrial technology
# industrial management
#
# Cluster 46:
# computational biophysics
# biophysics
#
# Cluster 47:
# actuarial science with computer science minor
# computer science with cybersecurity minor
# information secuity with cisco minor
# science with computer science
# computer science with co-op
# cisco certified internetwork expert (ccie routing  switching) lab training
# with distinction
# cisco certified internetwork expert (ccie voice) lab training
# computer engineering with hardware concentration
#
# Cluster 48:
# philosophy
# mathematics, philosophy
# mathematics; minor, philosophy
# computer science, philosophy
# | entrepreneurship, strategic management, philosophy of language, data science, physicaldigital art
#
# Cluster 49:
# communications and signal processing
# signal processing, communications and networks
# signal processing, instrumentation, automation, data analysis, algorithms
# image processing
# signal processing
# communication and signal processing
# telecommunications and signal processing
# ee, signal processing
# image processing and computer vision
# electrical and computer engineering, digital signal processing
# communications, signal processing and networking
# electrical engineering (signal processing)
# communications, signal processing, networks
# electrical and electronic engineering, msc in communication and signal processing
#
# Cluster 50:
# organic chemistry
# materials chemistry
# medicinal chemistry
# computer science, chemistry
# chemistry
# inorganic chemistry
# polymer chemistry
# physical chemistry
# chemistry; minors business, math
# chemistry and chemical engineering
# applied chemistry
#
# Cluster 51:
# web development
# fullstack web development
# full stack web development
# web development and administration
# urban economic development
# product development
# workforce development and training
# application development
# fullstack
#
# Cluster 52:
# electrical
# electrical enginneering
# electrical engineering
# electrical engineering (network safety)
# electrical engineering  mathmatics
# electrical engineeringcomputer science
# electrical  renewable energy engineering
# energy efficiency
# electrical engineering (rf and microwave)
#
# Cluster 53:
# technology management
# technology management mba
# computer engineering | hoeft technology  management class xxvi
# management and technology
# computerinformation technology administration and management
# mba
# aviation maintenance technology
# technology management - microsoft software and systems academy
#
# Cluster 54:
# information systems and decision sciences, concentration mis
# management information systems (mis) and business management
# finance  mis
# mis and marketing
# management information systems (mis)
#
# Cluster 55:
# msc mathematics and be electronics  instrumentation engineering
# electronics  instrumentation
# electronics and instrumentation of engineering
# electronics and instrumentation engineering
# instrumentation technologytechnician
# instrumentation engineering
# electronics and instrumentation
# instrumentation
#
# Cluster 56:
# bachelors in technology
# master in industrial management
# engineering technology in computers
# bachelor of technology in computer science
# master of science in information technology
# master's of science in technology commercialization
# master of science in business analytics
# bachelor of applied science in organizational leadership
# bachelor's degree
#
# Cluster 57:
# comparative literature
# english language and literature, general
# english literature
# english and french language and literature
# english language and literature
# japanese language and literature
# japanese, java
#
# Cluster 58:
# business administration, finance  international business concentrations
# bachelor of business administration marketing and finance
# introduction to economics, business and finance
# business and finance
# business administration, finance concentration
# business administration, finance
# business administration - finance
# mathematics in finance
# finance and international business
# business- finance
# business administration, information system and finance
# finance
# finance  international business
# economics  business finance
# finance, corporate finance
# business finance data science
# finance and transportation  logistics
# finance and financial management services
#
# Cluster 59:
# ingeniería mecatrónica
# ingeniería
# ingeniería mecatronica
#
# Cluster 60:
# computational biology
# mathematics and biology
# oncology and cancer biology
# mathematical biology
# geology-biology
# biology, general
# mathematics-chemistry-biology-entrepreneurship
# biochemistry and molecular biology
# english, biology
# biology, chemistry, naval science
# mathematics, biology
# biology
# computer science and biology
# geology
# biochemistry
#
# Cluster 61:
# engineering
# structural engineering
# electical engineering
# biomedicalmedical engineering
# electricalelectronic engineering
# vehicle engineering
# electrial engineering
# elecrical engineering
# plastics engineering
# nuclear engineering
# reverse engineering  exploitation
# mechanicalmanufacturing engineering
# biosystems engineering
# rf and microwave engineering
# pre-engineering
# architectural engineering
# optoelectronic engineering
# rf engineering
# transportation engineering
# advanced engineering
# chemical and biological engineering
# engineering, ai  ml techniques
# chemcial and biomolecular engineering
# metallurgical engineering
# e-commerce engineering
# chemical and biomolecular engineering
# petroleum engineering(reservoir simulation)
# electricalelectronics engineering
# computaional and mathematical engineering
# petroleum engineering
# chemical engineering
# electric engineering
#
# Cluster 62:
# optics applied mathematics
# applied mathematics and economics
# mathematics, arithmetic geometry
# applied mathematics
# applied mathematics and a specialization in computing
# electricalcomputer engineering, mathematics
# mathematics
# mathematics, advanced
# applicable mathematics
# applied mathematics, minor cs
# mathematics and applied mathematics
# mathematics (intensive)
# applied computational mathematics
# applied mathematics and computer science
# computational and applied mathematics
# mathematics, cs certificate
# pure mathematics
# cs
#
# Cluster 63:
# vlsi
# electrical engineering - vlsi
# vlsi design tools and techlonogy
# computer engineering (vlsi)
# vlsi systems
# vlsi design
# computer engineering, vlsi design concentration
# electrical and computer engineering - major in vlsi
# cmos vlsi
# electrical engineering (vlsi)
#
# Cluster 64:
# electronics and computer tech
# opto-electronics information science and engineering
# electronics and information science
# science and electronics
# electronics and computer science
# electronics and science
#
# Cluster 65:
# industrial and systems engineering, supply chain and transportation
# supply chain management
# logistics  supply chain analytics
# integrated supply chain management; engineering coursework - top  nationally ranked program
# logistics and supply chain management
# supply chain management and management information systems
# operations and supply chain management
# logistics, materials, and supply chain management
# business honors, supply chain management
# packaging value chain
#
# Cluster 66:
# computer science (mcit)
# computer science (games)
# computer science, min
# computer science
# honours computer science
# computer science, business
# computer science and cognitive science
# masters of science, computer science,
# computer science and robotics
# computer science and statistical science
# computer science and bioinformatics
# bsc computer science
# computer science and business
# computer science and italian
# computer science (harvey mudd college)
# computer science and engineereing
# computer science, finance
# transfer, computer science
# computer science - computer security
# icse - computer science
# computer science, entrepreneurship
# computer science  entrepreneurship
# computer science, cognitive science
# computer science, gold medalist
# computer science (data science concentration)
# oregon transfer degre
# college,  years
# computer science, concentrating on ai
# computer science, creative writing
# bioinformatics
#
# Cluster 67:
# computer engineer
# electrical engineer
# computer sciences engineer
# front-end engineer
# hybrid cloud engineer
# network engineer
# automation engineer technologytechnician
# computaer engineer
# oracle cloud
#
# Cluster 68:
# applied economics and statistics
# probability  statistics, applied mathematics, architecture
# applied statistics  computer science
# chemical engineering, applied statistics and informatics
# applied statistics
# applied statistics and data management
# applied mathematics and statistics  data science, distinction in both majors
#
# Cluster 69:
# java and cloud computing(aws)
# information and computing science
# parallel computing
# information  computing science
# high performance embedded computing
# scientific computing
# computing security
# computing systems
# mathematics and computing
# computing science  information systems
# engineering  computing
# cloud computing and software as a service
# computing and information technology
# computing
# java
#
# Cluster 70:
# science stream
# physicsmaterial science
# compute science
# science
# kinesiology and exercise science
# mathcomputer science
# compuer science
# nursing science
# englishcomputer science
# environmental geo-science
# quantitative methods and causal inference in social science
# science degree - network administration
# pure science
# environmental science
# packaging science
# material science
# military science
#
# Cluster 71:
# networking, and administration
# computer networking systems
# applied networking  system administration, communications
# computer networking
# networking
# system, networking, and lanwan managementmanager
# information networking
# computer networking and server administration
# computer science and networking
# engineering and applied science; telecommunications and networking
# cisco networking
# computer systems networking
# computer repair, networking
#
# Cluster 72:
# marketing, sales, art
# art history, criticism and conservation
# art
# art practice
# majored in art and minored in art history
# concentration in art history and languages
# educationinstructional practice
#
# Cluster 73:
# control and instrumentation engineering
# instrumentation and control engineering
# electronics instrumentation and control
# electronics and instrumentation control
# instrumentation and control
#
# Cluster 74:
# criminal justice
# criminal justice political science
# criminal justicelaw enforcement administration
# criminal justicepolice science
# criminal justicesociology
# criminal justice and corrections
#
# Cluster 75:
# master of financial management
# university of pennsylvania
# master of science (ms), management of information technology
# master of information systems management
# msc - master of computer sciences
# master of computational data science
# administrative of justice
# internet of things engineering
# internet of things
# masters of engineering
# graduate diploma of counselling and psychotherapy
# faculty of foreign languages
# (sardar patel college of engineering)
#
# Cluster 76:
# astronomy, physics, and mathematics
# physics, astronomy
# astronomy minor
# astronomy
# astronomy  physics
# mathematics, astronomy, physics
#
# Cluster 77:
# project management
# project lead the way program
# network security  agile project management
# project management certification
# information technology  project management
# chemical engineering; project management
# business analytics and project management
# business administration - project management
# engineering project management initiating and planning
# information technology project management
#
# Cluster 78:
# electronics engineering
# electronics and computers
# engineering, radiophysics and electronics
# micro electronics
# electronics and computer engineering
# computer electronics engineering
# electronics
# computers
#
# Cluster 79:
# korean language
# computer speech and language
# english language and literatureletters
# language and information technologies
# english language program
# linguistics; russian language and culture
#
# Cluster 80:
# game design and development
# game design  development
# electronic game design
# computer science and game design
# computer science (game development)
# game development
#
# Cluster 81:
# electric information engineering
# information sciencestudies
# information retrieval
# optoelectronic information science and engineering
# information science  engineering
# computer information science
# computer science  information engineering (another major finance)
# information science and engineering
# computer and information science
# information science engineering
# geographic information science and cartography
# computer science and information engineering
# information science
# information engineering
#
# Cluster 82:
# digital modeling in virtual reality at université d'angers
# digital currency
# digital media design
# digital communications
# communications in digital media
# dynamic digital media
# digital gaming and simulation
# digital communications  electro-optics
# fiber optics
# mit media lab
# interdisciplinary studies with a depth study in film, computing, and new digital media
# media planning, buying  analysis; social media management
# electro-magnetics
#
# Cluster 83:
# cybersecurity and forensics
# information systems, cybersecurity
# computer software and cybersecurity
# cybersecurity
# software engineering (cybersecurity)
# foundations of cybersecurity
# cybersecurity analytics
# major in cybersecurity
# cybersecurity engineering
# computer and information science and cybersecurity
#
# Cluster 84:
# industrial eng - operations mgmt  research
# operations research and statistics
# ml and operations research
# operations research and information engineering
# industrial engineering and operations research
# industrial engineering  operations research
# operations research
#
# Cluster 85:
# electrical power engineering
# power systems
# power electronics and motion control
# electric power engineering
# power converters and drives
# power and energy systems
# power electronics
# automotive motorsports  clean power systems
#
# Cluster 86:
# media arts  sciences
# liberal arts and sciencesliberal studies
# aassociate of arts
# animation arts  design
# arts and sciences
# liberal arts and sciences, general studies and humanities
# media arts and sciences
# interdisciplinary program with focus in communications, fine arts photography, sociology
# visual effects  animation
# d animation
#
# Cluster 87:
# bs of computer engineering and bs of computer science
# bs finance
# computer science (bs) and environmental science (bs)
# computer science bs
#
# Cluster 88:
# computer science and automation
# automation science and electrical engineering
# electrical engineering and automation
# software testing and automation specialization
# automation
# automation and robotics
# mechanical and automation engineering
# mechanical engineering and automation
# mechanical  automation engineering
#
# Cluster 89:
# mathematical and computational science
# computational science and engineering
# computational modelling and simulation
# computational mathematics
# computational science  engineering
# computational science
# computer science and computational mathematics
# computational engineering
#
# Cluster 90:
# cyber security  forensics emphasis
# network and cyber security
# cyber security and digital forensics
# cyber security engineering
# cyber security analytics
# cyber security
#
# Cluster 91:
# math statistics and probability
# statistics and econometrics
# computer science  statistics
# data science and statistics
# econometrics and quantitative economics, mathematics, computer science, statistics
# mathematics  statistics
# computer science and statistics (double)
# concentration statistics
# statistics and computer science
# psycholgoy, statistics
# statistics
# mathematics (statistics track)  economics
# data science, mathematics, statistics
# mathematics and statistics
# economics and statistics
# industrial statistics
# calculus  statistics
# statistics with emphasis on health science
#
# Cluster 92:
# sound artsaudio production
# production engineering
# production management
# double option in "computer information systems" and "production operation mgmt"
#
# Cluster 93:
# electronic and information engineering
# electrical and electronic engineering
# electronic engineering
# electrical and electronic engineering, computational electromagentics
# electronic publishing specialist
# electronic and computer engineering
# electrical  electronic engineering
# electronic circuits and systems
# finance(dual major), electronic and communication engineering
# microelectronics and solid electronic
# microelectronics
#
# Cluster 94:
# information systems and management
# management information systems
# management information systems and finance
# information systems management
# business management, minor management information systems
# management - management of information systems - risk management
# management of information and communications systems
# information management and systems
# management information systems, computer science and accounting minors
# management information systems and services
# management information systems, general
# information management
# information management  information systems
# management - information systems
#
# Cluster 95:
# computer science, finance, math
#  , sat  (math , reading , writing )
# math and science
# mathematics and applied math
# math computer science
# applied math
# computer science, applied math and statistics
# computer science, applied math
# physics, latin, applied math
# applied and computational mathematical sciences discrete math and algorithms
# math, physics, electronics
# discrete algorithms
#
# Cluster 96:
# electrical and electronics
# electrical engineering (electronics)
# electrical and electronics engineering, specification in robotics
# electrical  electronics eng
# electrical  electronics engineering
# electrical engineering, electronics circuits and system
# management science and innovation; electrical and electronics engineering
# electrical and electronics engineering
# electrical engineering electronics
#
# Cluster 97:
# specialization in nvh(noise vibration and harshness)
# mechanical engineer with a specialization in design
# mathematics with a specialization in actuarial science
# computer science (specialization in ai and os)
# electronics and communications engineering with minor specialization in computer science
# actuarial science
#
# Cluster 98:
# th standard
# aisse  (cbse)
# cbse th standard
# cbse
# primary educatiion till th
#
# Cluster 99:
# nanotechnology
# nanotechnology engineering
#
# Cluster 100:
# uctech school of design
# high school diploma
# computer science (school of engineering)
# school of computing, informatics, and decision systems engineering
# computer science (school of engineering), english
# school
# grade school
# regulargeneral high schoolsecondary diploma program
# school of earth sciences interdisciplinary program in earth energy and environmental science
#
# Cluster 101:
# mathematics, physics and chemistry
# mathematics physics chemistry
# physics, chemistry, mathematics, electronics
# mathematics, physics, chemistry, biology and languages
# physics, chemistry, mathematics, knowledge  inquiry
# mathematics,physics and chemistry
# physics, chemistry,mathematics,economics
# math,physics,chemistry and computers
# (physics, chemistry, mathematics, electronics)
# mpc - mathematics, physics and chemistry
# math, physics, chemistry
# mathematics, physics, chemistry
# mpc
#
# Cluster 102:
# computer engineering computer science
# computer science engineering
# computer science (engineering)
# computer engineering, computer science
# computer science  engineering
# computer engineering and computer science
# chemical engineering and computer science
# computer engineering
# computer engineering | computer science - intelligence
# engineering; computer science
# computer science and engineering
# computer engineering  computer science, german certificate
# cse (computer science and engineering)
# cse
# electric and computer engineering
# computer sc  engineering
# computer science - artificial intelligence
# computer engineering  society
#
# Cluster 103:
# sport and entertainment management
# sport management
#
# Cluster 104:
# construction management
# community development w areas of building construction and acocunts registrar
# construction engineering
# construction technology and management
# cityurban, community and regional planning
#
# Cluster 105:
# electrical and computer engineering (specialization in embedded systems)
# embedded system design
# hardware and embedded design
# software engineering, application programming, embedded systems, security
# embedded systems
# electrical engineering, specializing in embedded systems
# embedded systems design
# embedded systems  vlsi design
# embedded systems engineering
#
# Cluster 106:
# chinese
# chinese language and culture
# traditional chinese medicine and chinese herbology
# chinese language and literature
# chinese business environment  german
# german
# clinical medicine
#
# Cluster 107:
# english (teaching chinese as a foreign language)
# teaching english as a second or foreign languageesl language
# teaching english as a second language
# attended as part of the congress-bundestag youth exchange
#
# Cluster 108:
# communications; communication and culture; recruitment chairman
# communication
# information and communication engineering
# communication engineering
# dsp  communication systems
# organizational communication
# strategic communication, advertising
# tele-communication engineering
# communication theory and systems
# digital communication and mediamultimedia
# communication systems engineering
# computer and communication
# electrical engineering; communication system
# advertising
#
# Cluster 109:
# masters in computer applications
# computer applications
# computer programming, specific applications
# intermediate applications developer
# web applications and services
# communication applications technology
# computer science applications
# economics with financial applications, public policy
#
# Cluster 110:
# human resources management
# human resources managementpersonnel administration, general
# human environmental science
# human resources management and services
# natural resources
# human computer interaction
# informed leadership combating human trafficking globally
# human resources
# energy, environment, and natural resources law
#
# Cluster 111:
# innovation, entrepreneurship, strategy, management, technology
# product management strategy
# strategy
# corporate strategy and finance
# marketing, strategy, product management
# operationslogistics and business strategy
# finance strategy
# strategy  management consulting, marketing
# business strategy and marketing
# product innovation
# corporate innovation and entrepreneurship
# marketing
#
# Cluster 112:
# specialization machine learning
# deep learning
# computer science, deep learning
# computer science - machine learning
# machine learning engineer
# machine learning and computer vision
# electrical and computer engineering (machine learning specialization)
# statistics and machine learning
# machine learning, modeling and simulation
# machine learningdata science
# computer vision and machine learning
# electrical and computer engineering (machine learning track)
# optimization and learning
# statistics, machine learning
# machine tool technology
# research - machine learning
# machine learning
#
# Cluster 113:
# mechanical engineering, summa cum laude
# computer science (magna cum laude)
# magna cum laude
# business management, cum laude
# civil engineering - magna cum laude
# systems and computing engineering - summa cum laude
#
# Cluster 114:
# software quality assurance
# software engineering and quality testing
# software quality assurance course
# quality control
# mobile app testing using appium
#
# Cluster 115:
# business intelligence and data analytics
# chemical engineering and data analytics
# data analytics
# information systems management, business intelligence and data analytics
# data science  analytics
# business data analytics
# wharton's business analytics from data to insights
# data analytics engineering
# computer science and business data analytics
# mba with emphasis in business analytics  data science
# data science - business  industrial analytics
# concentration in data analytics, research, and assessment
# computer science and data analytics
# artificial intelligence
# cumulative   (converts to )
# exchange student- artificial intelligence
#
# Cluster 116:
# wireless communications
# wireless communication
# electronics  electrical communication engineering, micro-specialization in embedded wireless system
# wireless hacking
# electrical engineering - wireless communications
# wireless networks, computer science
# wireless embedded systems
#
# Cluster 117:
# , nancy-metz valedictorian
#  (valedictorian)
#
# Cluster 118:
# computer science vision, graphics, interaction, and robotics track
# vision, graphics, interaction, and robotics track
# computer vision
# robotics and artificial intelligence
# robotics
# stem track
#
# Cluster 119:
# philosophy with honors
# pass with honors
# electrical engineering with honors
# computer science (turing scholar honors program)
# honors
# oracle intensive program
# gifted program
# chemical and biomolecular engineering, high honors, quantitative finance minor
#
# Cluster 120:
# international baccalaureate
# business administration and international studies
# international transactions and comparative law
# international trade
# international relations and affairs
# organizational and international business
# marketing, international business
# international economics
# international relations
# international business and economics
# international business
# international management
# international economic law
# marketing and international business
# international public healthinternational health
# international educational development
# public health
# law
#
# Cluster 121:
# internet technologies
# linux  cloud infrastructure technologies  kubernetes  dockers
# multimedia and creative technologies
# geographic information science and technologies
# computer science (multimedia  creative technologies)
# business information technologies
# information technologies
#
# Cluster 122:
# bioengineering and biomedical engineering
# bioengineering
# bioengineering and biomedical engineering and minor in computer science
#
# Cluster 123:
# technical operator
# management informations systems, computer science, technical communication
# technical management
#
# Cluster 124:
# pcm with computer science
# pcm
# non-medical (pcm)
# science (pcm)
# non-medical
# non medical
#
# Cluster 125:
# applied mathematics and informatics
# computational informatics
# informatics
# information technology and informatics
# pcm with informatics practices
# biomedical informatics
#
# Cluster 126:
# materials and metallurgical engg
# computer science  engg
# computer science and engg
# electrical and computer engg
#
# Cluster 127:
# analog  mixed signal ic design
# analog ic design
# mixed signal vlsi
# rfmixed signal ic design
# analog and mixed signals
#
# Cluster 128:
# computer science and history
# history, computer science
# computer science and history of science
# secondary ed history
# history, business
# history
# secondary
#
# Cluster 129:
# mathematics and physics
# physics, mathematics
# physics, computer science, mathematics
# physics (minar mathematics)
# computer science, mathematics, physics
# mathematics, physics, and engineering
# sciences - physics, biology, mathematics
# mathematics and physics majors, computer science minor
#
# Cluster 130:
# computational neuroscience
# neuroscience
# neuroscience and photography
#
# Cluster 131:
# electronics and telecommunications
# telecommunications certificate
# telecommunications management
# telecommunications engineering
# electronics and telecommunications engg
# electronics  telecommunications
# telecommunications
# electronics and telecommunications engineering
# high schoolsecondary certificate programs
# professional certificate
#
# Cluster 132:
# it
# it management
# it strategic management
# it security
# it engineering
# it support
# business and it
# it operating systems and programming
#
# Cluster 133:
# civil engineering
# architectural and civil engineering
# earthquake engineering in civil engineering
# civil and environmental engineering
#
# Cluster 134:
# physics and math (double major)
# computer science and data science (double major)
# double major in mathematics and data science
# double major in applied mathematics and statistics
# double major in computer science and information systems
# dual major in computer science  engineering and mathematics
# double major in cybersecurity and network engineering
# computer science, commerce (double degree)
#
# Cluster 135:
# engineering mechanics
# mechanics and automotive
# mechanical and automotive engineering
# automotive engineering technologytechnician
# automotive engineering
# heating, air conditioning, ventilation and refrigeration maintenance technologytechnician
#
# Cluster 136:
# with specialization in product design and manufacturing
# (structures, materials and manufacturing)
# manufacturing and mechanical engineering
# computational design and manufacturing
# mechanical engineering computational mechanics and manufacturing
# propulsion and additive manufacturing
#
# Cluster 137:
# cognitive science  neuroscience
# cognitive neuroscience
# cognitive neuropsychology and neuroscience
# cognitive science
#
# Cluster 138:
# spanish languge and multicultural studies
# spanish
# biology and spanish literature
# computer science  spanish
# physics part ii  spanish part b
#
# Cluster 139:
# electronics and communications
# electrical, electronics and communications engineering
# electronics and tele-communications engineering
# electronics  communications engineering
# electronics and communications engineering
# electronics and tele communications
#
# Cluster 140:
# mathematics teacher education
# social studies teacher education
# history teacher education
#
# Cluster 141:
# user experience and web design
# user experience (ux) design minor; e-commerce web developer certification
# web design
# user experience design
# a+ certification
# e-commerceelectronic commerce
#
# Cluster 142:
# vlsi and computer architecture
# computer vision, history of architecture
# digital communication, computer architecture
# electrical and computer engineering - computer architecture and embedded systems
# architecture
# electrical engineering with focus on vlsi and computer architecture
# computer architecture  embedded system
# interior architecture  design
#
# Cluster 143:
# mpsi et mp
# mpsi - psi
#
# Cluster 144:
# data analytics  visualization
# data analytics and visualization
#
# Cluster 145:
# sciences pures et appliquée, programme eureka
# programmation sémantique, preuves et langages
# formation et enseignement secondaires
#
# Cluster 146:
# mechatronics, robotics, and automation engineering
# mechatronics engineering – co-operative program
# mechatronics design
# mechatronics engineering
# mechatronics technology
# mechatronics
#
# Cluster 147:
# assurance
# cybersecurity and informarion assurance
# computer and information systems securityinformation assurance
# information sciences - cybersecurity and information assurance
# information security and assurance
# information sciences, cybersecurity and information assurance
#
# Cluster 148:
# english literature, political science
# concentrations in small business  political science
# political science and government
# political science
# psychology and political science with a minor in business
# political science, computer science
#
# 0
# 111

# %% [markdown]
# Naming Degree Clusters with API:

# %%
model = genai.GenerativeModel('gemini-pro')
clusters_degree = {}
for cluster_id, deg_in_cluster in enumerate(clustered_degree):
    prompt = "name this degree cluster, give unique name:" + str(deg_in_cluster)
    response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            # Only one candidate for now.
            candidate_count=1,
            temperature=0.7
        )
    )
    time.sleep(1.5)
    clusters_degree[cluster_id] = response.parts[0].text

# %% [markdown]
# Re-Naming if there are duplicate names:

# %%
def print_duplicates(lst):
    seen = set()
    duplicates = set()

    for index,item in enumerate(lst):
        if item in seen:
            duplicates.add((item,index))
        else:
            seen.add(item)

    for dup in duplicates:
      prompt = f"give this degree cluster: {clustered_degree[dup[1]]}, a different name than:"+str(dup[0])
      response = model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            # Only one candidate for now.
            candidate_count=1,
            temperature=0.7
        )
    )
    time.sleep(1.5)
    clusters_degree[dup[1]] = response.parts[0].text





print_duplicates(list(clusters_degree.values()))


for key,val in clusters_degree.items():
    clusters_degree[key]=val.replace('*', '')

clustered_degree_dict ={}
for index,cluster in enumerate(copy_list):
  clustered_degree_dict[clusters_degree[index]] = cluster


degree_dict = {}
for key, values in clustered_degree_dict.items():
    for value in values:
        degree_dict[value] = key

# %% [markdown]
# Saving Degree Clusters to CSV:

# %%
def dict_to_csv(dictionary, filename):
    max_length = max(len(lst) for lst in dictionary.values())
    df = pd.DataFrame({k: pd.Series(v[:max_length]) for k, v in dictionary.items()})
    df.to_csv(filename, index=False)

dict_to_csv(clustered_degree_dict,'all_clustered_degree.csv')

# %% [markdown]
# Loading CSV to Dict:

# %%
# Load CSV file into DataFrame
df = pd.read_csv('all_clustered_degree.csv')

# Initialize clustered_skills as a list of empty lists
num_clusters = len(df.columns)
clustered_degree = [[] for _ in range(num_clusters)]

# Iterate over each column (cluster) in the DataFrame
for cluster_id, column_name in enumerate(df.columns):
    cleaned_list = [x for x in df[column_name].tolist() if not pd.isna(x)]
    clustered_degree[cluster_id] = [column_name,cleaned_list]
# Create a dictionary to store clusters
clustered_degree_dict = {cluster[0]: cluster[1] for cluster in clustered_degree}
print(len(clustered_degree_dict))
#print(clustered_dict)

# %% [markdown]
# Mapping Degree Fields:

# %%
degree_dict = {}
for key, values in clustered_degree_dict.items():
    for value in values:
        degree_dict[value] = key

def transform_list(lst):
    return [degree_dict.get(item,item) for item in lst]

# Apply the function to create the new column
model_df['degree_field'] = model_df['degree_field'].apply(lambda x: transform_list(x))

# %% [markdown]
# mapping skills to skill_cluster name

# %%
def map_skills(skill_string):
    skill_descriptions = skill_string.split(' ')
    skill_list = skill_descriptions[1::2]
    mapped_skills = []
    for skill in skill_list:
      mapped_skill = skill_dict.get(skill,skill)
      if mapped_skill:
          if ":" not in mapped_skill: mapped_skills.append(mapped_skill)
    return mapped_skills

# Apply the mapping function to the "skills" column to create a new column
model_df['skills'] = model_df['skills'].apply(map_skills)
#model_df['skills'] = model_df['skills'].apply(lambda x: x.split(", "))

# %% [markdown]
# cleaning courses_title

# %%
stop_words = ["the","of",'to',"and","for","in","i","ii","iii","ap","&","advanced"]

def remove_stop_words(sentence):
    # Tokenize the sentence into words
    words = sentence.split()
    # Remove stop words
    filtered_words = [word for word in words if word.lower() not in stop_words]
    # Reconstruct the sentence without stop words
    filtered_sentence = ' '.join(filtered_words)
    return filtered_sentence


def preprocess_string(string):
    # Lowercase the string
    string = string.lower()
    # Split the string into a list
    string=string.replace("'", "")
    processed_list = [elem.strip() for elem in string.strip("[]").split(",")]
    # Remove stop words
    processed_list = [remove_stop_words(sentence) for sentence in processed_list]
    return processed_list

# Apply the function to the column of strings

model_df['courses_title'] = model_df['courses_title'].apply(preprocess_string)
#test = model_df['courses_title'].iloc[:10]
#print(test[6])
